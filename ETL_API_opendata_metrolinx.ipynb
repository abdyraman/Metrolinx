# %%
# Dependencies
from pymongo import MongoClient
import requests
import json
from pprint import pprint
import pandas as pd

# %%
# Import the API key
from config import key

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the met database to a variable name
db = mongo['metrolinx']
# assign the collection to a variable
trains = db['trains']
buses=db['buses']
trip_updates=db['trip_updates']
service_messages=db['service_messages']
vechile_position=db['vechile_position']
train_cancelled=db['train_cancelled']
bus_cancelled=db['bus_cancelled']
all_cancelled=db['all_cancelled']

# %%
def get_data(trains_endpoint):
    base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'
    params = {
    "key": key
}

    # Run request
    response = requests.get(f"{base_url}{trains_endpoint}", params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Return the JSON response
        return response.json()
    else:
        # Raise an exception with the status code if the request failed
        response.raise_for_status()

# %%
trains_endpoint = "api/V1/ServiceataGlance/Trains/All"

try:
    train_data = get_data(trains_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trains_collection = db['trains']
    trains_collection.insert_one(train_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-07 10:26:52"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 232.0,
#                 "DelaySeconds": 70,
#                 "Display": "LW - Aldershot GO",
#                 "EndTime": "11:22",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "AL",
#                 "Latitude": 43.633879,
#                 "LineCode": "LW",
#                 "Longitude": -79.473591,
#                 "ModifiedDate": "2023-08-07 10:26:31",
#                 "NextStopCode": "GARD",
#                 "PrevStopCode": "DUFF",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "10:14",
#                 "TripNumber": "1013",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 37.0,
#                 "DelaySeconds": 149,
#                 "Display": "LW - Union Station",
#                 "EndTime": "11:15",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.425031,
#                 "LineCode": "LW",
#                 "Longitude": -79.713574,
#                 "ModifiedDate": "2023-08-07 10:26:30",
#                 "NextStopCode": "KERR",
#                 "PrevStopCode": "BO",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "10:04",
#                 "TripNumber": "1014",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "WATE",
#                 "Cars": "12",
#                 "Course": 0.0,
#                 "DelaySeconds": -2252,
#                 "Display": "LW - Union Station",
#                 "EndTime": "12:15",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.314081,
#                 "LineCode": "LW",
#                 "Longitude": -79.853175,
#                 "ModifiedDate": "2023-08-07 10:26:28",
#                 "NextStopCode": "WATE",
#                 "PrevStopCode": "AL",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "11:04",
#                 "TripNumber": "1016",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "KERR",
#                 "Cars": "-",
#                 "Course": 217.0,
#                 "DelaySeconds": 29,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "11:05",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.455737,
#                 "LineCode": "LW",
#                 "Longitude": -79.681793,
#                 "ModifiedDate": "2023-08-07 10:26:30",
#                 "NextStopCode": "KERR",
#                 "PrevStopCode": "OA",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "09:44",
#                 "TripNumber": "1711",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "MIME",
#                 "Cars": "12",
#                 "Course": 47.0,
#                 "DelaySeconds": -91,
#                 "Display": "LW - Union Station",
#                 "EndTime": "10:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.617788,
#                 "LineCode": "LW",
#                 "Longitude": -79.495059,
#                 "ModifiedDate": "2023-08-07 10:26:30",
#                 "NextStopCode": "MIME",
#                 "PrevStopCode": "MI",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "09:23",
#                 "TripNumber": "1712",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 331.0,
#                 "DelaySeconds": 46,
#                 "Display": "LW - Union Station",
#                 "EndTime": "11:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.275504,
#                 "LineCode": "LW",
#                 "Longitude": -79.887944,
#                 "ModifiedDate": "2023-08-07 10:26:29",
#                 "NextStopCode": "HAMJ",
#                 "PrevStopCode": "DDRN",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "10:23",
#                 "TripNumber": "1714",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 108.0,
#                 "DelaySeconds": 163,
#                 "Display": "LW - Niagara Falls GO (VIA Station)",
#                 "EndTime": "11:24",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "NI",
#                 "Latitude": 43.21657,
#                 "LineCode": "LW",
#                 "Longitude": -79.653415,
#                 "ModifiedDate": "2023-08-07 10:26:29",
#                 "NextStopCode": "HBWI",
#                 "PrevStopCode": "MCNE",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "09:03",
#                 "TripNumber": "1961",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "6",
#                 "Course": 97.0,
#                 "DelaySeconds": -231,
#                 "Display": "GT - Union Station",
#                 "EndTime": "10:36",
#                 "FirstStopCode": "MO",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.640374,
#                 "LineCode": "GT",
#                 "Longitude": -79.413255,
#                 "ModifiedDate": "2023-08-07 10:26:30",
#                 "NextStopCode": "STWE",
#                 "PrevStopCode": "PAWE",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "09:49",
#                 "TripNumber": "3412",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "6",
#                 "Course": 256.0,
#                 "DelaySeconds": 43,
#                 "Display": "GT - Mount Pleasant GO",
#                 "EndTime": "10:39",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "MO",
#                 "Latitude": 43.700128,
#                 "LineCode": "GT",
#                 "Longitude": -79.698089,
#                 "ModifiedDate": "2023-08-07 10:26:26",
#                 "NextStopCode": "HBPE",
#                 "PrevStopCode": "BE",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "09:51",
#                 "TripNumber": "3511",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "ALNS",
#                 "Cars": "12",
#                 "Course": 315.0,
#                 "DelaySeconds": 26,
#                 "Display": "BR - Allandale Waterfront GO",
#                 "EndTime": "10:37",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "AD",
#                 "Latitude": 44.350248,
#                 "LineCode": "BR",
#                 "Longitude": -79.625855,
#                 "ModifiedDate": "2023-08-07 10:26:28",
#                 "NextStopCode": "ALNS",
#                 "PrevStopCode": "BA",
#                 "RouteNumber": "BR   ",
#                 "StartTime": "08:53",
#                 "TripNumber": "6909",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 58.0,
#                 "DelaySeconds": 26,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "11:20",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.67276,
#                 "LineCode": "LE",
#                 "Longitude": -79.334971,
#                 "ModifiedDate": "2023-08-07 10:26:26",
#                 "NextStopCode": "HBCH",
#                 "PrevStopCode": "KING",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "10:20",
#                 "TripNumber": "9012",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 237.0,
#                 "DelaySeconds": 48,
#                 "Display": "LE - Union Station",
#                 "EndTime": "11:09",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.822658,
#                 "LineCode": "LE",
#                 "Longitude": -79.103441,
#                 "ModifiedDate": "2023-08-07 10:26:27",
#                 "NextStopCode": "RO",
#                 "PrevStopCode": "DURJ",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "10:04",
#                 "TripNumber": "9015",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 8.0,
#                 "DelaySeconds": -4,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "10:50",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.811315,
#                 "LineCode": "LE",
#                 "Longitude": -79.114503,
#                 "ModifiedDate": "2023-08-07 10:26:30",
#                 "NextStopCode": "DURJ",
#                 "PrevStopCode": "RO",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "09:50",
#                 "TripNumber": "9210",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 241.0,
#                 "DelaySeconds": 33,
#                 "Display": "LE - Union Station",
#                 "EndTime": "10:39",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.685235,
#                 "LineCode": "LE",
#                 "Longitude": -79.303552,
#                 "ModifiedDate": "2023-08-07 10:26:28",
#                 "NextStopCode": "CNDA",
#                 "PrevStopCode": "DA",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "09:34",
#                 "TripNumber": "9213",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "THIE",
#                 "Cars": "12",
#                 "Course": 65.0,
#                 "DelaySeconds": -453,
#                 "Display": "LE - Union Station",
#                 "EndTime": "11:39",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.870795,
#                 "LineCode": "LE",
#                 "Longitude": -78.885376,
#                 "ModifiedDate": "2023-08-07 10:26:28",
#                 "NextStopCode": "THIE",
#                 "PrevStopCode": "OS",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "10:34",
#                 "TripNumber": "9215",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
buses_endpoint='api/V1/ServiceataGlance/Buses/All'
try:
    buses_data = get_data(buses_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(buses_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    buses_collection = db['buses']
    buses_collection.insert_one(buses_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-07 10:26:52"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 92.0,
#                 "DelaySeconds": -157,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "11:24",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.18915,
#                 "LineCode": "12",
#                 "Longitude": -79.517483,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02402",
#                 "PrevStopCode": "02406",
#                 "RouteNumber": "12   ",
#                 "StartTime": "09:39",
#                 "TripNumber": "12261",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 96.0,
#                 "DelaySeconds": -205,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "10:54",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.177433,
#                 "LineCode": "12",
#                 "Longitude": -79.284717,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "00819",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "09:54",
#                 "TripNumber": "12263",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00177",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "12:34",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": false,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.3895,
#                 "LineCode": "12",
#                 "Longitude": -79.82915,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12   ",
#                 "StartTime": "10:39",
#                 "TripNumber": "12301",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00819",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "12:04",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": false,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.340217,
#                 "LineCode": "12",
#                 "Longitude": -79.809717,
#                 "ModifiedDate": "2023-08-07 10:26:18",
#                 "NextStopCode": "00819",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12B  ",
#                 "StartTime": "10:54",
#                 "TripNumber": "12303",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 3.0,
#                 "DelaySeconds": -117,
#                 "Display": "12  - Burlington Carpool",
#                 "EndTime": "11:15",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": true,
#                 "LastStopCode": "00139",
#                 "Latitude": 43.204733,
#                 "LineCode": "12",
#                 "Longitude": -79.595117,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00820",
#                 "PrevStopCode": "02406",
#                 "RouteNumber": "12   ",
#                 "StartTime": "09:25",
#                 "TripNumber": "12320",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02405",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12B - Burlington GO",
#                 "EndTime": "12:02",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": false,
#                 "LastStopCode": "00177",
#                 "Latitude": 43.108683,
#                 "LineCode": "12",
#                 "Longitude": -79.063183,
#                 "ModifiedDate": "2023-08-07 10:17:18",
#                 "NextStopCode": "02405",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12B  ",
#                 "StartTime": "10:57",
#                 "TripNumber": "12362",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02405",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12  - Burlington Carpool",
#                 "EndTime": "13:15",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": false,
#                 "LastStopCode": "00139",
#                 "Latitude": 43.108633,
#                 "LineCode": "12",
#                 "Longitude": -79.063,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02405",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12   ",
#                 "StartTime": "11:20",
#                 "TripNumber": "12400",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 214.0,
#                 "DelaySeconds": 81,
#                 "Display": "15 - Brantford Term",
#                 "EndTime": "10:56",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": true,
#                 "LastStopCode": "02617",
#                 "Latitude": 43.229283,
#                 "LineCode": "15",
#                 "Longitude": -79.95375,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02610",
#                 "PrevStopCode": "02619",
#                 "RouteNumber": "15   ",
#                 "StartTime": "10:01",
#                 "TripNumber": "15171",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 85.0,
#                 "DelaySeconds": 19,
#                 "Display": "15 - Aldershot GO",
#                 "EndTime": "11:20",
#                 "FirstStopCode": "02617",
#                 "IsInMotion": true,
#                 "LastStopCode": "00180",
#                 "Latitude": 43.13855,
#                 "LineCode": "15",
#                 "Longitude": -80.26365,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02614",
#                 "PrevStopCode": "02617",
#                 "RouteNumber": "15   ",
#                 "StartTime": "10:25",
#                 "TripNumber": "15440",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 108.0,
#                 "DelaySeconds": -383,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "10:30",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.253,
#                 "LineCode": "16",
#                 "Longitude": -79.870283,
#                 "ModifiedDate": "2023-08-07 10:23:39",
#                 "NextStopCode": null,
#                 "PrevStopCode": "01014",
#                 "RouteNumber": "16   ",
#                 "StartTime": "09:30",
#                 "TripNumber": "16261",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -510,
#                 "Display": "16  - Union Station",
#                 "EndTime": "10:35",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.64375,
#                 "LineCode": "16",
#                 "Longitude": -79.376417,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "09:30",
#                 "TripNumber": "16300",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "11:30",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.644067,
#                 "LineCode": "16",
#                 "Longitude": -79.377733,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "10:30",
#                 "TripNumber": "16301",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 39.0,
#                 "DelaySeconds": 290,
#                 "Display": "16  - Union Station",
#                 "EndTime": "11:05",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.3667,
#                 "LineCode": "16",
#                 "Longitude": -79.787583,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "10:00",
#                 "TripNumber": "16320",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Union Station",
#                 "EndTime": "11:40",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.252467,
#                 "LineCode": "16",
#                 "Longitude": -79.868333,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "10:30",
#                 "TripNumber": "16340",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Union Station",
#                 "EndTime": "12:15",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.2527,
#                 "LineCode": "16",
#                 "Longitude": -79.868517,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "11:00",
#                 "TripNumber": "16360",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Union Station",
#                 "EndTime": "12:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.2529,
#                 "LineCode": "16",
#                 "Longitude": -79.870083,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "11:30",
#                 "TripNumber": "16380",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "18  - Hamilton GO",
#                 "EndTime": "10:44",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.3131,
#                 "LineCode": "18",
#                 "Longitude": -79.8559,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "18   ",
#                 "StartTime": "10:27",
#                 "TripNumber": "18171",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 63.0,
#                 "DelaySeconds": 0,
#                 "Display": "18  - Aldershot GO",
#                 "EndTime": "10:54",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00180",
#                 "Latitude": 43.253017,
#                 "LineCode": "18",
#                 "Longitude": -79.870017,
#                 "ModifiedDate": "2023-08-07 10:14:18",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "18   ",
#                 "StartTime": "10:37",
#                 "TripNumber": "18420",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 252.0,
#                 "DelaySeconds": 412,
#                 "Display": "19 - Square One",
#                 "EndTime": "10:45",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.714267,
#                 "LineCode": "19",
#                 "Longitude": -79.533083,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": "00020",
#                 "RouteNumber": "19   ",
#                 "StartTime": "09:50",
#                 "TripNumber": "19271",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 39.0,
#                 "DelaySeconds": 7,
#                 "Display": "19 - Finch Terminal",
#                 "EndTime": "11:10",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.654483,
#                 "LineCode": "19",
#                 "Longitude": -79.6003,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02208",
#                 "PrevStopCode": "02659",
#                 "RouteNumber": "19   ",
#                 "StartTime": "10:15",
#                 "TripNumber": "19290",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Square One",
#                 "EndTime": "11:45",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.782717,
#                 "LineCode": "19",
#                 "Longitude": -79.414383,
#                 "ModifiedDate": "2023-08-07 10:25:39",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "10:50",
#                 "TripNumber": "19311",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": 67,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "10:28",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": true,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.521683,
#                 "LineCode": "21",
#                 "Longitude": -79.644417,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02214",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "09:38",
#                 "TripNumber": "21272",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 141.0,
#                 "DelaySeconds": -111,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "10:35",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": true,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.5691,
#                 "LineCode": "21",
#                 "Longitude": -79.601133,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02752",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "10:00",
#                 "TripNumber": "21274",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -263,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "10:44",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": false,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.5976,
#                 "LineCode": "21",
#                 "Longitude": -79.755333,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "01137",
#                 "PrevStopCode": "00129",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "09:54",
#                 "TripNumber": "21283",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": 94,
#                 "Display": "21A - Oakville GO",
#                 "EndTime": "10:50",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": true,
#                 "LastStopCode": "00137",
#                 "Latitude": 43.542183,
#                 "LineCode": "21",
#                 "Longitude": -79.790367,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01441",
#                 "PrevStopCode": "00808",
#                 "RouteNumber": "21A  ",
#                 "StartTime": "10:12",
#                 "TripNumber": "21290",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": 1,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "10:58",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": true,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.578217,
#                 "LineCode": "21",
#                 "Longitude": -79.733133,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01384",
#                 "PrevStopCode": "01237",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "10:08",
#                 "TripNumber": "21292",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02739",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "11:05",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": false,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.567567,
#                 "LineCode": "21",
#                 "Longitude": -79.66795,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02739",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21C  ",
#                 "StartTime": "10:30",
#                 "TripNumber": "21294",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00902",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21A - Milton GO",
#                 "EndTime": "11:11",
#                 "FirstStopCode": "00137",
#                 "IsInMotion": false,
#                 "LastStopCode": "00194",
#                 "Latitude": 43.45605,
#                 "LineCode": "21",
#                 "Longitude": -79.681617,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "00902",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21A  ",
#                 "StartTime": "10:31",
#                 "TripNumber": "21301",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 93,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "11:14",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": false,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.5126,
#                 "LineCode": "21",
#                 "Longitude": -79.632433,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "01241",
#                 "PrevStopCode": "00181",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "10:24",
#                 "TripNumber": "21303",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 314.0,
#                 "DelaySeconds": -39,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "10:52",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": true,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.578617,
#                 "LineCode": "21",
#                 "Longitude": -79.61385,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02655",
#                 "PrevStopCode": "02775",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "10:17",
#                 "TripNumber": "21305",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01483",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "11:28",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": false,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.592217,
#                 "LineCode": "21",
#                 "Longitude": -79.78855,
#                 "ModifiedDate": "2023-08-07 10:25:39",
#                 "NextStopCode": "01483",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21B  ",
#                 "StartTime": "10:38",
#                 "TripNumber": "21312",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00891",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21A - Oakville GO",
#                 "EndTime": "11:50",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": false,
#                 "LastStopCode": "00137",
#                 "Latitude": 43.524033,
#                 "LineCode": "21",
#                 "Longitude": -79.867683,
#                 "ModifiedDate": "2023-08-07 10:23:58",
#                 "NextStopCode": "00891",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21A  ",
#                 "StartTime": "11:12",
#                 "TripNumber": "21330",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 3.0,
#                 "DelaySeconds": 220,
#                 "Display": "25L - U of Waterloo",
#                 "EndTime": "11:00",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.412867,
#                 "LineCode": "25",
#                 "Longitude": -80.327867,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02148",
#                 "PrevStopCode": "02605",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "09:10",
#                 "TripNumber": "25241",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 249.0,
#                 "DelaySeconds": -79,
#                 "Display": "25C - U of Waterloo",
#                 "EndTime": "11:10",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.456917,
#                 "LineCode": "25",
#                 "Longitude": -80.115483,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02800",
#                 "PrevStopCode": "00133",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "09:55",
#                 "TripNumber": "25243",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 245.0,
#                 "DelaySeconds": 176,
#                 "Display": "25L - U of Waterloo",
#                 "EndTime": "12:00",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.530717,
#                 "LineCode": "25",
#                 "Longitude": -79.72475,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02151",
#                 "PrevStopCode": "02635",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "10:10",
#                 "TripNumber": "25281",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 32.0,
#                 "DelaySeconds": -591,
#                 "Display": "25L - Square One",
#                 "EndTime": "10:40",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.57255,
#                 "LineCode": "25",
#                 "Longitude": -79.6733,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02214",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "08:50",
#                 "TripNumber": "25310",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02148",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25C - U of Waterloo",
#                 "EndTime": "12:10",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.59535,
#                 "LineCode": "25",
#                 "Longitude": -79.648733,
#                 "ModifiedDate": "2023-08-07 10:25:18",
#                 "NextStopCode": "02148",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25C  ",
#                 "StartTime": "10:55",
#                 "TripNumber": "25313",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02215",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -528,
#                 "Display": "25L - U of Waterloo",
#                 "EndTime": "13:05",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.595267,
#                 "LineCode": "25",
#                 "Longitude": -79.64855,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25L  ",
#                 "StartTime": "11:10",
#                 "TripNumber": "25321",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 310.0,
#                 "DelaySeconds": -761,
#                 "Display": "25C - Square One",
#                 "EndTime": "10:35",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.595117,
#                 "LineCode": "25",
#                 "Longitude": -79.648317,
#                 "ModifiedDate": "2023-08-07 10:21:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "09:20",
#                 "TripNumber": "25332",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02151",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -525,
#                 "Display": "25L - Square One",
#                 "EndTime": "11:35",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.460333,
#                 "LineCode": "25",
#                 "Longitude": -80.133183,
#                 "ModifiedDate": "2023-08-07 10:26:18",
#                 "NextStopCode": "02151",
#                 "PrevStopCode": "02605",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "09:40",
#                 "TripNumber": "25350",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 164,
#                 "Display": "25C - Square One",
#                 "EndTime": "11:35",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.476467,
#                 "LineCode": "25",
#                 "Longitude": -80.52395,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "10:20",
#                 "TripNumber": "25372",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02153",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25L - Square One",
#                 "EndTime": "12:30",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.474633,
#                 "LineCode": "25",
#                 "Longitude": -80.538983,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02153",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25L  ",
#                 "StartTime": "10:35",
#                 "TripNumber": "25380",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 66.0,
#                 "DelaySeconds": -370,
#                 "Display": "27F - Meadowvale GO",
#                 "EndTime": "10:25",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00129",
#                 "Latitude": 43.597467,
#                 "LineCode": "27",
#                 "Longitude": -79.755267,
#                 "ModifiedDate": "2023-08-07 10:18:58",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02597",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "09:30",
#                 "TripNumber": "27261",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 37.0,
#                 "DelaySeconds": 65,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "10:55",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.706783,
#                 "LineCode": "27",
#                 "Longitude": -79.555167,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "00200",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "10:00",
#                 "TripNumber": "27280",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "27F - Meadowvale GO",
#                 "EndTime": "11:30",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00129",
#                 "Latitude": 43.782817,
#                 "LineCode": "27",
#                 "Longitude": -79.414467,
#                 "ModifiedDate": "2023-08-07 10:21:38",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "27F  ",
#                 "StartTime": "10:30",
#                 "TripNumber": "27301",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02598",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "12:05",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.5977,
#                 "LineCode": "27",
#                 "Longitude": -79.754617,
#                 "ModifiedDate": "2023-08-07 10:26:18",
#                 "NextStopCode": "02598",
#                 "PrevStopCode": null,
#                 "RouteNumber": "27F  ",
#                 "StartTime": "11:00",
#                 "TripNumber": "27320",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 8,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "10:40",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": false,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.521967,
#                 "LineCode": "29",
#                 "Longitude": -80.212233,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02721",
#                 "PrevStopCode": "01713",
#                 "RouteNumber": "29   ",
#                 "StartTime": "09:00",
#                 "TripNumber": "29251",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 233.0,
#                 "DelaySeconds": -157,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "11:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": true,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.598483,
#                 "LineCode": "29",
#                 "Longitude": -79.64235,
#                 "ModifiedDate": "2023-08-07 10:21:19",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": "02658",
#                 "RouteNumber": "29   ",
#                 "StartTime": "10:00",
#                 "TripNumber": "29291",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 39.0,
#                 "DelaySeconds": -23,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "11:20",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": true,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.56565,
#                 "LineCode": "29",
#                 "Longitude": -79.83505,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02214",
#                 "PrevStopCode": "02151",
#                 "RouteNumber": "29   ",
#                 "StartTime": "09:30",
#                 "TripNumber": "29320",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02660",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "12:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": false,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.635933,
#                 "LineCode": "29",
#                 "Longitude": -79.537433,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "11:00",
#                 "TripNumber": "29331",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00201",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "12:20",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": false,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.5449,
#                 "LineCode": "29",
#                 "Longitude": -80.2465,
#                 "ModifiedDate": "2023-08-07 10:25:39",
#                 "NextStopCode": "00201",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "10:30",
#                 "TripNumber": "29360",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 33.0,
#                 "DelaySeconds": 293,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "10:42",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.61005,
#                 "LineCode": "30",
#                 "Longitude": -79.7477,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00200",
#                 "RouteNumber": "30   ",
#                 "StartTime": "09:17",
#                 "TripNumber": "30230",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 12.0,
#                 "DelaySeconds": -9,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "10:47",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.60985,
#                 "LineCode": "30",
#                 "Longitude": -79.747867,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00200",
#                 "RouteNumber": "30   ",
#                 "StartTime": "09:22",
#                 "TripNumber": "30240",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 254.0,
#                 "DelaySeconds": 90,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "10:55",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.40405,
#                 "LineCode": "30",
#                 "Longitude": -80.375917,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02531",
#                 "PrevStopCode": "02587",
#                 "RouteNumber": "30   ",
#                 "StartTime": "09:35",
#                 "TripNumber": "30251",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02530",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -68,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "11:42",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.455533,
#                 "LineCode": "30",
#                 "Longitude": -80.492483,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02530",
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "30   ",
#                 "StartTime": "10:12",
#                 "TripNumber": "30270",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 138.0,
#                 "DelaySeconds": -245,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "11:47",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.458483,
#                 "LineCode": "30",
#                 "Longitude": -80.496433,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02530",
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "30   ",
#                 "StartTime": "10:17",
#                 "TripNumber": "30280",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02586",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "12:00",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.702217,
#                 "LineCode": "30",
#                 "Longitude": -79.689917,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02586",
#                 "PrevStopCode": null,
#                 "RouteNumber": "30   ",
#                 "StartTime": "10:35",
#                 "TripNumber": "30291",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02519",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 8975,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "08:45",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": false,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.745267,
#                 "LineCode": "33",
#                 "Longitude": -79.406933,
#                 "ModifiedDate": "2023-08-07 08:49:39",
#                 "NextStopCode": "02519",
#                 "PrevStopCode": null,
#                 "RouteNumber": "33   ",
#                 "StartTime": "06:20",
#                 "TripNumber": "33080",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 55.0,
#                 "DelaySeconds": 599,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "10:45",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.642933,
#                 "LineCode": "33",
#                 "Longitude": -79.648967,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "00354",
#                 "RouteNumber": "33   ",
#                 "StartTime": "08:15",
#                 "TripNumber": "33200",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 298,
#                 "Display": "33G - Mount Pleasant GO",
#                 "EndTime": "10:35",
#                 "FirstStopCode": "02413",
#                 "IsInMotion": false,
#                 "LastStopCode": "00296",
#                 "Latitude": 43.647533,
#                 "LineCode": "33",
#                 "Longitude": -79.868017,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00822",
#                 "PrevStopCode": "02696",
#                 "RouteNumber": "33G  ",
#                 "StartTime": "10:15",
#                 "TripNumber": "33240",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 46.0,
#                 "DelaySeconds": 144,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "12:55",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.558167,
#                 "LineCode": "33",
#                 "Longitude": -80.215267,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00802",
#                 "PrevStopCode": "01701",
#                 "RouteNumber": "33   ",
#                 "StartTime": "10:10",
#                 "TripNumber": "33280",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 315.0,
#                 "DelaySeconds": 496,
#                 "Display": "33 - U of Guelph",
#                 "EndTime": "12:10",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.6708,
# ...
#                 "LineCode": "68",
#                 "Longitude": -79.499067,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01805",
#                 "PrevStopCode": "01971",
#                 "RouteNumber": "68   ",
#                 "StartTime": "09:27",
#                 "TripNumber": "68330",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 351.0,
#                 "DelaySeconds": 295,
#                 "Display": "71  - Uxbridge",
#                 "EndTime": "10:48",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00302",
#                 "Latitude": 43.98045,
#                 "LineCode": "71",
#                 "Longitude": -79.232467,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00352",
#                 "PrevStopCode": "00965",
#                 "RouteNumber": "71   ",
#                 "StartTime": "09:13",
#                 "TripNumber": "71241",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 38.0,
#                 "DelaySeconds": 40,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "10:38",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.872033,
#                 "LineCode": "71",
#                 "Longitude": -79.287983,
#                 "ModifiedDate": "2023-08-07 10:25:59",
#                 "NextStopCode": "02111",
#                 "PrevStopCode": "00125",
#                 "RouteNumber": "71E  ",
#                 "StartTime": "09:43",
#                 "TripNumber": "71271",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 87.0,
#                 "DelaySeconds": 188,
#                 "Display": "71C - Old Elm GO",
#                 "EndTime": "11:33",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00352",
#                 "Latitude": 43.69785,
#                 "LineCode": "71",
#                 "Longitude": -79.3496,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00128",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "71C  ",
#                 "StartTime": "10:13",
#                 "TripNumber": "71281",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 173.0,
#                 "DelaySeconds": -247,
#                 "Display": "71C - Union Station",
#                 "EndTime": "10:45",
#                 "FirstStopCode": "00352",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.731033,
#                 "LineCode": "71",
#                 "Longitude": -79.331,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02141",
#                 "RouteNumber": "71C  ",
#                 "StartTime": "09:30",
#                 "TripNumber": "71300",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": "02144",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "11:38",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.644167,
#                 "LineCode": "71",
#                 "Longitude": -79.377817,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71E  ",
#                 "StartTime": "10:43",
#                 "TripNumber": "71311",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02110",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 3,
#                 "Display": "71  - Union Station",
#                 "EndTime": "11:20",
#                 "FirstStopCode": "00302",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.8825,
#                 "LineCode": "71",
#                 "Longitude": -79.261917,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02110",
#                 "PrevStopCode": "02113",
#                 "RouteNumber": "71   ",
#                 "StartTime": "09:35",
#                 "TripNumber": "71320",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": "00974",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "71C - Union Station",
#                 "EndTime": "12:20",
#                 "FirstStopCode": "00352",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.994833,
#                 "LineCode": "71",
#                 "Longitude": -79.233717,
#                 "ModifiedDate": "2023-08-07 10:14:18",
#                 "NextStopCode": "00974",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71C  ",
#                 "StartTime": "10:55",
#                 "TripNumber": "71360",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 215.0,
#                 "DelaySeconds": 194,
#                 "Display": "88  - DC Oshawa GO",
#                 "EndTime": "11:19",
#                 "FirstStopCode": "02501",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 44.100717,
#                 "LineCode": "88",
#                 "Longitude": -78.574633,
#                 "ModifiedDate": "2023-08-07 10:24:59",
#                 "NextStopCode": "02162",
#                 "PrevStopCode": "02504",
#                 "RouteNumber": "88   ",
#                 "StartTime": "09:34",
#                 "TripNumber": "88261",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": "02502",
#                 "BusType": "Coach",
#                 "Course": 179.0,
#                 "DelaySeconds": 0,
#                 "Display": "88  - DC Oshawa GO",
#                 "EndTime": "12:19",
#                 "FirstStopCode": "02501",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 44.357,
#                 "LineCode": "88",
#                 "Longitude": -78.287033,
#                 "ModifiedDate": "2023-08-07 10:23:39",
#                 "NextStopCode": "02502",
#                 "PrevStopCode": null,
#                 "RouteNumber": "88   ",
#                 "StartTime": "10:34",
#                 "TripNumber": "88281",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 99.0,
#                 "DelaySeconds": 191,
#                 "Display": "88  - Trent U",
#                 "EndTime": "11:43",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02501",
#                 "Latitude": 43.9112,
#                 "LineCode": "88",
#                 "Longitude": -78.658717,
#                 "ModifiedDate": "2023-08-07 10:25:39",
#                 "NextStopCode": "00539",
#                 "PrevStopCode": "00529",
#                 "RouteNumber": "88   ",
#                 "StartTime": "09:58",
#                 "TripNumber": "88380",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "00155",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "88  - Trent U",
#                 "EndTime": "12:48",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "02501",
#                 "Latitude": 43.870683,
#                 "LineCode": "88",
#                 "Longitude": -78.886217,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00155",
#                 "PrevStopCode": null,
#                 "RouteNumber": "88   ",
#                 "StartTime": "10:58",
#                 "TripNumber": "88430",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 62,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "10:55",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.775433,
#                 "LineCode": "92",
#                 "Longitude": -79.262917,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "01657",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "92   ",
#                 "StartTime": "09:20",
#                 "TripNumber": "92260",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 55.0,
#                 "DelaySeconds": 28,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "11:15",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.802817,
#                 "LineCode": "92",
#                 "Longitude": -79.13985,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00634",
#                 "PrevStopCode": "00170",
#                 "RouteNumber": "92   ",
#                 "StartTime": "09:50",
#                 "TripNumber": "92271",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 341.0,
#                 "DelaySeconds": 98,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "11:55",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.890617,
#                 "LineCode": "92",
#                 "Longitude": -78.8604,
#                 "ModifiedDate": "2023-08-07 10:25:39",
#                 "NextStopCode": "00166",
#                 "PrevStopCode": "00159",
#                 "RouteNumber": "92   ",
#                 "StartTime": "10:15",
#                 "TripNumber": "92300",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -235,
#                 "Display": "94  - Square One",
#                 "EndTime": "10:55",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.682817,
#                 "LineCode": "94",
#                 "Longitude": -79.613617,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": "00311",
#                 "RouteNumber": "94   ",
#                 "StartTime": "09:25",
#                 "TripNumber": "94250",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00147",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -228,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "10:50",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": false,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.775233,
#                 "LineCode": "94",
#                 "Longitude": -79.2611,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00147",
#                 "PrevStopCode": "01647",
#                 "RouteNumber": "94   ",
#                 "StartTime": "09:20",
#                 "TripNumber": "94251",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00723",
#                 "BusType": "Coach",
#                 "Course": 203.0,
#                 "DelaySeconds": 66,
#                 "Display": "94  - Square One",
#                 "EndTime": "12:00",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.830817,
#                 "LineCode": "94",
#                 "Longitude": -79.0849,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "00723",
#                 "PrevStopCode": null,
#                 "RouteNumber": "94   ",
#                 "StartTime": "10:25",
#                 "TripNumber": "94290",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 43.0,
#                 "DelaySeconds": 32,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "11:50",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.623467,
#                 "LineCode": "94",
#                 "Longitude": -79.621583,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02661",
#                 "PrevStopCode": "00132",
#                 "RouteNumber": "94   ",
#                 "StartTime": "10:20",
#                 "TripNumber": "94291",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 252.0,
#                 "DelaySeconds": 182,
#                 "Display": "96Z - Finch Terminal",
#                 "EndTime": "10:45",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.77375,
#                 "LineCode": "96",
#                 "Longitude": -79.291083,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02772",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "96Z  ",
#                 "StartTime": "09:30",
#                 "TripNumber": "96260",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 72.0,
#                 "DelaySeconds": -574,
#                 "Display": "96Z - DC Oshawa GO",
#                 "EndTime": "11:25",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.774767,
#                 "LineCode": "96",
#                 "Longitude": -79.2841,
#                 "ModifiedDate": "2023-08-07 10:26:19",
#                 "NextStopCode": "02776",
#                 "PrevStopCode": "01647",
#                 "RouteNumber": "96Z  ",
#                 "StartTime": "10:10",
#                 "TripNumber": "96281",
#                 "VariantDir": "E"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
trip_updates='api/V1/UP/Gtfs/Feed/TripUpdates'
try:
    trip_data = get_data(trip_updates)
    # Print the JSON response (pretty printed)
    print(json.dumps(trip_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trip_updates_collection = db['buses']
    trip_updates_collection.insert_one(trip_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230807-4013",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 118,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 53,
#                             "time": 1691418353,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1691418407,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:00:00",
#                     "trip_id": "20230807-4013"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230807-4113",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 70,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 59,
#                             "time": 1691418599,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 59,
#                             "time": 1691419259,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1691418407,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:15:00",
#                     "trip_id": "20230807-4113"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230807-4212",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 95,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 49,
#                             "time": 1691418589,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 49,
#                             "time": 1691419069,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1691418397,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:12:00",
#                     "trip_id": "20230807-4212"
#                 },
#                 "vehicle": {
#                     "id": "3002",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230807-4213",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691418600,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691419080,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691419440,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691420100,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1691418407,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:30:00",
#                     "trip_id": "20230807-4213"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230807-4312",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691418420,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691419080,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691419440,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691419920,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1691418407,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:27:00",
#                     "trip_id": "20230807-4312"
#                 },
#                 "vehicle": {
#                     "id": "3005",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1691418409
#     }
# }
# Data successfully inserted into MongoDB.

# %%
service_messages='api/V1/ServiceUpdate/ServiceAlert/All'
try:
    service_messages_data = get_data(service_messages)
    # Print the JSON response (pretty printed)
    print(json.dumps(service_messages_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    service_messages_collection = db['service_messages']
    service_messages_collection.insert_one(service_messages_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Messages": {
#         "Message": [
#             {
#                 "BodyEnglish": "The elevator connecting the main lobby to platforms 1 and 2 is out of service. The station remains accessible through the ramp in the bus terminal.",
#                 "BodyFrench": "L'ascenseur reliant le hall principal aux quais 1 et 2 est hors service. La gare reste accessible par la rampe de la station d'autobus.",
#                 "Category": "Amenity",
#                 "Code": "M0000383679",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-06-20 09:04:42",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "HA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting June 20, City of Brampton is expected to start construction at Bramalea Terminal by the Bramalea City Centre. As a result, a temporary new bus stop on Central Park Dr. @ Knightsbridge Rd. will be used until the terminal re-opens. Here\u2019s what you need to know: \u00b7 Construction is expected to last for six months. \u00b7 During the time of construction, the bus terminal building will remain open, and you will have access to washrooms. \u00b7 Please follow directional signs. \u00b7 The construction schedule may adjust due to weather conditions or unforeseen circumstances. We will keep you updated. Thank you for your patience and understanding. Please visit the City of Brampton for more information.",
#                 "BodyFrench": "\u00c0 compter 20 juin, la ville de Brampton devrait commencer des travaux de construction \u00e0 la station de Bramalea, \u00e0 c\u00f4t\u00e9 du Bramalea City Centre. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire situ\u00e9 \u00e0 l\u2019intersection de la promenade Central Park et du chemin Knightsbridge sera utilis\u00e9 jusqu\u2019\u00e0 ce que la station rouvre. Voici ce que vous devez savoir :\u00b7 Les travaux de construction devraient durer six mois. \u00b7 Durant ces travaux, l\u2019\u00e9difice de la station d\u2019autobus rester ouvert, et vous aurez acc\u00e8s aux toilettes. \u00b7 Veuillez suivre les panneaux de signalisation. \u00b7 Le calendrier de construction pourrait \u00eatre rajust\u00e9 en fonction des conditions m\u00e9t\u00e9orologiques ou de circonstances impr\u00e9vues. Nous vous tiendrons inform\u00e9s.Nous vous remercions de votre patience et de votre compr\u00e9hension. Veuillez visiter la ville de Brampton pour obtenir de plus amples renseignements.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000388353",
#                 "Lines": [
#                     {
#                         "Code": "32"
#                     },
#                     {
#                         "Code": "36"
#                     }
#                 ],
#                 "ParentCode": "M0000387619",
#                 "PostedDateTime": "2023-06-20 00:01:20",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Bramalea Bus Terminal temporary closure",
#                 "SubjectFrench": "Fermeture temporaire du terminal d\u2019autobus de Bramalea",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Construction continues in your bus loop. Here\u2019s what you need to know:\u2022 As of July 2, the Bronte GO bus loop will be closing, and all buses will operate out of the east parking lot.\u2022 The temporary bus stop in the east parking lot will be in use until approximately Mid-August.\u2022 Please be cautious near and around construction areas.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390213",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": "M0000389990",
#                 "PostedDateTime": "2023-07-01 10:03:28",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "BO",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "New temporary bus stops in the east lot",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Due to a construction project the southbound stop at Main Street and Baker Hill Boulevard will be missed and will also be moved back approximately 100 meters. Customers may board the bus at Main Street at Sandale Road. Please also note that the stop at Highway 48 and Hover Park will also be moved forward approximately 50 meters to provide better service during this time.",
#                 "BodyFrench": "En raison d'un projet de construction, l'arr\u00eat vers le sud de Main Street et Baker Hill Boulevard sera rat\u00e9 et sera \u00e9galement d\u00e9plac\u00e9 environ 100 m\u00e8tres. Les clients peuvent monter \u00e0 bord de l\u2019autobus sur la rue Main \u00e0 Sandale Road. Veuillez \u00e9galement noter que l\u2019arr\u00eat \u00e0 l\u2019autoroute 48 et \u00e0 Hover Park sera \u00e9galement avanc\u00e9 d\u2019environ 50 m\u00e8tres afin d\u2019offrir un meilleur service pendant cette p\u00e9riode.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000391018",
#                 "Lines": [
#                     {
#                         "Code": "70"
#                     },
#                     {
#                         "Code": "71"
#                     }
#                 ],
#                 "ParentCode": "M0000390922",
#                 "PostedDateTime": "2023-07-19 14:43:42",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified \u2013 Route 70 and 71",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the station building/bus loop/kiss & ride to the tunnel is out of service. Platforms are still accessible by using the pedestrian bridge. Visit the Pickering GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le b\u00e2timent de la gare, la ceinture de trafic pour autobus et le d\u00e9barcad\u00e8re au tunnel est hors service. Les quais sont toujours accessibles en empruntant la passerelle pour pi\u00e9tons. Visitez la page de la gare GO de Pickering pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392957",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-20 23:09:11",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "PIN",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Lane closures are scheduled on the Burlington Skyway Bridge in the evening on Friday August 11, and August 18, 2023. All westbound lanes heading toward Niagara will be closed by 10:00 p.m.Buses on your route will detour during this time and delays of up to 20 minutes can be expected. Lanes are scheduled to reopen the following Saturday morning by 10:00 a.m.",
#                 "BodyFrench": "Des fermetures de voies sont pr\u00e9vues sur le pont Skyway de Burlington dans la soir\u00e9e les vendredi 11 ao\u00fbt et 18 ao\u00fbt 2023. Toutes les voies vers l'ouest en direction de Niagara seront ferm\u00e9es d'ici 22 h.Les autobus de votre trajet feront un d\u00e9tour pendant cette p\u00e9riode et des retards allant jusqu'\u00e0 20 minutes peuvent \u00eatre pr\u00e9vus. Les voies doivent rouvrir le samedi matin suivant avant 10 h.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393308",
#                 "Lines": [
#                     {
#                         "Code": "12"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-28 14:59:06",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Burlington Skyway Bridge Project \u2013 Delays Expected",
#                 "SubjectFrench": "Projet du pont Skyway de Burlington - Retards pr\u00e9vus",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There are some rules in place to keep everyone safe and comfortable on the train. Learn everything you need to know about bringing a bike on the GO.",
#                 "BodyFrench": "Certaines r\u00e8gles sont en place pour que tout le monde reste en s\u00e9curit\u00e9 et confortable dans le train. Apprenez tout ce que vous avez besoin de savoir sur l'introduction d'un v\u00e9lo sur le GO.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393659",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": "M0000391811",
#                 "PostedDateTime": "2023-07-26 11:41:17",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Travelling with a bicycle?",
#                 "SubjectFrench": "Vous voyagez avec un v\u00e9lo ? \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the Finch Bus Terminal to the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator at the Kiss & Ride entrance on the northwest corner of Yonge St. at Hendon Ave. Visit the Finch GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie la station d\u2019autobus de la gare de Finch au tunnel de la TTC est hors service. Les passagers qui ont besoin de cet ascenseur pour acc\u00e9der au syst\u00e8me de la TTC sont invit\u00e9s \u00e0 utiliser l'ascenseur de la TTC situ\u00e9 \u00e0 l'entr\u00e9e de la zone de d\u00e9barcad\u00e8re, \u00e0 l'angle nord-ouest de Yonge St. et de Hendon Ave. Visitez la page de la gare GO de Finch pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393666",
#                 "Lines": [
#                     {
#                         "Code": "19"
#                     },
#                     {
#                         "Code": "27"
#                     },
#                     {
#                         "Code": "96"
#                     }
#                 ],
#                 "ParentCode": "M0000393657",
#                 "PostedDateTime": "2023-07-26 13:24:25",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "00013",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevators connecting the station to the tunnel (north side of platforms) as well as the tunnel to platform 2 and 3 are out of service. Customers who need these elevators should board the train at Scarborough GO or Union Station. An update will be provided as more information becomes available. Visit the Danforth GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "Les ascenseurs reliant la gare au tunnel (c\u00f4t\u00e9 nord des quais) ainsi que le tunnel aux quais 2 et 3 sont hors service. Les clients qui ont besoin de ces ascenseurs doivent monter \u00e0 bord du train \u00e0 la GO ou \u00e0 la Gare Union de Scarborough. La gare reste accessible depuis le tunnel ouest dans les stationnements sud et nord. Visitez la page de la gare Danforth GO pour trouver des informations utiles sur les d\u00e9parts, un plan de la gare et une liste de tous les services que nous proposons. Consultez notre page sur l'accessibilit\u00e9 pour d\u00e9couvrir comment nous nous engageons \u00e0 rendre nos services faciles \u00e0 utiliser pour tous.",
#                 "Category": "Amenity",
#                 "Code": "M0000394107",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": "M0000393930",
#                 "PostedDateTime": "2023-07-30 13:19:35",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "DA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting July 31st, the City of Brampton begins construction by Brampton Shopper's World. As a result, a new temporary bus stop will be located on Main Street and Charolais Boulevard for westbound trips. An update will be provided when this stop is back in service.",
#                 "BodyFrench": "\u00c0 partir du 31 juillet, la ville de Brampton commence la construction par Brampton Shopper's World. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire sera situ\u00e9 sur la rue Main et le boulevard Charolais pour les trajets en direction ouest. Une mise \u00e0 jour sera fournie lorsque cet arr\u00eat sera de nouveau en service.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000394202",
#                 "Lines": [
#                     {
#                         "Code": "31"
#                     },
#                     {
#                         "Code": "33"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-31 14:35:27",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified - Route 31 and 33",
#                 "SubjectFrench": "Trajet d'autobus modifi\u00e9 - Trajets 31 et 33 \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Work is underway on the Bloor Street Rail Bridge, resulting in traffic impacts on Bloor Street West. Please follow all directional signs and use caution when walking near construction areas. There is no impact to train service. Until August 11, the Bloor St. entrance to the GO station is closed. Please access the station via Ernest Ave. or the Dundas St. Pick-up/drop-off area. Visit the Bloor GO Station Improvement webpage to learn more.",
#                 "BodyFrench": "Des travaux sont en cours sur le pont ferroviaire de la rue Bloor, ce qui a des incidences sur la circulation sur la rue Bloor Ouest. Veuillez suivre tous les panneaux de signalisation et faire preuve de prudence en marchant pr\u00e8s des zones de construction. Le service de train ne sera pas touch\u00e9 durant ces travaux. L\u2019entr\u00e9e de la gare GO \u00e0 la rue Bloor sera ferm\u00e9e jusqu\u2019au 11 ao\u00fbt. Veuillez acc\u00e9der \u00e0 la gare par l\u2019avenue Ernest ou la zone de d\u00e9barcad\u00e8re de la rue Dundas. Allez \u00e0 la page Web Am\u00e9lioration de la gare GO de Bloor pour en savoir plus.",
#                 "Category": "UP Express Station Messages",
#                 "Code": "M0000394356",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-05 00:01:22",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BL",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "UP Station Disruption WEB",
#                 "SubjectEnglish": "Bloor Street West Rail Bridge Shift",
#                 "SubjectFrench": "D\u00e9placement du pont ferroviaire de la rue Bloor Ouest",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platforms 2 and 3 is out of service. Customers who need this elevator should board the train at Appleby or Aldershot. Visit the Burlington GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel aux quais 2 et 3 est hors service. Les passagers qui ont besoin de cet ascenseur doivent prendre le train \u00e0 Appleby ou \u00e0 Aldershot. Visitez la page de la gare GO de Burlington pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000394533",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-02 11:27:31",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BU",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the GO platform and the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator on Transway Crescent, adjacent to the south parking lot. Visit the Kennedy GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000394601",
#                 "Lines": [
#                     {
#                         "Code": "ST"
#                     }
#                 ],
#                 "ParentCode": "M0000390000",
#                 "PostedDateTime": "2023-08-02 23:04:06",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "KE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platforms 1 and 2 is out of service. Customers who need this elevator should board the train at Erindale GO or Meadowvale GO. Visit the Streetsville GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000394624",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000392979",
#                 "PostedDateTime": "2023-08-03 01:28:58",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "SR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le tunnel Est aux quais 1 et 2 est hors service. La gare reste accessible par l\u2019ascenseur du tunnel ouest. Visitez la page de la gare GO de Weston pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000394640",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-03 05:35:06",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "WE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service ",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "Category": "Amenity",
#                 "Code": "M0000394641",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-03 05:41:12",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "WE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "A temporary schedule change is in effect due to track work that requires trains to travel slower in some areas. Check updated schedules here. If you are connecting with local transit from Milton GO station, check connection times using triplinx.ca. Thank you for your patience during this important work.",
#                 "BodyFrench": "Un changement temporaire \u00e0 l\u2019horaire est en vigueur en raison de travaux sur la voie qui n\u00e9cessitent une r\u00e9duction de la vitesse des trains dans certains secteurs. Consultez les horaires mis \u00e0 jour ici. Si vous avez une correspondance avec le transport en commun local \u00e0 partir de la gare GO de Milton, consultez les heures de correspondance sur triplinx.ca. Nous vous remercions de votre patience pendant que nous effectuons ces travaux importants.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000394811",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000393486",
#                 "PostedDateTime": "2023-08-04 12:43:15",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Temporary schedule change on Milton Line",
#                 "SubjectFrench": "Changement temporaire \u00e0 l\u2019horaire de la ligne Milton",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Work is underway on the Bloor Street Rail Bridge, resulting in traffic impacts on Bloor Street West. Please follow all directional signs and use caution when walking near construction areas. There is no impact to train service. From August 12-18, the Bloor St. entrance to the GO station will be closed. Please access the station via Ernest Ave. or the Dundas St. Pick-up/drop-off area. Visit the Bloor GO Station Improvement webpage to learn more.",
#                 "BodyFrench": "Des travaux sont en cours sur le pont ferroviaire de la rue Bloor, ce qui a des incidences sur la circulation sur la rue Bloor Ouest. Veuillez suivre tous les panneaux de signalisation et faire preuve de prudence en marchant pr\u00e8s des zones de construction. Le service de train ne sera pas touch\u00e9 durant ces travaux. Du 12 au 18 ao\u00fbt, l\u2019entr\u00e9e de la gare GO sur la rue Bloor sera ferm\u00e9e. Veuillez acc\u00e9der \u00e0 la gare par l\u2019avenue Ernest ou la zone de d\u00e9barcad\u00e8re de la rue Dundas. Allez \u00e0 la page Web Am\u00e9lioration de la gare GO de Bloor pour en savoir plus.",
#                 "Category": "UP Express Station Messages",
#                 "Code": "M0000394827",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-04 14:31:33",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BL",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "UP Station Disruption WEB",
#                 "SubjectEnglish": " UP - Bloor Street West Rail Bridge Shift",
#                 "SubjectFrench": "D\u00e9placement du pont ferroviaire de la rue Bloor Ouest",
#                 "Trips": []
#             }
#         ]
#     },
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-07 10:26:53"
#     }
# }
# Data successfully inserted into MongoDB.

# %%
vechile_position='api/V1/UP/Gtfs/Feed/VehiclePosition'
try:
    vechile_position_data = get_data(vechile_position)
    # Print the JSON response (pretty printed)
    print(json.dumps(vechile_position_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    vechile_position_collection = db['service_messages']
    vechile_position_collection.insert_one(vechile_position_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230807-4013",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.683548,
#                     "longitude": -79.6139755,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1691418412,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:00:00",
#                     "trip_id": "20230807-4013"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230807-4113",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6885757,
#                     "longitude": -79.48963,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1691418412,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:15:00",
#                     "trip_id": "20230807-4113"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230807-4212",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6897621,
#                     "longitude": -79.4922256,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "BL",
#                 "timestamp": 1691418397,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:12:00",
#                     "trip_id": "20230807-4212"
#                 },
#                 "vehicle": {
#                     "id": "3002",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230807-4213",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.64437,
#                     "longitude": -79.3829346,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "UN",
#                 "timestamp": 1691418411,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:30:00",
#                     "trip_id": "20230807-4213"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230807-4312",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6829224,
#                     "longitude": -79.61338,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1691418412,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230807",
#                     "start_time": "10:27:00",
#                     "trip_id": "20230807-4312"
#                 },
#                 "vehicle": {
#                     "id": "3005",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1691418413
#     }
# }
# Data successfully inserted into MongoDB.

# %%
train_cancelled='api/V1/ServiceUpdate/Exceptions/Train'
try:
    train_cancelled_data = get_data(train_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    train_cancelled_collection = db['train_cancelled']
    train_cancelled_collection.insert_one(train_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-07 10:26:54"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E629Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E629K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LI",
#                     "ID": "727",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Old Elm GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E629B"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E629C"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.

# %%
bus_cancelled='api/V1/ServiceUpdate/Exceptions/Bus'
try:
    bus_cancelled_data = get_data(bus_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(bus_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    bus_cancelled_collection = db['bus_cancelled']
    bus_cancelled_collection.insert_one(bus_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "204",
#         "ErrorMessage": "No Content",
#         "TimeStamp": "2023-08-07 10:26:55"
#     },
#     "Trip": []
# }
# Data successfully inserted into MongoDB.

# %%
all_cancelled='api/V1/ServiceUpdate/Exceptions/All'
try:
    all_cancelled_data = get_data(all_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(all_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    all_cancelled_collection = db['all_cancelled']
    all_cancelled_collection.insert_one(all_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-07 10:26:56"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E629Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E629K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LI",
#                     "ID": "727",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Old Elm GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E629B"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E629C"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'covid_db', 'local', 'metrolinx']

# %%
# assign the met database to a variable name
db = mongo['metrolinx']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['bus_cancelled', 'service_messages', 'trains', 'buses', 'all_cancelled', 'train_cancelled']

# %%
# review a document in the artifacts collection
pprint(db.trains.find_one())
# Out:
# {'Metadata': {'ErrorCode': '200',
#               'ErrorMessage': 'OK',
#               'TimeStamp': '2023-07-26 23:18:19'},
#  'Trips': {'Trip': [{'AtStationCode': 'OSBO',
#                      'Cars': '12',
#                      'Course': 229.0,
#                      'DelaySeconds': 255,
#                      'Display': 'LW - Aldershot GO',
#                      'EndTime': '23:22',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': False,
#                      'LastStopCode': 'AL',
#                      'Latitude': 43.342057,
#                      'LineCode': 'LW',
#                      'Longitude': -79.807834,
#                      'ModifiedDate': '2023-07-26 23:18:16',
#                      'NextStopCode': 'OSBO',
#                      'PrevStopCode': 'BU',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '22:13',
#                      'TripNumber': '1037',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': None,
#                      'Cars': '12',
#                      'Course': 259.0,
#                      'DelaySeconds': 122,
#                      'Display': 'LW - Aldershot GO',
#                      'EndTime': '00:22',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'AL',
#                      'Latitude': 43.640613,
#                      'LineCode': 'LW',
#                      'Longitude': -79.398959,
#                      'ModifiedDate': '2023-07-26 23:18:12',
#                      'NextStopCode': 'BATH',
#                      'PrevStopCode': 'PORT',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '23:13',
#                      'TripNumber': '1039',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': None,
#                      'Cars': '12',
#                      'Course': 37.0,
#                      'DelaySeconds': 101,
#                      'Display': 'LW - Union Station',
#                      'EndTime': '00:01',
#                      'FirstStopCode': 'AL',
#                      'IsInMotion': True,
#                      'LastStopCode': 'UN',
#                      'Latitude': 43.452447,
#                      'LineCode': 'LW',
#                      'Longitude': -79.685025,
#                      'ModifiedDate': '2023-07-26 23:18:15',
#                      'NextStopCode': 'OA',
#                      'PrevStopCode': 'KERR',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '22:54',
#                      'TripNumber': '1040',
#                      'VariantDir': 'E'},
#                     {'AtStationCode': 'POCL',
#                      'Cars': '12',
#                      'Course': 219.0,
#                      'DelaySeconds': 192,
#                      'Display': 'LW - West Harbour GO',
#                      'EndTime': '00:09',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'WR',
#                      'Latitude': 43.556853,
#                      'LineCode': 'LW',
#                      'Longitude': -79.586366,
#                      'ModifiedDate': '2023-07-26 23:18:13',
#                      'NextStopCode': 'POCL',
#                      'PrevStopCode': 'PO',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '22:47',
#                      'TripNumber': '1737',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': 'MIME',
#                      'Cars': '12',
#                      'Course': 48.0,
#                      'DelaySeconds': 255,
#                      'Display': 'LW - Union Station',
#                      'EndTime': '23:31',
#                      'FirstStopCode': 'WR',
#                      'IsInMotion': False,
#                      'LastStopCode': 'UN',
#                      'Latitude': 43.617813,
#                      'LineCode': 'LW',
#                      'Longitude': -79.495084,
#                      'ModifiedDate': '2023-07-26 23:18:16',
#                      'NextStopCode': 'MIME',
#                      'PrevStopCode': 'MI',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '22:13',
#                      'TripNumber': '1738',
#                      'VariantDir': 'E'},
#                     {'AtStationCode': 'BO',
#                      'Cars': '12',
#                      'Course': 217.0,
#                      'DelaySeconds': 59,
#                      'Display': 'LW - Niagara Falls GO (VIA Station)',
#                      'EndTime': '01:01',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'NI',
#                      'Latitude': 43.444226,
#                      'LineCode': 'LW',
#                      'Longitude': -79.693644,
#                      'ModifiedDate': '2023-07-26 23:18:13',
#                      'NextStopCode': 'BO',
#                      'PrevStopCode': 'KERR',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '22:40',
#                      'TripNumber': '1987',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': 'FORT',
#                      'Cars': '12',
#                      'Course': 0.0,
#                      'DelaySeconds': 187,
#                      'Display': 'LW - Union Station',
#                      'EndTime': '23:24',
#                      'FirstStopCode': 'NI',
#                      'IsInMotion': False,
#                      'LastStopCode': 'UN',
#                      'Latitude': 43.636358,
#                      'LineCode': 'LW',
#                      'Longitude': -79.417504,
#                      'ModifiedDate': '2023-07-26 23:18:08',
#                      'NextStopCode': 'FORT',
#                      'PrevStopCode': 'EX',
#                      'RouteNumber': 'LW   ',
#                      'StartTime': '21:10',
#                      'TripNumber': '1988',
#                      'VariantDir': 'E'},
#                     {'AtStationCode': 'KI',
#                      'Cars': '6',
#                      'Course': 244.0,
#                      'DelaySeconds': -225,
#                      'Display': 'GT - Kitchener GO',
#                      'EndTime': '23:21',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'KI',
#                      'Latitude': 43.45679,
#                      'LineCode': 'GT',
#                      'Longitude': -80.490142,
#                      'ModifiedDate': '2023-07-26 23:17:16',
#                      'NextStopCode': 'KI',
#                      'PrevStopCode': 'KICL',
#                      'RouteNumber': 'GT   ',
#                      'StartTime': '21:34',
#                      'TripNumber': '3935',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': None,
#                      'Cars': '6',
#                      'Course': 254.0,
#                      'DelaySeconds': 38,
#                      'Display': 'GT - Guelph Central GO',
#                      'EndTime': '00:01',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'GL',
#                      'Latitude': 43.685964,
#                      'LineCode': 'GT',
#                      'Longitude': -79.76872,
#                      'ModifiedDate': '2023-07-26 23:18:13',
#                      'NextStopCode': 'BOVA',
#                      'PrevStopCode': 'BRDI',
#                      'RouteNumber': 'GT   ',
#                      'StartTime': '22:34',
#                      'TripNumber': '3937',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': None,
#                      'Cars': '12',
#                      'Course': 72.0,
#                      'DelaySeconds': 60,
#                      'Display': 'LE - Durham College Oshawa GO',
#                      'EndTime': '00:06',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'OS',
#                      'Latitude': 43.687615,
#                      'LineCode': 'LE',
#                      'Longitude': -79.294708,
#                      'ModifiedDate': '2023-07-26 23:18:14',
#                      'NextStopCode': 'SCAJ',
#                      'PrevStopCode': 'DA',
#                      'RouteNumber': 'LE   ',
#                      'StartTime': '23:06',
#                      'TripNumber': '9038',
#                      'VariantDir': 'E'},
#                     {'AtStationCode': None,
#                      'Cars': '12',
#                      'Course': 252.0,
#                      'DelaySeconds': -6,
#                      'Display': 'LE - Union Station',
#                      'EndTime': '00:08',
#                      'FirstStopCode': 'OS',
#                      'IsInMotion': True,
#                      'LastStopCode': 'UN',
#                      'Latitude': 43.85062,
#                      'LineCode': 'LE',
#                      'Longitude': -79.031249,
#                      'ModifiedDate': '2023-07-26 23:18:16',
#                      'NextStopCode': 'HARW',
#                      'PrevStopCode': 'HENRCP',
#                      'RouteNumber': 'LE   ',
#                      'StartTime': '23:07',
#                      'TripNumber': '9041',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': 'AJ',
#                      'Cars': '12',
#                      'Course': 56.0,
#                      'DelaySeconds': 61,
#                      'Display': 'LE - Durham College Oshawa GO',
#                      'EndTime': '23:36',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'OS',
#                      'Latitude': 43.832515,
#                      'LineCode': 'LE',
#                      'Longitude': -79.082737,
#                      'ModifiedDate': '2023-07-26 23:18:01',
#                      'NextStopCode': 'AJ',
#                      'PrevStopCode': 'PIN',
#                      'RouteNumber': 'LE   ',
#                      'StartTime': '22:36',
#                      'TripNumber': '9236',
#                      'VariantDir': 'E'},
#                     {'AtStationCode': None,
#                      'Cars': '12',
#                      'Course': 205.0,
#                      'DelaySeconds': 74,
#                      'Display': 'LE - Union Station',
#                      'EndTime': '23:38',
#                      'FirstStopCode': 'OS',
#                      'IsInMotion': True,
#                      'LastStopCode': 'UN',
#                      'Latitude': 43.725094,
#                      'LineCode': 'LE',
#                      'Longitude': -79.249706,
#                      'ModifiedDate': '2023-07-26 23:18:13',
#                      'NextStopCode': 'SC',
#                      'PrevStopCode': 'EG',
#                      'RouteNumber': 'LE   ',
#                      'StartTime': '22:37',
#                      'TripNumber': '9239',
#                      'VariantDir': 'W'},
#                     {'AtStationCode': None,
#                      'Cars': '10',
#                      'Course': 268.0,
#                      'DelaySeconds': 139,
#                      'Display': 'GT - Mount Pleasant GO',
#                      'EndTime': '23:36',
#                      'FirstStopCode': 'UN',
#                      'IsInMotion': True,
#                      'LastStopCode': 'MO',
#                      'Latitude': 43.704769,
#                      'LineCode': 'GT',
#                      'Longitude': -79.643413,
#                      'ModifiedDate': '2023-07-26 23:18:08',
#                      'NextStopCode': 'AIRW',
#                      'PrevStopCode': 'MA',
#                      'RouteNumber': 'GT   ',
#                      'StartTime': '22:47',
#                      'TripNumber': 'X3539',
#                      'VariantDir': 'W'}]},
#  '_id': ObjectId('64c1e1fba696f046ef9beeb5')}

# %%
# assign the collection to a variable
bus_cancelled = db['bus_cancelled']
service_messages = db['service_messages']
trains = db['trains']
buses = db['buses']
all_cancelled = db['all_cancelled']
train_cancelled = db['train_cancelled']

# %% [markdown]
# # Explore the Collection

# %%
query = {
    'Trips.Trip': {'$exists': True},
    'Trips.Trip.DelaySeconds': {'$gt': 0}  # Filter trips where DelaySeconds > 0
}
fields = {
    '_id': 0,  # Exclude _id field
    'Trips.Trip.TripNumber': 1,
    'Trips.Trip.StartTime': 1,
    'Trips.Trip.EndTime': 1,
    'Trips.Trip.DelaySeconds': 1,
    'Trips.Trip.RouteNumber': 1,
    'Trips.Trip.FirstStopCode': 1
}

# Cast the results as a list and save the results to a variable
results = list(trains.find(query, fields))

# Pretty print the results
pprint(results)
# Out:
# [{'Trips': {'Trip': [{'DelaySeconds': 255,
#                       'EndTime': '23:22',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '22:13',
#                       'TripNumber': '1037'},
#                      {'DelaySeconds': 122,
#                       'EndTime': '00:22',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '23:13',
#                       'TripNumber': '1039'},
#                      {'DelaySeconds': 101,
#                       'EndTime': '00:01',
#                       'FirstStopCode': 'AL',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '22:54',
#                       'TripNumber': '1040'},
#                      {'DelaySeconds': 192,
#                       'EndTime': '00:09',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '22:47',
#                       'TripNumber': '1737'},
#                      {'DelaySeconds': 255,
#                       'EndTime': '23:31',
#                       'FirstStopCode': 'WR',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '22:13',
#                       'TripNumber': '1738'},
#                      {'DelaySeconds': 59,
#                       'EndTime': '01:01',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '22:40',
#                       'TripNumber': '1987'},
#                      {'DelaySeconds': 187,
#                       'EndTime': '23:24',
#                       'FirstStopCode': 'NI',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '21:10',
#                       'TripNumber': '1988'},
#                      {'DelaySeconds': -225,
#                       'EndTime': '23:21',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '21:34',
#                       'TripNumber': '3935'},
#                      {'DelaySeconds': 38,
#                       'EndTime': '00:01',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '22:34',
#                       'TripNumber': '3937'},
#                      {'DelaySeconds': 60,
#                       'EndTime': '00:06',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '23:06',
#                       'TripNumber': '9038'},
#                      {'DelaySeconds': -6,
#                       'EndTime': '00:08',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '23:07',
#                       'TripNumber': '9041'},
#                      {'DelaySeconds': 61,
#                       'EndTime': '23:36',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '22:36',
#                       'TripNumber': '9236'},
#                      {'DelaySeconds': 74,
#                       'EndTime': '23:38',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '22:37',
#                       'TripNumber': '9239'},
#                      {'DelaySeconds': 139,
#                       'EndTime': '23:36',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '22:47',
#                       'TripNumber': 'X3539'}]}},
#  {'Trips': {'Trip': [{'DelaySeconds': 90,
#                       'EndTime': '15:22',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '14:14',
#                       'TripNumber': '1021'},
#                      {'DelaySeconds': 90,
#                       'EndTime': '15:15',
#                       'FirstStopCode': 'AL',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '14:04',
#                       'TripNumber': '1022'},
#                      {'DelaySeconds': -1215,
#                       'EndTime': '16:15',
#                       'FirstStopCode': 'AL',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '15:04',
#                       'TripNumber': '1024'},
#                      {'DelaySeconds': 62,
#                       'EndTime': '15:05',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '13:44',
#                       'TripNumber': '1719'},
#                      {'DelaySeconds': -202,
#                       'EndTime': '14:45',
#                       'FirstStopCode': 'WR',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '13:23',
#                       'TripNumber': '1720'},
#                      {'DelaySeconds': -13,
#                       'EndTime': '16:05',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '14:44',
#                       'TripNumber': '1721'},
#                      {'DelaySeconds': 39,
#                       'EndTime': '15:45',
#                       'FirstStopCode': 'WR',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '14:23',
#                       'TripNumber': '1722'},
#                      {'DelaySeconds': -2,
#                       'EndTime': '15:21',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '13:03',
#                       'TripNumber': '1969'},
#                      {'DelaySeconds': -312,
#                       'EndTime': '15:36',
#                       'FirstStopCode': 'MO',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '14:49',
#                       'TripNumber': '3422'},
#                      {'DelaySeconds': -441,
#                       'EndTime': '15:39',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '14:51',
#                       'TripNumber': '3521'},
#                      {'DelaySeconds': -550,
#                       'EndTime': '16:37',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'BR   ',
#                       'StartTime': '14:53',
#                       'TripNumber': '6921'},
#                      {'DelaySeconds': 29,
#                       'EndTime': '15:48',
#                       'FirstStopCode': 'AD',
#                       'RouteNumber': 'BR   ',
#                       'StartTime': '14:06',
#                       'TripNumber': '6922'},
#                      {'DelaySeconds': 29,
#                       'EndTime': '15:20',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '14:20',
#                       'TripNumber': '9020'},
#                      {'DelaySeconds': -13,
#                       'EndTime': '15:09',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '14:04',
#                       'TripNumber': '9023'},
#                      {'DelaySeconds': 47,
#                       'EndTime': '14:50',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '13:50',
#                       'TripNumber': '9218'},
#                      {'DelaySeconds': -372,
#                       'EndTime': '15:50',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '14:50',
#                       'TripNumber': '9220'},
#                      {'DelaySeconds': 10,
#                       'EndTime': '15:39',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '14:34',
#                       'TripNumber': '9223'}]}},
#  {'Trips': {'Trip': [{'DelaySeconds': 70,
#                       'EndTime': '11:22',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '10:14',
#                       'TripNumber': '1013'},
#                      {'DelaySeconds': 149,
#                       'EndTime': '11:15',
#                       'FirstStopCode': 'AL',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '10:04',
#                       'TripNumber': '1014'},
#                      {'DelaySeconds': -2252,
#                       'EndTime': '12:15',
#                       'FirstStopCode': 'AL',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '11:04',
#                       'TripNumber': '1016'},
#                      {'DelaySeconds': 29,
#                       'EndTime': '11:05',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '09:44',
#                       'TripNumber': '1711'},
#                      {'DelaySeconds': -91,
#                       'EndTime': '10:45',
#                       'FirstStopCode': 'WR',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '09:23',
#                       'TripNumber': '1712'},
#                      {'DelaySeconds': 46,
#                       'EndTime': '11:45',
#                       'FirstStopCode': 'WR',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '10:23',
#                       'TripNumber': '1714'},
#                      {'DelaySeconds': 163,
#                       'EndTime': '11:24',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LW   ',
#                       'StartTime': '09:03',
#                       'TripNumber': '1961'},
#                      {'DelaySeconds': -231,
#                       'EndTime': '10:36',
#                       'FirstStopCode': 'MO',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '09:49',
#                       'TripNumber': '3412'},
#                      {'DelaySeconds': 43,
#                       'EndTime': '10:39',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'GT   ',
#                       'StartTime': '09:51',
#                       'TripNumber': '3511'},
#                      {'DelaySeconds': 26,
#                       'EndTime': '10:37',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'BR   ',
#                       'StartTime': '08:53',
#                       'TripNumber': '6909'},
#                      {'DelaySeconds': 26,
#                       'EndTime': '11:20',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '10:20',
#                       'TripNumber': '9012'},
#                      {'DelaySeconds': 48,
#                       'EndTime': '11:09',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '10:04',
#                       'TripNumber': '9015'},
#                      {'DelaySeconds': -4,
#                       'EndTime': '10:50',
#                       'FirstStopCode': 'UN',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '09:50',
#                       'TripNumber': '9210'},
#                      {'DelaySeconds': 33,
#                       'EndTime': '10:39',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '09:34',
#                       'TripNumber': '9213'},
#                      {'DelaySeconds': -453,
#                       'EndTime': '11:39',
#                       'FirstStopCode': 'OS',
#                       'RouteNumber': 'LE   ',
#                       'StartTime': '10:34',
#                       'TripNumber': '9215'}]}}]

# %%
aggregated_df = pd.json_normalize(results)
aggregated_df.head()
# Out:
#                                           Trips.Trip
# 0  [{'TripNumber': '1037', 'StartTime': '22:13', ...
# 1  [{'TripNumber': '1021', 'StartTime': '14:14', ...
# 2  [{'TripNumber': '1013', 'StartTime': '10:14', ...

# %%
# Create a new DataFrame to store the separated data
new_data = []

for index, row in aggregated_df.iterrows():
    for trip in row['Trips.Trip']:
        new_item = {'Index': index}
        new_item.update(trip)
        new_data.append(new_item)

new_df = pd.DataFrame(new_data)
new_df.head(50)
# Out:
#     Index TripNumber StartTime EndTime RouteNumber  DelaySeconds FirstStopCode
# 0       0       1037     22:13   23:22       LW              255            UN
# 1       0       1039     23:13   00:22       LW              122            UN
# 2       0       1040     22:54   00:01       LW              101            AL
# 3       0       1737     22:47   00:09       LW              192            UN
# 4       0       1738     22:13   23:31       LW              255            WR
# 5       0       1987     22:40   01:01       LW               59            UN
# 6       0       1988     21:10   23:24       LW              187            NI
# 7       0       3935     21:34   23:21       GT             -225            UN
# 8       0       3937     22:34   00:01       GT               38            UN
# 9       0       9038     23:06   00:06       LE               60            UN
# 10      0       9041     23:07   00:08       LE               -6            OS
# 11      0       9236     22:36   23:36       LE               61            UN
# 12      0       9239     22:37   23:38       LE               74            OS
# 13      0      X3539     22:47   23:36       GT              139            UN
# 14      1       1021     14:14   15:22       LW               90            UN
# 15      1       1022     14:04   15:15       LW               90            AL
# 16      1       1024     15:04   16:15       LW            -1215            AL
# 17      1       1719     13:44   15:05       LW               62            UN
# 18      1       1720     13:23   14:45       LW             -202            WR
# 19      1       1721     14:44   16:05       LW              -13            UN
# 20      1       1722     14:23   15:45       LW               39            WR
# 21      1       1969     13:03   15:21       LW               -2            UN
# 22      1       3422     14:49   15:36       GT             -312            MO
# 23      1       3521     14:51   15:39       GT             -441            UN
# 24      1       6921     14:53   16:37       BR             -550            UN
# 25      1       6922     14:06   15:48       BR               29            AD
# 26      1       9020     14:20   15:20       LE               29            UN
# 27      1       9023     14:04   15:09       LE              -13            OS
# 28      1       9218     13:50   14:50       LE               47            UN
# 29      1       9220     14:50   15:50       LE             -372            UN
# 30      1       9223     14:34   15:39       LE               10            OS
# 31      2       1013     10:14   11:22       LW               70            UN
# 32      2       1014     10:04   11:15       LW              149            AL
# 33      2       1016     11:04   12:15       LW            -2252            AL
# 34      2       1711     09:44   11:05       LW               29            UN
# 35      2       1712     09:23   10:45       LW              -91            WR
# 36      2       1714     10:23   11:45       LW               46            WR
# 37      2       1961     09:03   11:24       LW              163            UN
# 38      2       3412     09:49   10:36       GT             -231            MO
# 39      2       3511     09:51   10:39       GT               43            UN
# 40      2       6909     08:53   10:37       BR               26            UN
# 41      2       9012     10:20   11:20       LE               26            UN
# 42      2       9015     10:04   11:09       LE               48            OS
# 43      2       9210     09:50   10:50       LE               -4            UN
# 44      2       9213     09:34   10:39       LE               33            OS
# 45      2       9215     10:34   11:39       LE             -453            OS

# %%
new_csv_file_path = 'trains.csv'
new_df.to_csv(new_csv_file_path, index=False)
