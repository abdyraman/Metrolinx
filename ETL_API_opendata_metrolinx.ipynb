# %%
# Dependencies
from pymongo import MongoClient
import requests
import json
from pprint import pprint

# %%
# Import the API key
from config import key

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the met database to a variable name
db = mongo['metrolinx']
# assign the collection to a variable
trains = db['trains']
buses=db['buses']
trip_updates=db['trip_updates']
service_messages=db['service_messages']
vechile_position=db['vechile_position']
train_cancelled=db['train_cancelled']
bus_cancelled=db['bus_cancelled']
all_cancelled=db['all_cancelled']

# %%
def get_data(trains_endpoint):
    base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'
    params = {
    "key": key
}

    # Run request
    response = requests.get(f"{base_url}{trains_endpoint}", params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Return the JSON response
        return response.json()
    else:
        # Raise an exception with the status code if the request failed
        response.raise_for_status()

# %%
trains_endpoint = "api/V1/ServiceataGlance/Trains/All"

try:
    train_data = get_data(trains_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trains_collection = db['trains']
    trains_collection.insert_one(train_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:19"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": "OSBO",
#                 "Cars": "12",
#                 "Course": 229.0,
#                 "DelaySeconds": 255,
#                 "Display": "LW - Aldershot GO",
#                 "EndTime": "23:22",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "AL",
#                 "Latitude": 43.342057,
#                 "LineCode": "LW",
#                 "Longitude": -79.807834,
#                 "ModifiedDate": "2023-07-26 23:18:16",
#                 "NextStopCode": "OSBO",
#                 "PrevStopCode": "BU",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:13",
#                 "TripNumber": "1037",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 259.0,
#                 "DelaySeconds": 122,
#                 "Display": "LW - Aldershot GO",
#                 "EndTime": "00:22",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "AL",
#                 "Latitude": 43.640613,
#                 "LineCode": "LW",
#                 "Longitude": -79.398959,
#                 "ModifiedDate": "2023-07-26 23:18:12",
#                 "NextStopCode": "BATH",
#                 "PrevStopCode": "PORT",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "23:13",
#                 "TripNumber": "1039",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 37.0,
#                 "DelaySeconds": 101,
#                 "Display": "LW - Union Station",
#                 "EndTime": "00:01",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.452447,
#                 "LineCode": "LW",
#                 "Longitude": -79.685025,
#                 "ModifiedDate": "2023-07-26 23:18:15",
#                 "NextStopCode": "OA",
#                 "PrevStopCode": "KERR",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:54",
#                 "TripNumber": "1040",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "POCL",
#                 "Cars": "12",
#                 "Course": 219.0,
#                 "DelaySeconds": 192,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "00:09",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.556853,
#                 "LineCode": "LW",
#                 "Longitude": -79.586366,
#                 "ModifiedDate": "2023-07-26 23:18:13",
#                 "NextStopCode": "POCL",
#                 "PrevStopCode": "PO",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:47",
#                 "TripNumber": "1737",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "MIME",
#                 "Cars": "12",
#                 "Course": 48.0,
#                 "DelaySeconds": 255,
#                 "Display": "LW - Union Station",
#                 "EndTime": "23:31",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.617813,
#                 "LineCode": "LW",
#                 "Longitude": -79.495084,
#                 "ModifiedDate": "2023-07-26 23:18:16",
#                 "NextStopCode": "MIME",
#                 "PrevStopCode": "MI",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:13",
#                 "TripNumber": "1738",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "BO",
#                 "Cars": "12",
#                 "Course": 217.0,
#                 "DelaySeconds": 59,
#                 "Display": "LW - Niagara Falls GO (VIA Station)",
#                 "EndTime": "01:01",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "NI",
#                 "Latitude": 43.444226,
#                 "LineCode": "LW",
#                 "Longitude": -79.693644,
#                 "ModifiedDate": "2023-07-26 23:18:13",
#                 "NextStopCode": "BO",
#                 "PrevStopCode": "KERR",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:40",
#                 "TripNumber": "1987",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "FORT",
#                 "Cars": "12",
#                 "Course": 0.0,
#                 "DelaySeconds": 187,
#                 "Display": "LW - Union Station",
#                 "EndTime": "23:24",
#                 "FirstStopCode": "NI",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.636358,
#                 "LineCode": "LW",
#                 "Longitude": -79.417504,
#                 "ModifiedDate": "2023-07-26 23:18:08",
#                 "NextStopCode": "FORT",
#                 "PrevStopCode": "EX",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "21:10",
#                 "TripNumber": "1988",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "KI",
#                 "Cars": "6",
#                 "Course": 244.0,
#                 "DelaySeconds": -225,
#                 "Display": "GT - Kitchener GO",
#                 "EndTime": "23:21",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "KI",
#                 "Latitude": 43.45679,
#                 "LineCode": "GT",
#                 "Longitude": -80.490142,
#                 "ModifiedDate": "2023-07-26 23:17:16",
#                 "NextStopCode": "KI",
#                 "PrevStopCode": "KICL",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "21:34",
#                 "TripNumber": "3935",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "6",
#                 "Course": 254.0,
#                 "DelaySeconds": 38,
#                 "Display": "GT - Guelph Central GO",
#                 "EndTime": "00:01",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "GL",
#                 "Latitude": 43.685964,
#                 "LineCode": "GT",
#                 "Longitude": -79.76872,
#                 "ModifiedDate": "2023-07-26 23:18:13",
#                 "NextStopCode": "BOVA",
#                 "PrevStopCode": "BRDI",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "22:34",
#                 "TripNumber": "3937",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 72.0,
#                 "DelaySeconds": 60,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "00:06",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.687615,
#                 "LineCode": "LE",
#                 "Longitude": -79.294708,
#                 "ModifiedDate": "2023-07-26 23:18:14",
#                 "NextStopCode": "SCAJ",
#                 "PrevStopCode": "DA",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "23:06",
#                 "TripNumber": "9038",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 252.0,
#                 "DelaySeconds": -6,
#                 "Display": "LE - Union Station",
#                 "EndTime": "00:08",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.85062,
#                 "LineCode": "LE",
#                 "Longitude": -79.031249,
#                 "ModifiedDate": "2023-07-26 23:18:16",
#                 "NextStopCode": "HARW",
#                 "PrevStopCode": "HENRCP",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "23:07",
#                 "TripNumber": "9041",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "AJ",
#                 "Cars": "12",
#                 "Course": 56.0,
#                 "DelaySeconds": 61,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "23:36",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.832515,
#                 "LineCode": "LE",
#                 "Longitude": -79.082737,
#                 "ModifiedDate": "2023-07-26 23:18:01",
#                 "NextStopCode": "AJ",
#                 "PrevStopCode": "PIN",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "22:36",
#                 "TripNumber": "9236",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 205.0,
#                 "DelaySeconds": 74,
#                 "Display": "LE - Union Station",
#                 "EndTime": "23:38",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.725094,
#                 "LineCode": "LE",
#                 "Longitude": -79.249706,
#                 "ModifiedDate": "2023-07-26 23:18:13",
#                 "NextStopCode": "SC",
#                 "PrevStopCode": "EG",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "22:37",
#                 "TripNumber": "9239",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "10",
#                 "Course": 268.0,
#                 "DelaySeconds": 139,
#                 "Display": "GT - Mount Pleasant GO",
#                 "EndTime": "23:36",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "MO",
#                 "Latitude": 43.704769,
#                 "LineCode": "GT",
#                 "Longitude": -79.643413,
#                 "ModifiedDate": "2023-07-26 23:18:08",
#                 "NextStopCode": "AIRW",
#                 "PrevStopCode": "MA",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "22:47",
#                 "TripNumber": "X3539",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
buses_endpoint='api/V1/ServiceataGlance/Buses/All'
try:
    buses_data = get_data(buses_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(buses_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    buses_collection = db['buses']
    buses_collection.insert_one(buses_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:19"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 174.0,
#                 "DelaySeconds": -38,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "23:19",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.108483,
#                 "LineCode": "12",
#                 "Longitude": -79.06345,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02404",
#                 "RouteNumber": "12   ",
#                 "StartTime": "21:39",
#                 "TripNumber": "12811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 109.0,
#                 "DelaySeconds": -124,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "00:19",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.211667,
#                 "LineCode": "12",
#                 "Longitude": -79.615017,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02621",
#                 "PrevStopCode": "02730",
#                 "RouteNumber": "12   ",
#                 "StartTime": "22:39",
#                 "TripNumber": "12841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 334.0,
#                 "DelaySeconds": -451,
#                 "Display": "12B - Burlington GO",
#                 "EndTime": "23:21",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": true,
#                 "LastStopCode": "00177",
#                 "Latitude": 43.33985,
#                 "LineCode": "12",
#                 "Longitude": -79.809533,
#                 "ModifiedDate": "2023-07-26 23:12:18",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00820",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "22:21",
#                 "TripNumber": "12860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00177",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "01:19",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": false,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.389467,
#                 "LineCode": "12",
#                 "Longitude": -79.829133,
#                 "ModifiedDate": "2023-07-26 23:16:57",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12   ",
#                 "StartTime": "23:39",
#                 "TripNumber": "12871",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 147,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "23:30",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.25905,
#                 "LineCode": "16",
#                 "Longitude": -79.9027,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01009",
#                 "PrevStopCode": "01010",
#                 "RouteNumber": "16   ",
#                 "StartTime": "22:30",
#                 "TripNumber": "16831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "00:25",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.644067,
#                 "LineCode": "16",
#                 "Longitude": -79.377733,
#                 "ModifiedDate": "2023-07-26 22:59:57",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "23:30",
#                 "TripNumber": "16861",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 78.0,
#                 "DelaySeconds": 151,
#                 "Display": "16  - Union Station",
#                 "EndTime": "23:55",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.3356,
#                 "LineCode": "16",
#                 "Longitude": -79.831517,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "23:00",
#                 "TripNumber": "16870",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "01:25",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.644067,
#                 "LineCode": "16",
#                 "Longitude": -79.377683,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "00:30",
#                 "TripNumber": "16891",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "18  - Hamilton GO",
#                 "EndTime": "23:44",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.312783,
#                 "LineCode": "18",
#                 "Longitude": -79.856417,
#                 "ModifiedDate": "2023-07-26 23:15:57",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "18   ",
#                 "StartTime": "23:27",
#                 "TripNumber": "18901",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 221.0,
#                 "DelaySeconds": 160,
#                 "Display": "19 - Square One",
#                 "EndTime": "23:35",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.707833,
#                 "LineCode": "19",
#                 "Longitude": -79.555317,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": "00020",
#                 "RouteNumber": "19   ",
#                 "StartTime": "22:50",
#                 "TripNumber": "19851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Square One",
#                 "EndTime": "00:35",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.782717,
#                 "LineCode": "19",
#                 "Longitude": -79.414383,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "23:50",
#                 "TripNumber": "19911",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02659",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Finch Terminal",
#                 "EndTime": "01:00",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.595017,
#                 "LineCode": "19",
#                 "Longitude": -79.64955,
#                 "ModifiedDate": "2023-07-26 23:14:57",
#                 "NextStopCode": "02659",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "00:15",
#                 "TripNumber": "19920",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 106.0,
#                 "DelaySeconds": 130,
#                 "Display": "21  - Union Station",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.5683,
#                 "LineCode": "21",
#                 "Longitude": -79.668317,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02739",
#                 "PrevStopCode": "01191",
#                 "RouteNumber": "21   ",
#                 "StartTime": "22:20",
#                 "TripNumber": "21830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00809",
#                 "BusType": "Coach",
#                 "Course": 145.0,
#                 "DelaySeconds": 173,
#                 "Display": "21A - Milton GO",
#                 "EndTime": "23:36",
#                 "FirstStopCode": "00137",
#                 "IsInMotion": true,
#                 "LastStopCode": "00194",
#                 "Latitude": 43.505833,
#                 "LineCode": "21",
#                 "Longitude": -79.744833,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00809",
#                 "PrevStopCode": "01435",
#                 "RouteNumber": "21A  ",
#                 "StartTime": "23:01",
#                 "TripNumber": "21851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": -12,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "23:45",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": true,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.576733,
#                 "LineCode": "21",
#                 "Longitude": -79.715733,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01436",
#                 "PrevStopCode": "01384",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "22:55",
#                 "TripNumber": "21853",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 212.0,
#                 "DelaySeconds": 73,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "23:19",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": true,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.575267,
#                 "LineCode": "21",
#                 "Longitude": -79.6647,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00189",
#                 "PrevStopCode": "02738",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "22:47",
#                 "TripNumber": "21855",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00891",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21  - Union Station",
#                 "EndTime": "01:05",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.524017,
#                 "LineCode": "21",
#                 "Longitude": -79.867683,
#                 "ModifiedDate": "2023-07-26 22:50:57",
#                 "NextStopCode": "00891",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21   ",
#                 "StartTime": "23:25",
#                 "TripNumber": "21860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00902",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21A - Milton GO",
#                 "EndTime": "00:06",
#                 "FirstStopCode": "00137",
#                 "IsInMotion": false,
#                 "LastStopCode": "00194",
#                 "Latitude": 43.4558,
#                 "LineCode": "21",
#                 "Longitude": -79.683133,
#                 "ModifiedDate": "2023-07-26 23:07:37",
#                 "NextStopCode": "00902",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21A  ",
#                 "StartTime": "23:31",
#                 "TripNumber": "21861",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01241",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21D - Lisgar GO",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": false,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.512917,
#                 "LineCode": "21",
#                 "Longitude": -79.6329,
#                 "ModifiedDate": "2023-07-26 23:17:17",
#                 "NextStopCode": "01241",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21D  ",
#                 "StartTime": "23:25",
#                 "TripNumber": "21863",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02751",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 48,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "23:49",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": false,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.55595,
#                 "LineCode": "21",
#                 "Longitude": -79.586683,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02751",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21C  ",
#                 "StartTime": "23:17",
#                 "TripNumber": "21865",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02751",
#                 "BusType": "Coach",
#                 "Course": 135.0,
#                 "DelaySeconds": 0,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "00:49",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": true,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.590933,
#                 "LineCode": "21",
#                 "Longitude": -79.63135,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02751",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21C  ",
#                 "StartTime": "00:17",
#                 "TripNumber": "21895",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 116,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.4739,
#                 "LineCode": "25",
#                 "Longitude": -80.531467,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02148",
#                 "RouteNumber": "25   ",
#                 "StartTime": "21:45",
#                 "TripNumber": "25801",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00337",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -8,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "00:20",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.527633,
#                 "LineCode": "25",
#                 "Longitude": -79.903983,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00337",
#                 "PrevStopCode": "02635",
#                 "RouteNumber": "25   ",
#                 "StartTime": "22:45",
#                 "TripNumber": "25841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02215",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "01:20",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.594833,
#                 "LineCode": "25",
#                 "Longitude": -79.649717,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25   ",
#                 "StartTime": "23:45",
#                 "TripNumber": "25871",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": -161,
#                 "Display": "25  - Square One",
#                 "EndTime": "00:10",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.458033,
#                 "LineCode": "25",
#                 "Longitude": -80.131417,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02636",
#                 "PrevStopCode": "00337",
#                 "RouteNumber": "25   ",
#                 "StartTime": "22:35",
#                 "TripNumber": "25890",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 61.0,
#                 "DelaySeconds": 341,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.620517,
#                 "LineCode": "27",
#                 "Longitude": -79.70775,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "00200",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "23:00",
#                 "TripNumber": "27850",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02660",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "23:35",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": false,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.635683,
#                 "LineCode": "29",
#                 "Longitude": -79.537717,
#                 "ModifiedDate": "2023-07-26 21:54:57",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "21:55",
#                 "TripNumber": "29831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 126.0,
#                 "DelaySeconds": 204,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "00:00",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": true,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.52875,
#                 "LineCode": "29",
#                 "Longitude": -79.7271,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02214",
#                 "PrevStopCode": "02151",
#                 "RouteNumber": "29   ",
#                 "StartTime": "22:20",
#                 "TripNumber": "29880",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02660",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "01:35",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": false,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.635717,
#                 "LineCode": "29",
#                 "Longitude": -79.53765,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "23:55",
#                 "TripNumber": "29891",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02153",
#                 "BusType": "Coach",
#                 "Course": 224.0,
#                 "DelaySeconds": 5065,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.702533,
#                 "LineCode": "30",
#                 "Longitude": -79.6889,
#                 "ModifiedDate": "2023-07-26 23:14:38",
#                 "NextStopCode": "02153",
#                 "PrevStopCode": null,
#                 "RouteNumber": "30   ",
#                 "StartTime": "21:50",
#                 "TripNumber": "30790",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 321.0,
#                 "DelaySeconds": 184,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "23:39",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.4411,
#                 "LineCode": "30",
#                 "Longitude": -80.463917,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02186",
#                 "PrevStopCode": "02205",
#                 "RouteNumber": "30   ",
#                 "StartTime": "22:19",
#                 "TripNumber": "30821",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02586",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "00:39",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.7022,
#                 "LineCode": "30",
#                 "Longitude": -79.689933,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02586",
#                 "PrevStopCode": null,
#                 "RouteNumber": "30   ",
#                 "StartTime": "23:19",
#                 "TripNumber": "30851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02586",
#                 "BusType": "Coach",
#                 "Course": 79.0,
#                 "DelaySeconds": 0,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "01:36",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.70215,
#                 "LineCode": "30",
#                 "Longitude": -79.6898,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02586",
#                 "PrevStopCode": null,
#                 "RouteNumber": "30   ",
#                 "StartTime": "00:16",
#                 "TripNumber": "30881",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 248.0,
#                 "DelaySeconds": 195,
#                 "Display": "31L - Bramalea GO",
#                 "EndTime": "23:51",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "02728",
#                 "Latitude": 43.63505,
#                 "LineCode": "31",
#                 "Longitude": -79.421583,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02728",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "31L  ",
#                 "StartTime": "23:11",
#                 "TripNumber": "31851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 39.0,
#                 "DelaySeconds": 276,
#                 "Display": "31E - Union Station",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "02413",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.67325,
#                 "LineCode": "31",
#                 "Longitude": -79.725133,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01459",
#                 "PrevStopCode": "00223",
#                 "RouteNumber": "31E  ",
#                 "StartTime": "22:30",
#                 "TripNumber": "31874",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02802",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "31E - Union Station",
#                 "EndTime": "01:00",
#                 "FirstStopCode": "02413",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.656117,
#                 "LineCode": "31",
#                 "Longitude": -79.918217,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02802",
#                 "PrevStopCode": null,
#                 "RouteNumber": "31E  ",
#                 "StartTime": "23:30",
#                 "TripNumber": "31880",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 130.0,
#                 "DelaySeconds": 150,
#                 "Display": "33A - York Mills Term",
#                 "EndTime": "23:55",
#                 "FirstStopCode": "00221",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.667467,
#                 "LineCode": "33",
#                 "Longitude": -79.735517,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00991",
#                 "PrevStopCode": "00223",
#                 "RouteNumber": "33A  ",
#                 "StartTime": "23:10",
#                 "TripNumber": "33850",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 316.0,
#                 "DelaySeconds": 384,
#                 "Display": "33 - U of Guelph",
#                 "EndTime": "00:45",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.67365,
#                 "LineCode": "33",
#                 "Longitude": -79.7434,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01306",
#                 "PrevStopCode": "01307",
#                 "RouteNumber": "33   ",
#                 "StartTime": "22:30",
#                 "TripNumber": "33861",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 129.0,
#                 "DelaySeconds": 86,
#                 "Display": "36B - Bramalea Term",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "02827",
#                 "Latitude": 43.719167,
#                 "LineCode": "36",
#                 "Longitude": -79.71985,
#                 "ModifiedDate": "2023-07-26 23:15:57",
#                 "NextStopCode": null,
#                 "PrevStopCode": "01184",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "22:25",
#                 "TripNumber": "36831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 170.0,
#                 "DelaySeconds": 113,
#                 "Display": "36B - York Mills Term",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "02827",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.745267,
#                 "LineCode": "36",
#                 "Longitude": -79.406967,
#                 "ModifiedDate": "2023-07-26 23:16:37",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00019",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "22:35",
#                 "TripNumber": "36840",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01657",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "36B - Bramalea Term",
#                 "EndTime": "00:10",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": false,
#                 "LastStopCode": "02827",
#                 "Latitude": 43.74535,
#                 "LineCode": "36",
#                 "Longitude": -79.407267,
#                 "ModifiedDate": "2023-07-26 23:17:17",
#                 "NextStopCode": "01657",
#                 "PrevStopCode": null,
#                 "RouteNumber": "36B  ",
#                 "StartTime": "23:25",
#                 "TripNumber": "36861",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01185",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "36B - York Mills Term",
#                 "EndTime": "00:15",
#                 "FirstStopCode": "02827",
#                 "IsInMotion": false,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.718033,
#                 "LineCode": "36",
#                 "Longitude": -79.717933,
#                 "ModifiedDate": "2023-07-26 23:17:17",
#                 "NextStopCode": "01185",
#                 "PrevStopCode": null,
#                 "RouteNumber": "36B  ",
#                 "StartTime": "23:35",
#                 "TripNumber": "36870",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": 628,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.663317,
#                 "LineCode": "40",
#                 "Longitude": -79.59085,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "00311",
#                 "PrevStopCode": "02661",
#                 "RouteNumber": "40   ",
#                 "StartTime": "22:10",
#                 "TripNumber": "40830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 98.0,
#                 "DelaySeconds": 102,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "00:00",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.505783,
#                 "LineCode": "40",
#                 "Longitude": -79.74465,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": "02163",
#                 "RouteNumber": "40   ",
#                 "StartTime": "22:05",
#                 "TripNumber": "40831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 294.0,
#                 "DelaySeconds": 235,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.260317,
#                 "LineCode": "40",
#                 "Longitude": -79.881667,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "01005",
#                 "PrevStopCode": "02759",
#                 "RouteNumber": "40   ",
#                 "StartTime": "23:10",
#                 "TripNumber": "40860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00311",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -28,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "00:55",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.782817,
#                 "LineCode": "40",
#                 "Longitude": -79.523533,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00311",
#                 "PrevStopCode": "02021",
#                 "RouteNumber": "40   ",
#                 "StartTime": "23:05",
#                 "TripNumber": "40861",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "01:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.25295,
#                 "LineCode": "40",
#                 "Longitude": -79.869383,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "40   ",
#                 "StartTime": "00:15",
#                 "TripNumber": "40890",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02021",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "01:50",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.839533,
#                 "LineCode": "40",
#                 "Longitude": -79.424933,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02021",
#                 "PrevStopCode": null,
#                 "RouteNumber": "40   ",
#                 "StartTime": "00:05",
#                 "TripNumber": "40891",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00727",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 6062,
#                 "Display": "41A - Square One",
#                 "EndTime": "21:45",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.594867,
#                 "LineCode": "41",
#                 "Longitude": -79.648183,
#                 "ModifiedDate": "2023-07-26 21:39:37",
#                 "NextStopCode": "00727",
#                 "PrevStopCode": null,
#                 "RouteNumber": "41A  ",
#                 "StartTime": "20:00",
#                 "TripNumber": "41743",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 106.0,
#                 "DelaySeconds": 86,
#                 "Display": "41 - Hamilton GO",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.258267,
#                 "LineCode": "41",
#                 "Longitude": -79.882367,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "01007",
#                 "PrevStopCode": "01011",
#                 "RouteNumber": "41   ",
#                 "StartTime": "20:10",
#                 "TripNumber": "41751",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -198,
#                 "Display": "41 - Pickering GO",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.77885,
#                 "LineCode": "41",
#                 "Longitude": -79.341333,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02816",
#                 "PrevStopCode": "02021",
#                 "RouteNumber": "41   ",
#                 "StartTime": "21:00",
#                 "TripNumber": "41780",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 220.0,
#                 "DelaySeconds": 189,
#                 "Display": "41 - Hamilton GO",
#                 "EndTime": "00:10",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.547867,
#                 "LineCode": "41",
#                 "Longitude": -79.704267,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00138",
#                 "PrevStopCode": "02215",
#                 "RouteNumber": "41   ",
#                 "StartTime": "21:10",
#                 "TripNumber": "41781",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 278.0,
#                 "DelaySeconds": 1027,
#                 "Display": "41 - Hamilton GO",
#                 "EndTime": "01:10",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.837317,
#                 "LineCode": "41",
#                 "Longitude": -79.396883,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00350",
#                 "PrevStopCode": "02757",
#                 "RouteNumber": "41   ",
#                 "StartTime": "22:10",
#                 "TripNumber": "41811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 314.0,
#                 "DelaySeconds": 93,
#                 "Display": "41 - Pickering GO",
#                 "EndTime": "01:00",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.599133,
#                 "LineCode": "41",
#                 "Longitude": -79.642133,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02673",
#                 "PrevStopCode": "00132",
#                 "RouteNumber": "41   ",
#                 "StartTime": "22:00",
#                 "TripNumber": "41820",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -263,
#                 "Display": "47  - Hwy. 407 Bus Term",
#                 "EndTime": "23:20",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.783167,
#                 "LineCode": "47",
#                 "Longitude": -79.5234,
#                 "ModifiedDate": "2023-07-26 23:15:38",
#                 "NextStopCode": null,
#                 "PrevStopCode": "08041",
#                 "RouteNumber": "47   ",
#                 "StartTime": "21:30",
#                 "TripNumber": "47860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00139",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 334,
#                 "Display": "47  - Hwy. 407 Bus Term",
#                 "EndTime": "00:45",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.261933,
#                 "LineCode": "47",
#                 "Longitude": -79.922617,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00139",
#                 "PrevStopCode": "02185",
#                 "RouteNumber": "47   ",
#                 "StartTime": "23:00",
#                 "TripNumber": "47910",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 217.0,
#                 "DelaySeconds": 2360,
#                 "Display": "48 - U of Guelph",
#                 "EndTime": "23:20",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.57145,
#                 "LineCode": "48",
#                 "Longitude": -79.829733,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02627",
#                 "PrevStopCode": "02508",
#                 "RouteNumber": "48   ",
#                 "StartTime": "21:45",
#                 "TripNumber": "48811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 235.0,
#                 "DelaySeconds": 205,
#                 "Display": "48 - U of Guelph",
#                 "EndTime": "00:20",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.6466,
#                 "LineCode": "48",
#                 "Longitude": -79.727917,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "01246",
#                 "PrevStopCode": "00354",
#                 "RouteNumber": "48   ",
#                 "StartTime": "22:45",
#                 "TripNumber": "48841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": 637,
#                 "Display": "48 - Hwy. 407 Bus Term",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.749967,
#                 "LineCode": "48",
#                 "Longitude": -79.641283,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": null,
#                 "PrevStopCode": "08041",
#                 "RouteNumber": "48   ",
#                 "StartTime": "21:55",
#                 "TripNumber": "48860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02728",
#                 "BusType": "Coach",
#                 "Course": 153.0,
#                 "DelaySeconds": -172,
#                 "Display": "48 - U of Guelph",
#                 "EndTime": "01:20",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.782883,
#                 "LineCode": "48",
#                 "Longitude": -79.523167,
#                 "ModifiedDate": "2023-07-26 23:17:17",
#                 "NextStopCode": "02728",
#                 "PrevStopCode": null,
#                 "RouteNumber": "48   ",
#                 "StartTime": "23:45",
#                 "TripNumber": "48871",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 69.0,
#                 "DelaySeconds": 149,
#                 "Display": "48 - Hwy. 407 Bus Term",
#                 "EndTime": "00:25",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.4708,
#                 "LineCode": "48",
#                 "Longitude": -80.065267,
#                 "ModifiedDate": "2023-07-26 23:16:18",
#                 "NextStopCode": "01198",
#                 "PrevStopCode": "00337",
#                 "RouteNumber": "48   ",
#                 "StartTime": "22:55",
#                 "TripNumber": "48890",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 74.0,
#                 "DelaySeconds": 5,
#                 "Display": "54 - Mount Joy GO",
#                 "EndTime": "23:55",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00121",
# ...
#                 "Latitude": 44.38625,
#                 "LineCode": "68",
#                 "Longitude": -79.69235,
#                 "ModifiedDate": "2023-07-26 23:16:38",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00359",
#                 "RouteNumber": "68   ",
#                 "StartTime": "21:23",
#                 "TripNumber": "68721",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02521",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "68 - Barrie Terminal",
#                 "EndTime": "23:43",
#                 "FirstStopCode": "00081",
#                 "IsInMotion": false,
#                 "LastStopCode": "02828",
#                 "Latitude": 43.999583,
#                 "LineCode": "68",
#                 "Longitude": -79.4592,
#                 "ModifiedDate": "2023-07-26 22:19:37",
#                 "NextStopCode": "02521",
#                 "PrevStopCode": null,
#                 "RouteNumber": "68   ",
#                 "StartTime": "22:23",
#                 "TripNumber": "68761",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 73.0,
#                 "DelaySeconds": 211,
#                 "Display": "71C - Old Elm GO",
#                 "EndTime": "23:23",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00352",
#                 "Latitude": 43.971183,
#                 "LineCode": "71",
#                 "Longitude": -79.247567,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02177",
#                 "PrevStopCode": "01925",
#                 "RouteNumber": "71C  ",
#                 "StartTime": "22:13",
#                 "TripNumber": "71821",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 352.0,
#                 "DelaySeconds": 476,
#                 "Display": "71  - Uxbridge",
#                 "EndTime": "23:48",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00302",
#                 "Latitude": 43.9087,
#                 "LineCode": "71",
#                 "Longitude": -79.26785,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00738",
#                 "PrevStopCode": "02575",
#                 "RouteNumber": "71   ",
#                 "StartTime": "22:18",
#                 "TripNumber": "71831",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 384,
#                 "Display": "71C - Union Station",
#                 "EndTime": "00:15",
#                 "FirstStopCode": "00352",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.956817,
#                 "LineCode": "71",
#                 "Longitude": -79.27905,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02190",
#                 "PrevStopCode": "02192",
#                 "RouteNumber": "71C  ",
#                 "StartTime": "23:05",
#                 "TripNumber": "71840",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 327.0,
#                 "DelaySeconds": -522,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "23:53",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.67085,
#                 "LineCode": "71",
#                 "Longitude": -79.358183,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00128",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "71E  ",
#                 "StartTime": "23:08",
#                 "TripNumber": "71851",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02144",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 283,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "23:58",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.644117,
#                 "LineCode": "71",
#                 "Longitude": -79.377817,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71E  ",
#                 "StartTime": "23:13",
#                 "TripNumber": "71861",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02144",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "71  - Uxbridge",
#                 "EndTime": "00:43",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00302",
#                 "Latitude": 43.64405,
#                 "LineCode": "71",
#                 "Longitude": -79.377683,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71   ",
#                 "StartTime": "23:18",
#                 "TripNumber": "71871",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02144",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "71C - Old Elm GO",
#                 "EndTime": "01:13",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00352",
#                 "Latitude": 43.644183,
#                 "LineCode": "71",
#                 "Longitude": -79.377833,
#                 "ModifiedDate": "2023-07-26 23:17:57",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71C  ",
#                 "StartTime": "00:13",
#                 "TripNumber": "71881",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 76.0,
#                 "DelaySeconds": 54,
#                 "Display": "88  - DC Oshawa GO",
#                 "EndTime": "23:24",
#                 "FirstStopCode": "02501",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 44.1877,
#                 "LineCode": "88",
#                 "Longitude": -78.464133,
#                 "ModifiedDate": "2023-07-26 22:26:17",
#                 "NextStopCode": "02162",
#                 "PrevStopCode": "02504",
#                 "RouteNumber": "88   ",
#                 "StartTime": "21:49",
#                 "TripNumber": "88811",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 45.0,
#                 "DelaySeconds": 94,
#                 "Display": "88  - Trent U",
#                 "EndTime": "23:48",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02501",
#                 "Latitude": 44.2285,
#                 "LineCode": "88",
#                 "Longitude": -78.386033,
#                 "ModifiedDate": "2023-07-26 23:16:17",
#                 "NextStopCode": "02502",
#                 "PrevStopCode": "02504",
#                 "RouteNumber": "88   ",
#                 "StartTime": "22:13",
#                 "TripNumber": "88870",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02572",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "90B - Union Station",
#                 "EndTime": "00:40",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.8707,
#                 "LineCode": "90",
#                 "Longitude": -78.886167,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02572",
#                 "PrevStopCode": null,
#                 "RouteNumber": "90B  ",
#                 "StartTime": "23:40",
#                 "TripNumber": "90901",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 230.0,
#                 "DelaySeconds": 305,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.800733,
#                 "LineCode": "92",
#                 "Longitude": -79.143517,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00723",
#                 "PrevStopCode": "00622",
#                 "RouteNumber": "92   ",
#                 "StartTime": "22:30",
#                 "TripNumber": "92830",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 64.0,
#                 "DelaySeconds": 77,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "00:15",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.780967,
#                 "LineCode": "92",
#                 "Longitude": -79.252583,
#                 "ModifiedDate": "2023-07-26 23:17:37",
#                 "NextStopCode": "00623",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "92   ",
#                 "StartTime": "22:50",
#                 "TripNumber": "92841",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02749",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.8705,
#                 "LineCode": "92",
#                 "Longitude": -78.8865,
#                 "ModifiedDate": "2023-07-26 23:16:58",
#                 "NextStopCode": "02749",
#                 "PrevStopCode": null,
#                 "RouteNumber": "92   ",
#                 "StartTime": "23:30",
#                 "TripNumber": "92860",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00011",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "01:10",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.72485,
#                 "LineCode": "92",
#                 "Longitude": -79.449067,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00011",
#                 "PrevStopCode": null,
#                 "RouteNumber": "92   ",
#                 "StartTime": "23:50",
#                 "TripNumber": "92871",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 223.0,
#                 "DelaySeconds": -39,
#                 "Display": "94  - Square One",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.70385,
#                 "LineCode": "94",
#                 "Longitude": -79.564017,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02209",
#                 "PrevStopCode": "00020",
#                 "RouteNumber": "94   ",
#                 "StartTime": "22:25",
#                 "TripNumber": "94830",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 89.0,
#                 "DelaySeconds": -240,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.768,
#                 "LineCode": "94",
#                 "Longitude": -79.322267,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00147",
#                 "PrevStopCode": "01647",
#                 "RouteNumber": "94   ",
#                 "StartTime": "22:20",
#                 "TripNumber": "94831",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00723",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "94  - Square One",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.830783,
#                 "LineCode": "94",
#                 "Longitude": -79.08475,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "00723",
#                 "PrevStopCode": null,
#                 "RouteNumber": "94   ",
#                 "StartTime": "23:25",
#                 "TripNumber": "94860",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02659",
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": 0,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "00:45",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.595067,
#                 "LineCode": "94",
#                 "Longitude": -79.64955,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02659",
#                 "PrevStopCode": null,
#                 "RouteNumber": "94   ",
#                 "StartTime": "23:20",
#                 "TripNumber": "94861",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 267.0,
#                 "DelaySeconds": 63,
#                 "Display": "96B - Finch Terminal",
#                 "EndTime": "23:30",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.766817,
#                 "LineCode": "96",
#                 "Longitude": -79.3557,
#                 "ModifiedDate": "2023-07-26 23:17:58",
#                 "NextStopCode": "02772",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "96B  ",
#                 "StartTime": "22:30",
#                 "TripNumber": "96830",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
trip_updates='api/V1/UP/Gtfs/Feed/TripUpdates'
try:
    trip_data = get_data(trip_updates)
    # Print the JSON response (pretty printed)
    print(json.dumps(trip_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trip_updates_collection = db['buses']
    trip_updates_collection.insert_one(trip_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230726-4039",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 74,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 26,
#                             "time": 1690428326,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1690427897,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:00:00",
#                     "trip_id": "20230726-4039"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230726-4138",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 60,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 45,
#                             "time": 1690428165,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1690427897,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "22:57:00",
#                     "trip_id": "20230726-4138"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230726-4238",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 159,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 31,
#                             "time": 1690428211,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 31,
#                             "time": 1690428571,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 31,
#                             "time": 1690429051,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1690427897,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:12:00",
#                     "trip_id": "20230726-4238"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230726-4338",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690428420,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690429080,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690429440,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690429920,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1690427897,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:27:00",
#                     "trip_id": "20230726-4338"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1690427898
#     }
# }
# Data successfully inserted into MongoDB.

# %%
service_messages='api/V1/ServiceUpdate/ServiceAlert/All'
try:
    service_messages_data = get_data(service_messages)
    # Print the JSON response (pretty printed)
    print(json.dumps(service_messages_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    service_messages_collection = db['service_messages']
    service_messages_collection.insert_one(service_messages_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Messages": {
#         "Message": [
#             {
#                 "BodyEnglish": "The elevator connecting the main lobby to platforms 1 and 2 is out of service. The station remains accessible through the ramp in the bus terminal.",
#                 "BodyFrench": "L'ascenseur reliant le hall principal aux quais 1 et 2 est hors service. La gare reste accessible par la rampe de la station d'autobus.",
#                 "Category": "Amenity",
#                 "Code": "M0000383679",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-06-20 09:04:42",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "HA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting June 20, City of Brampton is expected to start construction at Bramalea Terminal by the Bramalea City Centre. As a result, a temporary new bus stop on Central Park Dr. @ Knightsbridge Rd. will be used until the terminal re-opens. Here\u2019s what you need to know: \u00b7 Construction is expected to last for six months. \u00b7 During the time of construction, the bus terminal building will remain open, and you will have access to washrooms. \u00b7 Please follow directional signs. \u00b7 The construction schedule may adjust due to weather conditions or unforeseen circumstances. We will keep you updated. Thank you for your patience and understanding. Please visit the City of Brampton for more information.",
#                 "BodyFrench": "\u00c0 compter 20 juin, la ville de Brampton devrait commencer des travaux de construction \u00e0 la station de Bramalea, \u00e0 c\u00f4t\u00e9 du Bramalea City Centre. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire situ\u00e9 \u00e0 l\u2019intersection de la promenade Central Park et du chemin Knightsbridge sera utilis\u00e9 jusqu\u2019\u00e0 ce que la station rouvre. Voici ce que vous devez savoir :\u00b7 Les travaux de construction devraient durer six mois. \u00b7 Durant ces travaux, l\u2019\u00e9difice de la station d\u2019autobus rester ouvert, et vous aurez acc\u00e8s aux toilettes. \u00b7 Veuillez suivre les panneaux de signalisation. \u00b7 Le calendrier de construction pourrait \u00eatre rajust\u00e9 en fonction des conditions m\u00e9t\u00e9orologiques ou de circonstances impr\u00e9vues. Nous vous tiendrons inform\u00e9s.Nous vous remercions de votre patience et de votre compr\u00e9hension. Veuillez visiter la ville de Brampton pour obtenir de plus amples renseignements.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000388353",
#                 "Lines": [
#                     {
#                         "Code": "32"
#                     },
#                     {
#                         "Code": "36"
#                     }
#                 ],
#                 "ParentCode": "M0000387619",
#                 "PostedDateTime": "2023-06-20 00:01:20",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Bramalea Bus Terminal temporary closure",
#                 "SubjectFrench": "Fermeture temporaire du terminal d\u2019autobus de Bramalea",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the GO platform and the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator on Transway Crescent, adjacent to the south parking lot. Visit the Kennedy GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390000",
#                 "Lines": [
#                     {
#                         "Code": "ST"
#                     }
#                 ],
#                 "ParentCode": "M0000384996",
#                 "PostedDateTime": "2023-06-30 01:26:04",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "KE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Construction continues in your bus loop. Here\u2019s what you need to know:\u2022 As of July 2, the Bronte GO bus loop will be closing, and all buses will operate out of the east parking lot.\u2022 The temporary bus stop in the east parking lot will be in use until approximately Mid-August.\u2022 Please be cautious near and around construction areas.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390213",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": "M0000389990",
#                 "PostedDateTime": "2023-07-01 10:03:28",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "BO",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "New temporary bus stops in the east lot",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Due to a construction project the southbound stop at Main Street and Baker Hill Boulevard will be missed and will also be moved back approximately 100 meters. Customers may board the bus at Main Street at Sandale Road. Please also note that the stop at Highway 48 and Hover Park will also be moved forward approximately 50 meters to provide better service during this time.",
#                 "BodyFrench": "En raison d'un projet de construction, l'arr\u00eat vers le sud de Main Street et Baker Hill Boulevard sera rat\u00e9 et sera \u00e9galement d\u00e9plac\u00e9 environ 100 m\u00e8tres. Les clients peuvent monter \u00e0 bord de l\u2019autobus sur la rue Main \u00e0 Sandale Road. Veuillez \u00e9galement noter que l\u2019arr\u00eat \u00e0 l\u2019autoroute 48 et \u00e0 Hover Park sera \u00e9galement avanc\u00e9 d\u2019environ 50 m\u00e8tres afin d\u2019offrir un meilleur service pendant cette p\u00e9riode.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000391018",
#                 "Lines": [
#                     {
#                         "Code": "70"
#                     },
#                     {
#                         "Code": "71"
#                     }
#                 ],
#                 "ParentCode": "M0000390922",
#                 "PostedDateTime": "2023-07-19 14:43:42",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified \u2013 Route 70 and 71",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the station building/bus loop/kiss & ride to the tunnel is out of service. Platforms are still accessible by using the pedestrian bridge. Visit the Pickering GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le b\u00e2timent de la gare, la ceinture de trafic pour autobus et le d\u00e9barcad\u00e8re au tunnel est hors service. Les quais sont toujours accessibles en empruntant la passerelle pour pi\u00e9tons. Visitez la page de la gare GO de Pickering pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392957",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-20 23:09:11",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "PIN",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platform 1 and 2 is out of service. Customers who need this elevator should board the train at Erindale GO or Meadowvale GO. Visit the Streetsville GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel aux quais 1 et 2 est hors service. Les passagers qui ont besoin de cet ascenseur doivent monter dans le train \u00e0 la gare GO d\u2019Erindale ou de Meadowvale. Visitez la page de la gare GO de Streetsville pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392979",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000392584",
#                 "PostedDateTime": "2023-07-21 00:44:51",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "SR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Lane closures are scheduled on the Burlington Skyway Bridge in the evening on Friday July 28, August 11, and August 18, 2023. All westbound lanes heading toward Niagara will be closed by 10:00 p.m.Buses on your route will detour during this time and delays of up to 20 minutes can be expected. Lanes are scheduled to reopen the following Saturday morning by 10:00 a.m.",
#                 "BodyFrench": "Des fermetures de voies sont pr\u00e9vues sur le pont Skyway de Burlington dans la soir\u00e9e les vendredi 28 juillet, 11 ao\u00fbt et 18 ao\u00fbt 2023. Toutes les voies vers l'ouest en direction de Niagara seront ferm\u00e9es d'ici 22 h.Les autobus de votre trajet feront un d\u00e9tour pendant cette p\u00e9riode et des retards allant jusqu'\u00e0 20 minutes peuvent \u00eatre pr\u00e9vus. Les voies doivent rouvrir le samedi matin suivant avant 10 h.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393308",
#                 "Lines": [
#                     {
#                         "Code": "12"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-23 23:57:20",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Burlington Skyway Bridge Project \u2013 Delays Expected ",
#                 "SubjectFrench": "Projet du pont Skyway de Burlington - Retards pr\u00e9vus \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the parking deck to platform 1 is out of service. Platform 1 remains accessible via the station elevator. Visit the West Harbour GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le stationnement \u00e0 la quai 1 est hors service. La quai 1 reste accessible par l'ascenseur de la gare. Visitez la page de la gare GO de West Harbour pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393312",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": "M0000392320",
#                 "PostedDateTime": "2023-07-24 00:26:58",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "WR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of Service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "A temporary schedule change is in effect due to track work that requires trains to travel slower in some areas. Morning trains to Union Station have been adjusted to depart six minutes earlier. Evening trains depart Union Station at their current scheduled time but arrive at Milton GO station six minutes later. Check your updated schedules here. If you are connecting with local transit from Milton GO station, check connection times using triplinx.ca. Thank you for your patience during this important work.",
#                 "BodyFrench": null,
#                 "Category": "Service Disruption",
#                 "Code": "M0000393486",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000393352",
#                 "PostedDateTime": "2023-07-25 07:10:00",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Temporary schedule change on Milton Line",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Durham College Oshawa GO customers: The Oshawa west parking lot that is located on Victoria St. E is closed due to construction. Customers can utilize the main station parking lot located at the Durham College Oshawa GO station.",
#                 "BodyFrench": "Durham College Oshawa GO clients : L'parc de stationnement ouest d'Oshawa, situ\u00e9 sur la rue Victoria E, est ferm\u00e9 en raison de travaux de construction. Les clients peuvent utiliser le parc de stationnement principal de la station situ\u00e9e \u00e0 la GO de Durham College Oshawa.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393500",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-25 09:08:34",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "OS",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Durham College Oshawa GO parking ",
#                 "SubjectFrench": "Durham College Oshawa GO parking \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There will be extra GO train service between Exhibition GO and Union Station. There will also be express GO trains serving Union Station, Exhibition GO, Port Credit, Oakville, and Burlington GO stations. Check schedules before you travel.",
#                 "BodyFrench": "Il y aura un service de train GO suppl\u00e9mentaire entre la gare GO d\u2019Exhibition et Union. Il y aura \u00e9galement des trains express GO desservant les gares GO d\u2019Union, d\u2019Exhibition, de Port Credit, d\u2019Oakville et de Burlington. V\u00e9rifiez les horaires avant de vous d\u00e9placer.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393620",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 02:04:44",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "We\u2019re adding special Lakeshore West line service on Saturday, August 5 to provide customers with more transit options to the Grande Parade.",
#                 "SubjectFrench": "Nous ajoutons un service sp\u00e9cial \u00e0 la ligne de Lakeshore West, le samedi 5 ao\u00fbt, afin de fournir aux clients plus d\u2019options de transport en commun \u00e0 destination de la Grande Parade.",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Eastbound trips will depart Milton GO at 6:46 a.m. and 10:16 a.m., making all stops to Union Station. Westbound trips will depart Union Station at 6:10 p.m. and 9:19 p.m., making all stops to Milton GO. There will also be one eastbound trip from Milton GO at 7:25 p.m., making all stops to Union. Station, and one westbound trip from Union Station at 9:01 a.m., making all stops to Milton GO. Check schedules before you travel.",
#                 "BodyFrench": "Les trajets de l\u2019Est quitteront Milton GO \u00e0 6 h 46 et 10 h 16, faisant tous les arr\u00eats jusqu\u2019\u00e0 la Gare Union. Les trajets de l\u2019ouest quitteront la Gare Union \u00e0 18 h 10 et \u00e0 21 h 19, ce qui fera tous les arr\u00eats pour Milton GO. Il y aura \u00e9galement un trajet vers l'est de Milton GO \u00e0 19 h 25, faisant tous les arr\u00eats vers Union. Gare, et un trajet vers l'ouest de la Gare Union \u00e0 9 h 01, en direction de Milton GO. V\u00e9rifiez les horaires avant de voyager.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393622",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 02:38:34",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "We\u2019re adding special Milton line service on Saturday, August 5, to provide customers with more transit options to the Grande Parade.",
#                 "SubjectFrench": "Nous ajoutons un service de ligne Milton sp\u00e9cial le samedi 5 ao\u00fbt pour offrir aux clients plus d\u2019options de transport en commun \u00e0 la Grande Parade. \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Our staff will closely monitor traffic conditions along this route and will begin diversions only when required to ensure customers can get to where they need to go as efficiently as possible. As a result, these diversions will not be reflected in online schedules or trip planning tools. During the diversion, eastbound GO Bus Route 16 trips will end at Aldershot GO to connect customers to Lakeshore West trains. Westbound trips will begin at Aldershot GO.",
#                 "BodyFrench": "\u00b7 Notre personnel surveillera de pr\u00e8s les conditions de circulation le long de cette route et mettra en place des d\u00e9tours seulement au besoin pour s\u2019assurer que les clients peuvent se rendre l\u00e0 o\u00f9 ils ont besoin d\u2019aller le plus efficacement possible. Par cons\u00e9quent, ces d\u00e9tours ne seront pas pris en compte dans les horaires en ligne ou les outils de planification de d\u00e9placement. \u00b7 Pendant la p\u00e9riode o\u00f9 des d\u00e9tours sont mis en place, les d\u00e9placements en direction est du trajet d\u2019autobus GO 16 se termineront \u00e0 la gare GO d\u2019Aldershot afin de relier les clients aux trains de Lakeshore West. Les voyages en direction de l\u2019ouest commenceront \u00e0 la gare GO d\u2019Aldershot.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393623",
#                 "Lines": [
#                     {
#                         "Code": "16"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 03:54:36",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "For most of the day on Saturday, August 5, GO Bus Route 16 will be rerouted due to road closures for the Caribbean Carnival Grande Parade. ",
#                 "SubjectFrench": "Pendant la plus grande partie de la journ\u00e9e du samedi 5 ao\u00fbt, le trajet de l\u2019autobus GO 16 sera modifi\u00e9 en raison des fermetures de routes pour la Grande Parade du Carnaval des Cara\u00efbes. ",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "\u00b7 Southbound trips will depart from Old Elm GO at 6:46 a.m. and 9:35 a.m., making all stops to Union Station. \u00b7 Northbound trips will depart Union Station at 5:42 p.m. and 9:44 p.m., making all stops to Old Elm GO. \u00b7 There will also be one southbound trip from Old Elm at 7:03 p.m., making all stops to Union Station, and one northbound trip from Union Station at 8:13 a.m., making all stops to Old Elm. Check schedules before you travel.",
#                 "BodyFrench": null,
#                 "Category": "Service Disruption",
#                 "Code": "M0000393637",
#                 "Lines": [
#                     {
#                         "Code": "ST"
#                     }
#                 ],
#                 "ParentCode": "M0000393633",
#                 "PostedDateTime": "2023-07-26 07:29:02",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "We\u2019re adding special Stouffville line service on Saturday, August 5 to provide customers with more transit options to the Grande Parade.",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the pedestrian bridge to platforms 1 and 2 is out of service. The station remains accessible from the west tunnel in the south lot and from the north lot. Visit the Whitby GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie la passerelle pour pi\u00e9tons aux quais 1 et 2 est hors service. La gare reste accessible depuis le tunnel ouest dans le stationnement sud et depuis le stationnement nord. Visitez la page de la gare GO de Whitby pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393638",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 07:38:10",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "WH",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting platform 2 and the tunnel is out of service. Customers who need this elevator should board the train at Bronte GO or Clarkson GO. Visit the Oakville GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur reliant la quai 2 et le tunnel est hors service. Les passagers qui ont besoin de cet ascenseur doivent monter dans le train \u00e0 la gare de Clarkson ou de Bronte. Visitez la page de la gare GO d\u2019Oakville pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393640",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 08:16:22",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "OA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There are some rules in place to keep everyone safe and comfortable on the train. Learn everything you need to know about bringing a bike on the GO.",
#                 "BodyFrench": "Certaines r\u00e8gles sont en place pour que tout le monde reste en s\u00e9curit\u00e9 et confortable dans le train. Apprenez tout ce que vous avez besoin de savoir sur l'introduction d'un v\u00e9lo sur le GO.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393659",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": "M0000391811",
#                 "PostedDateTime": "2023-07-26 11:41:17",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Travelling with a bicycle?",
#                 "SubjectFrench": "Vous voyagez avec un v\u00e9lo ? \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platforms 1 and 2 is out of service. Customers who need this elevator should board the train at Bramalea or Etobicoke North. Train service at Etobicoke North GO is only available on weekdays. Visit the Malton GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel aux quais 1 et 2 est hors service. Les passagers qui ont besoin de cet ascenseur doivent monter dans le train \u00e0 Bramalea ou Etobicoke Nord. Le service de train \u00e0 Etobicoke North GO n'est disponible que les jours de semaine. Visitez la page de la gare GO de Malton pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393662",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 12:38:55",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "MA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the Finch Bus Terminal to the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator at the Kiss & Ride entrance on the northwest corner of Yonge St. at Hendon Ave. Visit the Finch GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie la station d\u2019autobus de la gare de Finch au tunnel de la TTC est hors service. Les passagers qui ont besoin de cet ascenseur pour acc\u00e9der au syst\u00e8me de la TTC sont invit\u00e9s \u00e0 utiliser l'ascenseur de la TTC situ\u00e9 \u00e0 l'entr\u00e9e de la zone de d\u00e9barcad\u00e8re, \u00e0 l'angle nord-ouest de Yonge St. et de Hendon Ave. Visitez la page de la gare GO de Finch pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393666",
#                 "Lines": [
#                     {
#                         "Code": "19"
#                     },
#                     {
#                         "Code": "27"
#                     },
#                     {
#                         "Code": "96"
#                     }
#                 ],
#                 "ParentCode": "M0000393657",
#                 "PostedDateTime": "2023-07-26 13:24:25",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "00013",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The Hamilton GO Centre 14:25 - Pickering GO 18:05 bus will begin at Square One Bus Terminal due to an operational issue. The next bus departed Hamilton Bus Terminal at 14:40.",
#                 "BodyFrench": "Le bus Centre GO de Hamilton 14 h 25 - Gare GO de Pickering 18 h 05 commencera \u00e0 la Station d'autobus Square One en raison d'un probl\u00e8me op\u00e9rationnel. Le bus suivant a quitt\u00e9 la Station d'autobus de Hamilton \u00e0 14 h 40.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393672",
#                 "Lines": [
#                     {
#                         "Code": "41"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-26 14:54:32",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus trip modified \u2013 Hamilton GO Centre 14:25 - Pickering GO 18:05",
#                 "SubjectFrench": "Trajet d'autobus modifi\u00e9 - Centre GO de Hamilton 14 h 25 - Gare GO de Pickering 18 h 05 \r\n",
#                 "Trips": [
#                     {
#                         "TripNumber": "41450"
#                     }
#                 ]
#             }
#         ]
#     },
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:20"
#     }
# }
# Data successfully inserted into MongoDB.

# %%
vechile_position='api/V1/UP/Gtfs/Feed/VehiclePosition'
try:
    vechile_position_data = get_data(vechile_position)
    # Print the JSON response (pretty printed)
    print(json.dumps(vechile_position_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    vechile_position_collection = db['service_messages']
    vechile_position_collection.insert_one(vechile_position_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230726-4039",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.7062836,
#                     "longitude": -79.56514,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1690427892,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:00:00",
#                     "trip_id": "20230726-4039"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230726-4138",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.64058,
#                     "longitude": -79.41813,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "UN",
#                 "timestamp": 1690427892,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "22:57:00",
#                     "trip_id": "20230726-4138"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230726-4238",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.705204,
#                     "longitude": -79.61156,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1690427892,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:12:00",
#                     "trip_id": "20230726-4238"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230726-4338",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6829224,
#                     "longitude": -79.61338,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1690427892,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230726",
#                     "start_time": "23:27:00",
#                     "trip_id": "20230726-4338"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1690427893
#     }
# }
# Data successfully inserted into MongoDB.

# %%
train_cancelled='api/V1/ServiceUpdate/Exceptions/Train'
try:
    train_cancelled_data = get_data(train_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    train_cancelled_collection = db['train_cancelled']
    train_cancelled_collection.insert_one(train_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:20"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8122"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E6908Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E2726Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E658Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E8123Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "AL",
#                     "ID": "2",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Aldershot GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1019Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3824K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3824Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658C"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1334"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1333"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "ET",
#                     "ID": "24",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Etobicoke North GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BR",
#                     "ID": "27",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Brampton GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MO",
#                     "ID": "674",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mount Pleasant GO",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3539"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "MO",
#                     "ID": "674",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mount Pleasant GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3539Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BO",
#                     "ID": "5",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bronte GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "AP",
#                     "ID": "4",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Appleby GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BU",
#                     "ID": "3",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1639"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658B"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1438"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BU",
#                     "ID": "3",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1639Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E5006Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E6908D"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E2726W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E6910Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8122Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Aldershot GO 14:54 - Union Station GO 16:00",
#             "TripNumber": "1024"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E3824C"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.

# %%
bus_cancelled='api/V1/ServiceUpdate/Exceptions/Bus'
try:
    bus_cancelled_data = get_data(bus_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(bus_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    bus_cancelled_collection = db['bus_cancelled']
    bus_cancelled_collection.insert_one(bus_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:21"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00201",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "University Of Guelph",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01708",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Stone Rd.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02718",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Kortright Rd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01712",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Edinburgh Rd. S.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01714",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Arkell Rd.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01716",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Clairfields Dr. W.",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02678",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Clair Rd. W.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01718",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Brock Rd. S. @ Maple Leaf Ln.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02626",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Brock Rd. S. @ Gilmour Rd.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "University of Guelph 06:35 - Hwy 407 Bus Terminal 08:25",
#             "TripNumber": "48220"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00181",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01241",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy @ Credit Valley Hospital",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01240",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy. @ Erin Centre Blvd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01446",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy.  @ Mcfarren Blvd.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01455",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy.  @ Vista Blvd.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00730",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy @ Britannia Rd",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01325",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Millcreek Dr.  @ Erin Mills Pkwy.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01327",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Millcreek Dr.  @ Millrace Crt.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02597",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "6715 Millcreek Dr @ Aquitaine Ave",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Clarkson GO 09:25 - Lisgar GO 10:05",
#             "TripNumber": "21263"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02674",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hwy 407 Bus Terminal",
#                     "Order": 16,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 17,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00133",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Square One GO Terminal",
#                     "Order": 18,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02215",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 19,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 20,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01441",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd.  @ Burnhamthorpe Rd.",
#                     "Order": 21,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02700",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Dundas St.",
#                     "Order": 22,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02786",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Rosegate Way",
#                     "Order": 23,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02763",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Glenashton Dr.",
#                     "Order": 24,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02764",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ River Oaks Blvd. E.",
#                     "Order": 25,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02765",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Upper Middle Rd. E.",
#                     "Order": 26,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00939",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Sheridan College",
#                     "Order": 27,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02766",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Mccraney St. E.",
#                     "Order": 28,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01729",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Leighland Ave.",
#                     "Order": 29,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00137",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 30,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 12:25 - Oakville GO 15:30",
#             "TripNumber": "56380"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00137",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00902",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Iroquois Shore Rd.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01727",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ White Oaks Blvd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00939",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Sheridan College",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02783",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Upper Middle Rd. E.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02784",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Briarhall Gate",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02785",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Glenashton Dr.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Rosegate Way",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02647",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Dundas St. E.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01435",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd.  @ Burnhamthorpe Rd.",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02214",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Oakville GO 16:10 - Durham College Oshawa GO 19:30",
#             "TripNumber": "56541"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00141",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hamilton GO Centre",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01002",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. E. @ Hughson St. N.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01006",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St W. @ Hamilton Place",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01001",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W.  @ Caroline St. N.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02759",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Queen St. N.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01004",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Pearl St. N.",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01005",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Strathcona Ave. N.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00178",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Dundurn St. N.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02185",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Main St. W.  @ Haddon Ave. S.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00310",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Mcmaster U Bus Term.",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00139",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Dundas St. @ Hwy. 407 Park & Ride",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00138",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bronte Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 13,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02214",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 14,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Hamilton GO Centre 16:55 - Pickering GO 20:30",
#             "TripNumber": "41580"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02777",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Centennial College",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02757",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Consumers Rd. @ William Sylvester Dr.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02674",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hwy 407 Bus Terminal",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00133",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Square One GO Terminal",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Pickering GO 19:00 - Square One 20:45",
#             "TripNumber": "41703"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Finch Bus Terminal 16:30 - Durham College Oshawa GO 17:55",
#             "TripNumber": "96571"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.

# %%
all_cancelled='api/V1/ServiceUpdate/Exceptions/All'
try:
    all_cancelled_data = get_data(all_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(all_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    all_cancelled_collection = db['all_cancelled']
    all_cancelled_collection.insert_one(all_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-26 23:18:21"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8122"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00201",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "University Of Guelph",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01708",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Stone Rd.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02718",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Kortright Rd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01712",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Edinburgh Rd. S.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01714",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Arkell Rd.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01716",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Clairfields Dr. W.",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02678",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Gordon St. @ Clair Rd. W.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01718",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Brock Rd. S. @ Maple Leaf Ln.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02626",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Brock Rd. S. @ Gilmour Rd.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "University of Guelph 06:35 - Hwy 407 Bus Terminal 08:25",
#             "TripNumber": "48220"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E6908Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E2726Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00181",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01241",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy @ Credit Valley Hospital",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01240",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy. @ Erin Centre Blvd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01446",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy.  @ Mcfarren Blvd.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01455",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy.  @ Vista Blvd.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00730",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Pkwy @ Britannia Rd",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01325",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Millcreek Dr.  @ Erin Mills Pkwy.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01327",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Millcreek Dr.  @ Millrace Crt.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02597",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "6715 Millcreek Dr @ Aquitaine Ave",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Clarkson GO 09:25 - Lisgar GO 10:05",
#             "TripNumber": "21263"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E658Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02674",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hwy 407 Bus Terminal",
#                     "Order": 16,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 17,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00133",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Square One GO Terminal",
#                     "Order": 18,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02215",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 19,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 20,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01441",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd.  @ Burnhamthorpe Rd.",
#                     "Order": 21,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02700",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Dundas St.",
#                     "Order": 22,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02786",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Rosegate Way",
#                     "Order": 23,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02763",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Glenashton Dr.",
#                     "Order": 24,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02764",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ River Oaks Blvd. E.",
#                     "Order": 25,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02765",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Upper Middle Rd. E.",
#                     "Order": 26,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00939",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Sheridan College",
#                     "Order": 27,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02766",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Mccraney St. E.",
#                     "Order": 28,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01729",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Leighland Ave.",
#                     "Order": 29,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00137",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 30,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 12:25 - Oakville GO 15:30",
#             "TripNumber": "56380"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E8123Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00137",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00902",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Iroquois Shore Rd.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01727",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ White Oaks Blvd.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00939",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Sheridan College",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02783",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Upper Middle Rd. E.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02784",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Briarhall Gate",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02785",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Glenashton Dr.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Rosegate Way",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02647",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Dundas St. E.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01435",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd.  @ Burnhamthorpe Rd.",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02214",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Oakville GO 16:10 - Durham College Oshawa GO 19:30",
#             "TripNumber": "56541"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "AL",
#                     "ID": "2",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Aldershot GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1019Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3824K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00141",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hamilton GO Centre",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01002",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. E. @ Hughson St. N.",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01006",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St W. @ Hamilton Place",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01001",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W.  @ Caroline St. N.",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02759",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Queen St. N.",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01004",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Pearl St. N.",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "01005",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Strathcona Ave. N.",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00178",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "King St. W. @ Dundurn St. N.",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02185",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Main St. W.  @ Haddon Ave. S.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00310",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Mcmaster U Bus Term.",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00139",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Dundas St. @ Hwy. 407 Park & Ride",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00138",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bronte Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02163",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Trafalgar Rd. @ Hwy. 407 Park & Ride",
#                     "Order": 13,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02214",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Erin Mills Transitway Station",
#                     "Order": 14,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Hamilton GO Centre 16:55 - Pickering GO 20:30",
#             "TripNumber": "41580"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3824Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658C"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1334"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02777",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Centennial College",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02757",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Consumers Rd. @ William Sylvester Dr.",
#                     "Order": 9,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02674",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hwy 407 Bus Terminal",
#                     "Order": 10,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 11,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00133",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Square One GO Terminal",
#                     "Order": 12,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Pickering GO 19:00 - Square One 20:45",
#             "TripNumber": "41703"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1333"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658K"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "ET",
#                     "ID": "24",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Etobicoke North GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BR",
#                     "ID": "27",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Brampton GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MO",
#                     "ID": "674",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mount Pleasant GO",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3539"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "MO",
#                     "ID": "674",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mount Pleasant GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3539Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BO",
#                     "ID": "5",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bronte GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "AP",
#                     "ID": "4",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Appleby GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BU",
#                     "ID": "3",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 8,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1639"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658B"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1438"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BU",
#                     "ID": "3",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1639Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E5006Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E6908D"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E2726W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E6910Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8122Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Aldershot GO 14:54 - Union Station GO 16:00",
#             "TripNumber": "1024"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Finch Bus Terminal 16:30 - Durham College Oshawa GO 17:55",
#             "TripNumber": "96571"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E3824C"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.
