# %%
# Dependencies
import requests
import json
from pprint import pprint

# %%
# Import the API key
from config import key

# %%
# Set the search parameters
trains_endpoint = "api/V1/ServiceataGlance/Trains/All"
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{trains_endpoint}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:34:07"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 235.0,
#                 "DelaySeconds": -31,
#                 "Display": "LW - Aldershot GO",
#                 "EndTime": "23:22",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "AL",
#                 "Latitude": 43.597057,
#                 "LineCode": "LW",
#                 "Longitude": -79.535365,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "LO",
#                 "PrevStopCode": "CANP",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:14",
#                 "TripNumber": "1037",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 29.0,
#                 "DelaySeconds": 127,
#                 "Display": "LW - Union Station",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.47052,
#                 "LineCode": "LW",
#                 "Longitude": -79.669085,
#                 "ModifiedDate": "2023-07-23 22:33:40",
#                 "NextStopCode": "9THL",
#                 "PrevStopCode": "OAKY",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:04",
#                 "TripNumber": "1038",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "WATE",
#                 "Cars": "12",
#                 "Course": 0.0,
#                 "DelaySeconds": -1217,
#                 "Display": "LW - Union Station",
#                 "EndTime": "00:01",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.314118,
#                 "LineCode": "LW",
#                 "Longitude": -79.853117,
#                 "ModifiedDate": "2023-07-23 22:33:44",
#                 "NextStopCode": "WATE",
#                 "PrevStopCode": "AL",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:54",
#                 "TripNumber": "1040",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "BURL",
#                 "Cars": "12",
#                 "Course": 217.0,
#                 "DelaySeconds": 102,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "23:05",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.417872,
#                 "LineCode": "LW",
#                 "Longitude": -79.721278,
#                 "ModifiedDate": "2023-07-23 22:33:43",
#                 "NextStopCode": "BURL",
#                 "PrevStopCode": "BO",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "21:44",
#                 "TripNumber": "1735",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 75.0,
#                 "DelaySeconds": 19,
#                 "Display": "LW - Union Station",
#                 "EndTime": "22:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.633596,
#                 "LineCode": "LW",
#                 "Longitude": -79.427612,
#                 "ModifiedDate": "2023-07-23 22:33:37",
#                 "NextStopCode": "DUFF",
#                 "PrevStopCode": "GARD",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "21:23",
#                 "TripNumber": "1736",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "12",
#                 "Course": 78.0,
#                 "DelaySeconds": -617,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.644953,
#                 "LineCode": "LW",
#                 "Longitude": -79.378102,
#                 "ModifiedDate": "2023-07-23 22:33:44",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:44",
#                 "TripNumber": "1737",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "WATE",
#                 "Cars": "12",
#                 "Course": 49.0,
#                 "DelaySeconds": -81,
#                 "Display": "LW - Union Station",
#                 "EndTime": "23:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.314101,
#                 "LineCode": "LW",
#                 "Longitude": -79.852938,
#                 "ModifiedDate": "2023-07-23 22:33:40",
#                 "NextStopCode": "WATE",
#                 "PrevStopCode": "AL",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:23",
#                 "TripNumber": "1738",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "6",
#                 "Course": 74.0,
#                 "DelaySeconds": -90,
#                 "Display": "GT - Union Station",
#                 "EndTime": "22:36",
#                 "FirstStopCode": "MO",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.643932,
#                 "LineCode": "GT",
#                 "Longitude": -79.38356,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "UN",
#                 "PrevStopCode": "JOHN",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "21:49",
#                 "TripNumber": "3436",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "6",
#                 "Course": 253.0,
#                 "DelaySeconds": 31,
#                 "Display": "GT - Mount Pleasant GO",
#                 "EndTime": "22:39",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "MO",
#                 "Latitude": 43.685258,
#                 "LineCode": "GT",
#                 "Longitude": -79.77196,
#                 "ModifiedDate": "2023-07-23 22:33:43",
#                 "NextStopCode": "BOVA",
#                 "PrevStopCode": "BRDI",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "21:51",
#                 "TripNumber": "3535",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "10",
#                 "Course": 308.0,
#                 "DelaySeconds": 207,
#                 "Display": "BR - Allandale Waterfront GO",
#                 "EndTime": "22:37",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "AD",
#                 "Latitude": 44.362254,
#                 "LineCode": "BR",
#                 "Longitude": -79.645738,
#                 "ModifiedDate": "2023-07-23 22:33:34",
#                 "NextStopCode": "ALNS",
#                 "PrevStopCode": "BA",
#                 "RouteNumber": "BR   ",
#                 "StartTime": "20:53",
#                 "TripNumber": "6933",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "12",
#                 "Course": 80.0,
#                 "DelaySeconds": -1160,
#                 "Display": "BR - Allandale Waterfront GO",
#                 "EndTime": "00:37",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "AD",
#                 "Latitude": 43.645306,
#                 "LineCode": "BR",
#                 "Longitude": -79.378845,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "BR   ",
#                 "StartTime": "22:53",
#                 "TripNumber": "6937",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "-",
#                 "Course": 250.0,
#                 "DelaySeconds": 147,
#                 "Display": "LW - Oakville GO",
#                 "EndTime": "23:10",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OA",
#                 "Latitude": 43.642102,
#                 "LineCode": "LW",
#                 "Longitude": -79.393317,
#                 "ModifiedDate": "2023-07-23 22:33:44",
#                 "NextStopCode": "PORT",
#                 "PrevStopCode": "BLUE",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:29",
#                 "TripNumber": "X1137",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "12",
#                 "Course": 90.0,
#                 "DelaySeconds": -80,
#                 "Display": "LW - Mimico GO",
#                 "EndTime": "22:48",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "MI",
#                 "Latitude": 43.644814,
#                 "LineCode": "LW",
#                 "Longitude": -79.378735,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:35",
#                 "TripNumber": "X1439",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "-",
#                 "Course": 273.0,
#                 "DelaySeconds": 136,
#                 "Display": "GT - Bramalea GO",
#                 "EndTime": "23:01",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "BE",
#                 "Latitude": 43.640198,
#                 "LineCode": "GT",
#                 "Longitude": -79.408693,
#                 "ModifiedDate": "2023-07-23 22:33:42",
#                 "NextStopCode": "STWE",
#                 "PrevStopCode": "BATH",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "22:28",
#                 "TripNumber": "X3037",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "OAKY",
#                 "Cars": "10",
#                 "Course": 217.0,
#                 "DelaySeconds": -680,
#                 "Display": null,
#                 "EndTime": "23:22",
#                 "FirstStopCode": "OA",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.456062,
#                 "LineCode": "LW",
#                 "Longitude": -79.681091,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "OAKY",
#                 "PrevStopCode": "OA",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "22:45",
#                 "TripNumber": "XX1190",
#                 "VariantDir": "E"
#             }
#         ]
#     }
# }

# %%
buses_endpoint='api/V1/ServiceataGlance/Buses/All'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{buses_endpoint}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:36:02"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 87.0,
#                 "DelaySeconds": 1730,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "22:24",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.1351,
#                 "LineCode": "12",
#                 "Longitude": -79.139817,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "02646",
#                 "RouteNumber": "12   ",
#                 "StartTime": "20:39",
#                 "TripNumber": "12781",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 93.0,
#                 "DelaySeconds": 104,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "23:19",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.18765,
#                 "LineCode": "12",
#                 "Longitude": -79.43535,
#                 "ModifiedDate": "2023-07-23 22:35:02",
#                 "NextStopCode": "02646",
#                 "PrevStopCode": "02621",
#                 "RouteNumber": "12   ",
#                 "StartTime": "21:39",
#                 "TripNumber": "12811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00177",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "00:19",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": false,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.388767,
#                 "LineCode": "12",
#                 "Longitude": -79.8284,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": null,
#                 "RouteNumber": "12   ",
#                 "StartTime": "22:39",
#                 "TripNumber": "12841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00820",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 161,
#                 "Display": "12  - Burlington Carpool",
#                 "EndTime": "23:04",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": false,
#                 "LastStopCode": "00139",
#                 "Latitude": 43.242383,
#                 "LineCode": "12",
#                 "Longitude": -79.759917,
#                 "ModifiedDate": "2023-07-23 22:31:01",
#                 "NextStopCode": "00820",
#                 "PrevStopCode": "02406",
#                 "RouteNumber": "12   ",
#                 "StartTime": "21:14",
#                 "TripNumber": "12850",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 296.0,
#                 "DelaySeconds": 232,
#                 "Display": "12B - Burlington GO",
#                 "EndTime": "23:21",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": true,
#                 "LastStopCode": "00177",
#                 "Latitude": 43.154033,
#                 "LineCode": "12",
#                 "Longitude": -79.1555,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": "02405",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "22:21",
#                 "TripNumber": "12860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 248.0,
#                 "DelaySeconds": 180,
#                 "Display": "15 - Brantford Term",
#                 "EndTime": "23:01",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": true,
#                 "LastStopCode": "02617",
#                 "Latitude": 43.206367,
#                 "LineCode": "15",
#                 "Longitude": -80.028083,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02610",
#                 "PrevStopCode": "02619",
#                 "RouteNumber": "15   ",
#                 "StartTime": "22:01",
#                 "TripNumber": "15871",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 345.0,
#                 "DelaySeconds": 246,
#                 "Display": "15 - Aldershot GO",
#                 "EndTime": "22:44",
#                 "FirstStopCode": "02617",
#                 "IsInMotion": true,
#                 "LastStopCode": "00180",
#                 "Latitude": 43.26265,
#                 "LineCode": "15",
#                 "Longitude": -79.923133,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00310",
#                 "RouteNumber": "15   ",
#                 "StartTime": "21:54",
#                 "TripNumber": "15900",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 324,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.643883,
#                 "LineCode": "16",
#                 "Longitude": -79.37695,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00732",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "16   ",
#                 "StartTime": "22:30",
#                 "TripNumber": "16831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 310.0,
#                 "DelaySeconds": 542,
#                 "Display": "16  - Union Station",
#                 "EndTime": "23:00",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.511133,
#                 "LineCode": "16",
#                 "Longitude": -79.691433,
#                 "ModifiedDate": "2023-07-23 22:35:02",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "22:00",
#                 "TripNumber": "16840",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 79.0,
#                 "DelaySeconds": 40,
#                 "Display": "18  - Hamilton GO",
#                 "EndTime": "22:47",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.25875,
#                 "LineCode": "18",
#                 "Longitude": -79.904583,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00732",
#                 "PrevStopCode": "00180",
#                 "RouteNumber": "18   ",
#                 "StartTime": "22:27",
#                 "TripNumber": "18871",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 218.0,
#                 "DelaySeconds": 365,
#                 "Display": "19 - Square One",
#                 "EndTime": "22:40",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.629483,
#                 "LineCode": "19",
#                 "Longitude": -79.6153,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02658",
#                 "RouteNumber": "19   ",
#                 "StartTime": "21:50",
#                 "TripNumber": "19811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 20.0,
#                 "DelaySeconds": 134,
#                 "Display": "19 - Finch Terminal",
#                 "EndTime": "23:05",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.679083,
#                 "LineCode": "19",
#                 "Longitude": -79.576383,
#                 "ModifiedDate": "2023-07-23 22:33:41",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "02208",
#                 "RouteNumber": "19   ",
#                 "StartTime": "22:15",
#                 "TripNumber": "19830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Square One",
#                 "EndTime": "23:40",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.782767,
#                 "LineCode": "19",
#                 "Longitude": -79.414683,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "22:50",
#                 "TripNumber": "19851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00891",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21A - Oakville GO",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": false,
#                 "LastStopCode": "00137",
#                 "Latitude": 43.524167,
#                 "LineCode": "21",
#                 "Longitude": -79.867967,
#                 "ModifiedDate": "2023-07-23 21:11:42",
#                 "NextStopCode": "00891",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21A  ",
#                 "StartTime": "22:15",
#                 "TripNumber": "21820",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 111.0,
#                 "DelaySeconds": 93,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "22:58",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": true,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.575383,
#                 "LineCode": "21",
#                 "Longitude": -79.710133,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01436",
#                 "PrevStopCode": "01384",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "22:13",
#                 "TripNumber": "21822",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 183.0,
#                 "DelaySeconds": 307,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "22:44",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": true,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.595267,
#                 "LineCode": "21",
#                 "Longitude": -79.756117,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01137",
#                 "PrevStopCode": "00129",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "21:54",
#                 "TripNumber": "21823",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 42.0,
#                 "DelaySeconds": 71,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "23:05",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": true,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.57335,
#                 "LineCode": "21",
#                 "Longitude": -79.666383,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01361",
#                 "PrevStopCode": "00189",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "22:33",
#                 "TripNumber": "21824",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 94.0,
#                 "DelaySeconds": 30,
#                 "Display": "21  - Union Station",
#                 "EndTime": "00:15",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.523817,
#                 "LineCode": "21",
#                 "Longitude": -79.866867,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00896",
#                 "PrevStopCode": "00194",
#                 "RouteNumber": "21   ",
#                 "StartTime": "22:35",
#                 "TripNumber": "21830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 306.0,
#                 "DelaySeconds": -30,
#                 "Display": "21A - Milton GO",
#                 "EndTime": "23:09",
#                 "FirstStopCode": "00137",
#                 "IsInMotion": true,
#                 "LastStopCode": "00194",
#                 "Latitude": 43.464917,
#                 "LineCode": "21",
#                 "Longitude": -79.68765,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00939",
#                 "PrevStopCode": "00902",
#                 "RouteNumber": "21A  ",
#                 "StartTime": "22:31",
#                 "TripNumber": "21831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 303.0,
#                 "DelaySeconds": -67,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "23:14",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": true,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.553967,
#                 "LineCode": "21",
#                 "Longitude": -79.696317,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01241",
#                 "PrevStopCode": "00181",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "22:24",
#                 "TripNumber": "21833",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 261,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "22:52",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": false,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.583567,
#                 "LineCode": "21",
#                 "Longitude": -79.621567,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02654",
#                 "PrevStopCode": "02751",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "22:17",
#                 "TripNumber": "21835",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02215",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "23:44",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": false,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.512933,
#                 "LineCode": "21",
#                 "Longitude": -79.6329,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21B  ",
#                 "StartTime": "22:54",
#                 "TripNumber": "21853",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 349.0,
#                 "DelaySeconds": 54,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.44175,
#                 "LineCode": "25",
#                 "Longitude": -80.4558,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02800",
#                 "PrevStopCode": "02184",
#                 "RouteNumber": "25   ",
#                 "StartTime": "21:10",
#                 "TripNumber": "25781",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 241.0,
#                 "DelaySeconds": 13,
#                 "Display": "25C - U of Waterloo",
#                 "EndTime": "22:45",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.475167,
#                 "LineCode": "25",
#                 "Longitude": -80.527867,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02148",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "21:30",
#                 "TripNumber": "25803",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 249.0,
#                 "DelaySeconds": -277,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.537167,
#                 "LineCode": "25",
#                 "Longitude": -79.8849,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00337",
#                 "PrevStopCode": "02635",
#                 "RouteNumber": "25   ",
#                 "StartTime": "22:10",
#                 "TripNumber": "25821",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02215",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25  - U of Waterloo",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.595,
#                 "LineCode": "25",
#                 "Longitude": -79.649533,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25   ",
#                 "StartTime": "23:10",
#                 "TripNumber": "25851",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 75.0,
#                 "DelaySeconds": -25,
#                 "Display": "25  - Square One",
#                 "EndTime": "23:35",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.438467,
#                 "LineCode": "25",
#                 "Longitude": -80.225567,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02151",
#                 "PrevStopCode": "02605",
#                 "RouteNumber": "25   ",
#                 "StartTime": "21:55",
#                 "TripNumber": "25870",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 20.0,
#                 "DelaySeconds": 3576,
#                 "Display": "27F - Meadowvale GO",
#                 "EndTime": "22:25",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00129",
#                 "Latitude": 43.597167,
#                 "LineCode": "27",
#                 "Longitude": -79.755517,
#                 "ModifiedDate": "2023-07-23 22:29:41",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "27F  ",
#                 "StartTime": "21:30",
#                 "TripNumber": "27801",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 71.0,
#                 "DelaySeconds": 278,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.7241,
#                 "LineCode": "27",
#                 "Longitude": -79.473833,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01648",
#                 "PrevStopCode": "00022",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "22:00",
#                 "TripNumber": "27820",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 171.0,
#                 "DelaySeconds": 184,
#                 "Display": "27F - Meadowvale GO",
#                 "EndTime": "23:20",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00129",
#                 "Latitude": 43.77205,
#                 "LineCode": "27",
#                 "Longitude": -79.4137,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00300",
#                 "PrevStopCode": "01654",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "22:30",
#                 "TripNumber": "27831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02598",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.597533,
#                 "LineCode": "27",
#                 "Longitude": -79.755367,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02598",
#                 "PrevStopCode": null,
#                 "RouteNumber": "27F  ",
#                 "StartTime": "23:00",
#                 "TripNumber": "27850",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 127.0,
#                 "DelaySeconds": 12,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "22:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": true,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.529133,
#                 "LineCode": "29",
#                 "Longitude": -80.224883,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00201",
#                 "RouteNumber": "29   ",
#                 "StartTime": "21:00",
#                 "TripNumber": "29791",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 221.0,
#                 "DelaySeconds": 40,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "23:40",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": true,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.54525,
#                 "LineCode": "29",
#                 "Longitude": -79.708167,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02151",
#                 "PrevStopCode": "02215",
#                 "RouteNumber": "29   ",
#                 "StartTime": "22:00",
#                 "TripNumber": "29831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00201",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "00:20",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": false,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.5449,
#                 "LineCode": "29",
#                 "Longitude": -80.2465,
#                 "ModifiedDate": "2023-07-23 22:35:02",
#                 "NextStopCode": "00201",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "22:40",
#                 "TripNumber": "29880",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02186",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -294,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "23:00",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.451767,
#                 "LineCode": "30",
#                 "Longitude": -80.4871,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02186",
#                 "PrevStopCode": "02205",
#                 "RouteNumber": "30   ",
#                 "StartTime": "21:35",
#                 "TripNumber": "30791",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 63.0,
#                 "DelaySeconds": 986,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "22:45",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.66875,
#                 "LineCode": "33",
#                 "Longitude": -79.590667,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "00354",
#                 "RouteNumber": "33   ",
#                 "StartTime": "20:20",
#                 "TripNumber": "33750",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 14.0,
#                 "DelaySeconds": -177,
#                 "Display": "33G - Mount Pleasant GO",
#                 "EndTime": "22:35",
#                 "FirstStopCode": "02413",
#                 "IsInMotion": true,
#                 "LastStopCode": "00296",
#                 "Latitude": 43.674367,
#                 "LineCode": "33",
#                 "Longitude": -79.823083,
#                 "ModifiedDate": "2023-07-23 22:31:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00214",
#                 "RouteNumber": "33G  ",
#                 "StartTime": "22:15",
#                 "TripNumber": "33780",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 317.0,
#                 "DelaySeconds": 64,
#                 "Display": "33 - U of Guelph",
#                 "EndTime": "00:05",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.70465,
#                 "LineCode": "33",
#                 "Longitude": -79.785267,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02712",
#                 "PrevStopCode": "01454",
#                 "RouteNumber": "33   ",
#                 "StartTime": "21:30",
#                 "TripNumber": "33821",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 94.0,
#                 "DelaySeconds": 927,
#                 "Display": "36B - York Mills Term",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "02827",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.696717,
#                 "LineCode": "36",
#                 "Longitude": -79.600833,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "08042",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "22:10",
#                 "TripNumber": "36800",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 227.0,
#                 "DelaySeconds": -9,
#                 "Display": "36B - Bramalea Term",
#                 "EndTime": "23:00",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "02827",
#                 "Latitude": 43.751033,
#                 "LineCode": "36",
#                 "Longitude": -79.412717,
#                 "ModifiedDate": "2023-07-23 22:17:42",
#                 "NextStopCode": "00020",
#                 "PrevStopCode": "01657",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "22:15",
#                 "TripNumber": "36831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 6349,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "20:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.840183,
#                 "LineCode": "40",
#                 "Longitude": -79.42525,
#                 "ModifiedDate": "2023-07-23 20:56:02",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "40   ",
#                 "StartTime": "19:10",
#                 "TripNumber": "40710",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 337.0,
#                 "DelaySeconds": 411,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.715217,
#                 "LineCode": "40",
#                 "Longitude": -79.618133,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02771",
#                 "PrevStopCode": "00311",
#                 "RouteNumber": "40   ",
#                 "StartTime": "21:10",
#                 "TripNumber": "40790",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 177.0,
#                 "DelaySeconds": 267,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.3761,
#                 "LineCode": "40",
#                 "Longitude": -79.83295,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00732",
#                 "PrevStopCode": "00139",
#                 "RouteNumber": "40   ",
#                 "StartTime": "21:05",
#                 "TripNumber": "40791",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02163",
#                 "BusType": "Coach",
#                 "Course": 199.0,
#                 "DelaySeconds": 337,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.389017,
#                 "LineCode": "40",
#                 "Longitude": -79.82805,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02163",
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "40   ",
#                 "StartTime": "22:10",
#                 "TripNumber": "40830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02209",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "23:55",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.682267,
#                 "LineCode": "40",
#                 "Longitude": -79.61185,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02209",
#                 "PrevStopCode": "02674",
#                 "RouteNumber": "40   ",
#                 "StartTime": "22:05",
#                 "TripNumber": "40831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.2529,
#                 "LineCode": "40",
#                 "Longitude": -79.8692,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "40   ",
#                 "StartTime": "23:10",
#                 "TripNumber": "40860",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 73.0,
#                 "DelaySeconds": 673,
#                 "Display": "47W - Hamilton GO",
#                 "EndTime": "22:35",
#                 "FirstStopCode": "02820",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.260017,
#                 "LineCode": "47",
#                 "Longitude": -79.897633,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": "01013",
#                 "PrevStopCode": "01009",
#                 "RouteNumber": "47W  ",
#                 "StartTime": "20:25",
#                 "TripNumber": "47781",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 296.0,
#                 "DelaySeconds": 657,
#                 "Display": "47  - Hamilton GO",
#                 "EndTime": "23:00",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.38285,
#                 "LineCode": "47",
#                 "Longitude": -79.835217,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00310",
#                 "PrevStopCode": "00139",
#                 "RouteNumber": "47   ",
#                 "StartTime": "21:10",
#                 "TripNumber": "47791",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 218.0,
#                 "DelaySeconds": -11,
#                 "Display": "47W - Hamilton GO",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "02820",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.508583,
#                 "LineCode": "47",
#                 "Longitude": -79.748467,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00139",
#                 "PrevStopCode": "02163",
#                 "RouteNumber": "47W  ",
#                 "StartTime": "21:25",
#                 "TripNumber": "47811",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": -37,
#                 "Display": "47  - Hamilton GO",
#                 "EndTime": "23:55",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.655667,
#                 "LineCode": "47",
#                 "Longitude": -79.682767,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": "02728",
#                 "RouteNumber": "47   ",
#                 "StartTime": "22:10",
#                 "TripNumber": "47831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 136.0,
#                 "DelaySeconds": 185,
#                 "Display": "47  - Hwy. 407 Bus Term",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.700233,
#                 "LineCode": "47",
#                 "Longitude": -79.684283,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": null,
#                 "PrevStopCode": "08041",
#                 "RouteNumber": "47   ",
#                 "StartTime": "21:00",
#                 "TripNumber": "47840",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -41,
#                 "Display": "47W - Hamilton GO",
#                 "EndTime": "00:25",
#                 "FirstStopCode": "02820",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.791667,
#                 "LineCode": "47",
#                 "Longitude": -79.536383,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02728",
#                 "PrevStopCode": "02820",
#                 "RouteNumber": "47W  ",
#                 "StartTime": "22:25",
#                 "TripNumber": "47841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 358.0,
#                 "DelaySeconds": 124,
#                 "Display": "47  - Hwy. 407 Bus Term",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.362117,
#                 "LineCode": "47",
#                 "Longitude": -79.8319,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00138",
#                 "PrevStopCode": "00310",
#                 "RouteNumber": "47   ",
#                 "StartTime": "22:00",
#                 "TripNumber": "47880",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01002",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "47  - Hwy. 407 Bus Term",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.252783,
#                 "LineCode": "47",
#                 "Longitude": -79.869017,
#                 "ModifiedDate": "2023-07-23 22:29:41",
#                 "NextStopCode": "01002",
#                 "PrevStopCode": null,
#                 "RouteNumber": "47   ",
#                 "StartTime": "23:05",
#                 "TripNumber": "47910",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 196.0,
#                 "DelaySeconds": 346,
#                 "Display": "52 - DC Oshawa GO",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "02674",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.91345,
#                 "LineCode": "52",
#                 "Longitude": -79.096233,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02779",
#                 "PrevStopCode": "08043",
#                 "RouteNumber": "52   ",
#                 "StartTime": "21:45",
#                 "TripNumber": "52891",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 342.0,
#                 "DelaySeconds": 413,
#                 "Display": "52 - Hwy. 407 Bus Term",
#                 "EndTime": "23:05",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02673",
#                 "Latitude": 43.8821,
#                 "LineCode": "52",
#                 "Longitude": -79.214217,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": "02539",
#                 "RouteNumber": "52   ",
#                 "StartTime": "21:35",
#                 "TripNumber": "52900",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02674",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 324,
#                 "Display": "52X - DC Oshawa GO",
#                 "EndTime": "00:15",
#                 "FirstStopCode": "02820",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.847233,
#                 "LineCode": "52",
#                 "Longitude": -79.541733,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02674",
#                 "PrevStopCode": null,
#                 "RouteNumber": "52X  ",
#                 "StartTime": "22:30",
#                 "TripNumber": "52921",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00027",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 6154,
#                 "Display": "65F - Union Station",
#                 "EndTime": "21:22",
#                 "FirstStopCode": "00081",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.645667,
#                 "LineCode": "65",
#                 "Longitude": -79.378133,
#                 "ModifiedDate": "2023-07-23 21:31:41",
#                 "NextStopCode": "00027",
#                 "PrevStopCode": null,
#                 "RouteNumber": "65F  ",
#                 "StartTime": "19:57",
#                 "TripNumber": "65742",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 168.0,
#                 "DelaySeconds": -146,
#                 "Display": "65 - East Gwillimbury GO",
#                 "EndTime": "22:58",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00276",
#                 "Latitude": 44.00005,
#                 "LineCode": "65",
#                 "Longitude": -79.45945,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02726",
#                 "PrevStopCode": "00081",
#                 "RouteNumber": "65   ",
#                 "StartTime": "21:48",
#                 "TripNumber": "65811",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 106,
#                 "Display": "65E - East Gwillimbury GO",
#                 "EndTime": "23:33",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00276",
#                 "Latitude": 43.838567,
#                 "LineCode": "65",
#                 "Longitude": -79.502067,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02158",
#                 "PrevStopCode": "00028",
#                 "RouteNumber": "65E  ",
#                 "StartTime": "21:53",
#                 "TripNumber": "65813",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 76.0,
#                 "DelaySeconds": 358,
#                 "Display": "65F - Union Station",
#                 "EndTime": "23:12",
#                 "FirstStopCode": "00081",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.842483,
#                 "LineCode": "65",
#                 "Longitude": -79.4834,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00028",
#                 "RouteNumber": "65F  ",
#                 "StartTime": "21:52",
#                 "TripNumber": "65822",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 146.0,
#                 "DelaySeconds": 149,
#                 "Display": "68B - East Gwillimbury GO",
#                 "EndTime": "23:20",
#                 "FirstStopCode": "02828",
# ...
#                 "Latitude": 44.003383,
#                 "LineCode": "88",
#                 "Longitude": -78.605417,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "02504",
#                 "PrevStopCode": "02162",
#                 "RouteNumber": "88   ",
#                 "StartTime": "21:58",
#                 "TripNumber": "88860",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 223.0,
#                 "DelaySeconds": 259,
#                 "Display": "88  - DC Oshawa GO",
#                 "EndTime": "23:24",
#                 "FirstStopCode": "02501",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 44.107117,
#                 "LineCode": "88",
#                 "Longitude": -78.568117,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": "02162",
#                 "PrevStopCode": "02504",
#                 "RouteNumber": "88   ",
#                 "StartTime": "21:44",
#                 "TripNumber": "88901",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": "02697",
#                 "BusType": "Coach",
#                 "Course": 165.0,
#                 "DelaySeconds": 885,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "22:30",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.865133,
#                 "LineCode": "90",
#                 "Longitude": -78.937817,
#                 "ModifiedDate": "2023-07-23 22:35:01",
#                 "NextStopCode": "02697",
#                 "PrevStopCode": "00161",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "21:25",
#                 "TripNumber": "90794",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 254.0,
#                 "DelaySeconds": 633,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.8305,
#                 "LineCode": "90",
#                 "Longitude": -79.079267,
#                 "ModifiedDate": "2023-07-23 22:35:02",
#                 "NextStopCode": "00161",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "21:50",
#                 "TripNumber": "90810",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 343.0,
#                 "DelaySeconds": 173,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.835233,
#                 "LineCode": "90",
#                 "Longitude": -79.0686,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00031",
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "21:55",
#                 "TripNumber": "90812",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 1080,
#                 "Display": "90B - Union Station",
#                 "EndTime": "22:20",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.645283,
#                 "LineCode": "90",
#                 "Longitude": -79.369833,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "21:10",
#                 "TripNumber": "90823",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 357.0,
#                 "DelaySeconds": 173,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "23:20",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.747967,
#                 "LineCode": "90",
#                 "Longitude": -79.333267,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00161",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "22:20",
#                 "TripNumber": "90830",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 246.0,
#                 "DelaySeconds": -482,
#                 "Display": "90B - Union Station",
#                 "EndTime": "22:45",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.648817,
#                 "LineCode": "90",
#                 "Longitude": -79.35845,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "21:35",
#                 "TripNumber": "90831",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 348.0,
#                 "DelaySeconds": 378,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "23:25",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.663233,
#                 "LineCode": "90",
#                 "Longitude": -79.355333,
#                 "ModifiedDate": "2023-07-23 22:35:21",
#                 "NextStopCode": "00161",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "22:25",
#                 "TripNumber": "90832",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00147",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "90B - DC Oshawa GO",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.644083,
#                 "LineCode": "90",
#                 "Longitude": -79.377683,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00147",
#                 "PrevStopCode": null,
#                 "RouteNumber": "90B  ",
#                 "StartTime": "22:50",
#                 "TripNumber": "90840",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 158.0,
#                 "DelaySeconds": 153,
#                 "Display": "90B - Union Station",
#                 "EndTime": "23:10",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.830733,
#                 "LineCode": "90",
#                 "Longitude": -79.083733,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "90B  ",
#                 "StartTime": "22:05",
#                 "TripNumber": "90841",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 684,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.7874,
#                 "LineCode": "92",
#                 "Longitude": -79.268217,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "01657",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "92   ",
#                 "StartTime": "21:25",
#                 "TripNumber": "92800",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 42.0,
#                 "DelaySeconds": 383,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "23:15",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.819333,
#                 "LineCode": "92",
#                 "Longitude": -79.114733,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00971",
#                 "PrevStopCode": "00634",
#                 "RouteNumber": "92   ",
#                 "StartTime": "21:50",
#                 "TripNumber": "92811",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00011",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "00:10",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.725333,
#                 "LineCode": "92",
#                 "Longitude": -79.449383,
#                 "ModifiedDate": "2023-07-23 22:25:22",
#                 "NextStopCode": "00011",
#                 "PrevStopCode": null,
#                 "RouteNumber": "92   ",
#                 "StartTime": "22:50",
#                 "TripNumber": "92841",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02749",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "00:50",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.8705,
#                 "LineCode": "92",
#                 "Longitude": -78.886517,
#                 "ModifiedDate": "2023-07-23 22:34:21",
#                 "NextStopCode": "02749",
#                 "PrevStopCode": null,
#                 "RouteNumber": "92   ",
#                 "StartTime": "23:25",
#                 "TripNumber": "92860",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 217.0,
#                 "DelaySeconds": -325,
#                 "Display": "94  - Square One",
#                 "EndTime": "22:55",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.661583,
#                 "LineCode": "94",
#                 "Longitude": -79.592617,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "00133",
#                 "PrevStopCode": "02660",
#                 "RouteNumber": "94   ",
#                 "StartTime": "21:25",
#                 "TripNumber": "94790",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 78.0,
#                 "DelaySeconds": 2,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "22:50",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.794217,
#                 "LineCode": "94",
#                 "Longitude": -79.210933,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "94   ",
#                 "StartTime": "21:20",
#                 "TripNumber": "94791",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 232.0,
#                 "DelaySeconds": -247,
#                 "Display": "94  - Square One",
#                 "EndTime": "23:50",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.791517,
#                 "LineCode": "94",
#                 "Longitude": -79.22215,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02816",
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "94   ",
#                 "StartTime": "22:25",
#                 "TripNumber": "94830",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 193.0,
#                 "DelaySeconds": -94,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "23:45",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.683717,
#                 "LineCode": "94",
#                 "Longitude": -79.6052,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00022",
#                 "PrevStopCode": "02208",
#                 "RouteNumber": "94   ",
#                 "StartTime": "22:20",
#                 "TripNumber": "94831",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00161",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 13,
#                 "Display": "96B - DC Oshawa GO",
#                 "EndTime": "23:10",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.77415,
#                 "LineCode": "96",
#                 "Longitude": -79.261067,
#                 "ModifiedDate": "2023-07-23 22:35:22",
#                 "NextStopCode": "00161",
#                 "PrevStopCode": "01647",
#                 "RouteNumber": "96B  ",
#                 "StartTime": "22:10",
#                 "TripNumber": "96821",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02572",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 330,
#                 "Display": "96B - Finch Terminal",
#                 "EndTime": "23:30",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.871,
#                 "LineCode": "96",
#                 "Longitude": -78.886067,
#                 "ModifiedDate": "2023-07-23 22:35:41",
#                 "NextStopCode": "02572",
#                 "PrevStopCode": null,
#                 "RouteNumber": "96B  ",
#                 "StartTime": "22:30",
#                 "TripNumber": "96830",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }

# %%
trip_updates='api/V1/UP/Gtfs/Feed/TripUpdates'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{trip_updates}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230723-4038",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690166520,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690167180,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690167540,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690168020,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1690166420,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:42:00",
#                     "trip_id": "20230723-4038"
#                 },
#                 "vehicle": {
#                     "id": "3002",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230723-4137",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 108,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 48,
#                             "time": 1690166448,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1690166420,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:15:00",
#                     "trip_id": "20230723-4137"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230723-4237",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 212,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 85,
#                             "time": 1690166365,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 85,
#                             "time": 1690166725,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 85,
#                             "time": 1690167385,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1690166420,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:30:00",
#                     "trip_id": "20230723-4237"
#                 },
#                 "vehicle": {
#                     "id": "1004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230723-4336",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 197,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 57,
#                             "time": 1690166367,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 57,
#                             "time": 1690166697,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 57,
#                             "time": 1690167177,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1690166420,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:27:00",
#                     "trip_id": "20230723-4336"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230723-4337",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690166700,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690167180,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690167540,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1690168200,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1690166420,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:45:00",
#                     "trip_id": "20230723-4337"
#                 },
#                 "vehicle": {
#                     "id": "3005",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1690166422
#     }
# }

# %%
service_messages='api/V1/ServiceUpdate/ServiceAlert/All'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{service_messages}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Messages": {
#         "Message": [
#             {
#                 "BodyEnglish": "The elevator connecting the main lobby to platforms 1 and 2 is out of service. The station remains accessible through the ramp in the bus terminal.",
#                 "BodyFrench": "L'ascenseur reliant le hall principal aux quais 1 et 2 est hors service. La gare reste accessible par la rampe de la station d'autobus.",
#                 "Category": "Amenity",
#                 "Code": "M0000383679",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-06-20 09:04:42",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "HA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting June 20, City of Brampton is expected to start construction at Bramalea Terminal by the Bramalea City Centre. As a result, a temporary new bus stop on Central Park Dr. @ Knightsbridge Rd. will be used until the terminal re-opens. Here\u2019s what you need to know: \u00b7 Construction is expected to last for six months. \u00b7 During the time of construction, the bus terminal building will remain open, and you will have access to washrooms. \u00b7 Please follow directional signs. \u00b7 The construction schedule may adjust due to weather conditions or unforeseen circumstances. We will keep you updated. Thank you for your patience and understanding. Please visit the City of Brampton for more information.",
#                 "BodyFrench": "\u00c0 compter 20 juin, la ville de Brampton devrait commencer des travaux de construction \u00e0 la station de Bramalea, \u00e0 c\u00f4t\u00e9 du Bramalea City Centre. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire situ\u00e9 \u00e0 l\u2019intersection de la promenade Central Park et du chemin Knightsbridge sera utilis\u00e9 jusqu\u2019\u00e0 ce que la station rouvre. Voici ce que vous devez savoir :\u00b7 Les travaux de construction devraient durer six mois. \u00b7 Durant ces travaux, l\u2019\u00e9difice de la station d\u2019autobus rester ouvert, et vous aurez acc\u00e8s aux toilettes. \u00b7 Veuillez suivre les panneaux de signalisation. \u00b7 Le calendrier de construction pourrait \u00eatre rajust\u00e9 en fonction des conditions m\u00e9t\u00e9orologiques ou de circonstances impr\u00e9vues. Nous vous tiendrons inform\u00e9s.Nous vous remercions de votre patience et de votre compr\u00e9hension. Veuillez visiter la ville de Brampton pour obtenir de plus amples renseignements.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000388353",
#                 "Lines": [
#                     {
#                         "Code": "32"
#                     },
#                     {
#                         "Code": "36"
#                     }
#                 ],
#                 "ParentCode": "M0000387619",
#                 "PostedDateTime": "2023-06-20 00:01:20",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Bramalea Bus Terminal temporary closure",
#                 "SubjectFrench": "Fermeture temporaire du terminal d\u2019autobus de Bramalea",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the GO platform and the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator on Transway Crescent, adjacent to the south parking lot. Visit the Kennedy GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390000",
#                 "Lines": [
#                     {
#                         "Code": "ST"
#                     }
#                 ],
#                 "ParentCode": "M0000384996",
#                 "PostedDateTime": "2023-06-30 01:26:04",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "KE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Construction continues in your bus loop. Here\u2019s what you need to know:\u2022 As of July 2, the Bronte GO bus loop will be closing, and all buses will operate out of the east parking lot.\u2022 The temporary bus stop in the east parking lot will be in use until approximately Mid-August.\u2022 Please be cautious near and around construction areas.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390213",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": "M0000389990",
#                 "PostedDateTime": "2023-07-01 10:03:28",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "BO",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "New temporary bus stops in the east lot",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Due to a construction project the southbound stop at Main Street and Baker Hill Boulevard will be missed and will also be moved back approximately 100 meters. Customers may board the bus at Main Street at Sandale Road. Please also note that the stop at Highway 48 and Hover Park will also be moved forward approximately 50 meters to provide better service during this time.",
#                 "BodyFrench": "En raison d'un projet de construction, l'arr\u00eat vers le sud de Main Street et Baker Hill Boulevard sera rat\u00e9 et sera \u00e9galement d\u00e9plac\u00e9 environ 100 m\u00e8tres. Les clients peuvent monter \u00e0 bord de l\u2019autobus sur la rue Main \u00e0 Sandale Road. Veuillez \u00e9galement noter que l\u2019arr\u00eat \u00e0 l\u2019autoroute 48 et \u00e0 Hover Park sera \u00e9galement avanc\u00e9 d\u2019environ 50 m\u00e8tres afin d\u2019offrir un meilleur service pendant cette p\u00e9riode.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000391018",
#                 "Lines": [
#                     {
#                         "Code": "70"
#                     },
#                     {
#                         "Code": "71"
#                     }
#                 ],
#                 "ParentCode": "M0000390922",
#                 "PostedDateTime": "2023-07-19 14:43:42",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified \u2013 Route 70 and 71",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "For your safety, there is a maximum number of bicycles allowed in each train coach. Our staff are actively monitoring the number of bicycles on trains to ensure the safety and comfort of our customers and crews. If the number of bicycles onboard a train exceeds the limit, those additional customers with bicycles may be asked to exit the train and wait for the next one. If all trains are above capacity, customers with bicycles may need to consider an alternative travel option. Here is some information that you may not know about travelling on the GO train with your bicycle: Bicycles are welcome on board our trains, except on weekdays during rush hour (trips that arrive at Union Station between 6:30 and 9:30 a.m. and trips that leave Union Station between 3:30 and 6:30 p.m.). For your safety and comfort, when boarding the train, please ensure you board at doors identified by a green bicycle sticker and keep your bicycle in the designated bicycle zone. If designated bicycle zones are full, you will have to wait for the next train. If all trains are at capacity, you may not be able to board a GO train with your bicycle. Bikes are not permitted on accessible coaches, except for customers with disabilities who have requested and received approval from GO Transit for individual accommodation. Once you\u2019re onboard, remember to stay with your bicycle throughout your journey. Bikes are not permitted on the upper levels of the train. Non-compliance with the Metrolinx Bicycle Policy may result in a ticket or other enforcement action under the Provincial Offences Act. Your safety is our priority. Train crews need to move through the train when responding to emergencies or service-related issues. For everyone\u2019s safety, ensure bikes do not block doorways, stairwells, aisles or bathrooms. Riding your bike or e-bike while on platforms, in tunnels, or in station buildings is always prohibited. Please walk your bike in these areas. Secure your bicycle with City of Toronto \u2013 Bicycle Parking.",
#                 "BodyFrench": "Pour votre s\u00e9curit\u00e9, un nombre maximum de v\u00e9los est permis dans chaque autocar. Notre personnel surveille activement le nombre de v\u00e9los dans les trains pour assurer la s\u00e9curit\u00e9 et le confort de nos clients et de nos \u00e9quipages. Si le nombre de bicyclettes \u00e0 bord d'un train d\u00e9passe la limite, on peut demander \u00e0 ces clients suppl\u00e9mentaires qui ont des bicyclettes de sortir du train et d'attendre la prochaine. Si tous les trains sont au-dessus de leur capacit\u00e9, les clients qui ont des bicyclettes peuvent devoir envisager une autre option de d\u00e9placement. Voici quelques informations que vous ne connaissez peut-\u00eatre pas sur le voyage sur le Train GO avec votre v\u00e9lo : Les bicyclettes sont les bienvenues \u00e0 bord de nos trains, sauf en semaine pendant les heures de pointe (trajets qui arrivent \u00e0 la Gare Union entre 6h30 et 9h30 et trajets qui quittent la Gare Union entre 15h30 et 18h30). Pour votre s\u00e9curit\u00e9 et votre confort, lors de votre embarquement dans le train, assurez-vous de monter \u00e0 bord des portes identifi\u00e9es par un autocollant de v\u00e9lo vert et gardez votre v\u00e9lo dans la zone de v\u00e9lo d\u00e9sign\u00e9e. Si les zones de bicyclettes d\u00e9sign\u00e9es sont pleines, vous devrez attendre le prochain train. Si tous les trains sont \u00e0 port\u00e9e de main, vous ne pourrez peut-\u00eatre pas monter \u00e0 bord d'un Train GO avec votre v\u00e9lo. Les v\u00e9los ne sont pas autoris\u00e9s sur les autocars accessibles, sauf pour les clients ayant une d\u00e9ficience qui ont demand\u00e9 et re\u00e7u l\u2019approbation du GO Transit pour l\u2019h\u00e9bergement individuel. Une fois \u00e0 bord, n\u2019oubliez pas de rester avec votre v\u00e9lo tout au long de votre voyage. Les v\u00e9los ne sont pas autoris\u00e9s dans les \u00e9tages sup\u00e9rieurs du train. Le non-respect de la Politique sur les v\u00e9los de Metrolinx peut donner lieu \u00e0 un billet ou \u00e0 toute autre mesure d\u2019application de la loi en vertu de la Loi sur les infractions provinciales. Votre s\u00e9curit\u00e9 est notre priorit\u00e9. Les \u00e9quipes de train doivent se d\u00e9placer dans le train lorsqu\u2019elles r\u00e9pondent \u00e0 des situations d\u2019urgence ou \u00e0 des probl\u00e8mes li\u00e9s au service. Pour la s\u00e9curit\u00e9 de tous, assurez-vous que les v\u00e9los ne bloquent pas les portes, les escaliers, les all\u00e9es ou les salles de bains. Il est toujours interdit de faire du v\u00e9lo ou du v\u00e9lo \u00e9lectronique sur les quais, dans les tunnels ou dans les immeubles de la gare. Veuillez marcher votre v\u00e9lo dans ces zones. S\u00e9curisez votre v\u00e9lo avec Ville de Toronto - Parking pour v\u00e9los.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000391811",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": "M0000391759",
#                 "PostedDateTime": "2023-07-13 01:44:13",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Reminder: A maximum of two bikes are permitted in each designated bicycle zone.",
#                 "SubjectFrench": "Rappel : Un maximum de deux v\u00e9los sont permis dans chaque zone de v\u00e9los d\u00e9sign\u00e9e. \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting Tuesday, July 25, track work will require trains to travel slower in some areas. Morning trains to Union Station will leave six minutes earlier than scheduled. Evening trains will leave Union Station at their current scheduled time but will arrive at Milton GO station six minutes later. Please plan your trip ahead of time at gotransit.com or triplinx.ca. Thank you for your patience during this important work.",
#                 "BodyFrench": "\u00c0 compter du mardi 25 juillet, le travaux \u00e0 la voie ferr\u00e9e exigera que les trains circulent plus lentement dans certaines zones. Les trains du matin \u00e0 Gare Union partiront six minutes plus t\u00f4t que pr\u00e9vu. Les trains du soir quitteront la Gare Union \u00e0 l'heure pr\u00e9vue, mais arriveront \u00e0 la gare GO de Milton six minutes plus tard. Veuillez planifier votre voyage sur gotransit.com/fr  ou https://www.triplinx.ca/fr. Merci de votre patience pendant cet important travail.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000392672",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-19 15:56:58",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "UN",
#                         "Name": null
#                     },
#                     {
#                         "Code": "KP",
#                         "Name": null
#                     },
#                     {
#                         "Code": "DI",
#                         "Name": null
#                     },
#                     {
#                         "Code": "CO",
#                         "Name": null
#                     },
#                     {
#                         "Code": "ER",
#                         "Name": null
#                     },
#                     {
#                         "Code": "SR",
#                         "Name": null
#                     },
#                     {
#                         "Code": "ME",
#                         "Name": null
#                     },
#                     {
#                         "Code": "LS",
#                         "Name": null
#                     },
#                     {
#                         "Code": "ML",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Temporary schedule change on Milton Line",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the station building/bus loop/kiss & ride to the tunnel is out of service. Platforms are still accessible by using the pedestrian bridge. Visit the Pickering GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le b\u00e2timent de la gare, la ceinture de trafic pour autobus et le d\u00e9barcad\u00e8re au tunnel est hors service. Les quais sont toujours accessibles en empruntant la passerelle pour pi\u00e9tons. Visitez la page de la gare GO de Pickering pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392957",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-20 23:09:11",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "PIN",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platform 1 and 2 is out of service. Customers who need this elevator should board the train at Erindale GO or Meadowvale GO. Visit the Streetsville GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel aux quais 1 et 2 est hors service. Les passagers qui ont besoin de cet ascenseur doivent monter dans le train \u00e0 la gare GO d\u2019Erindale ou de Meadowvale. Visitez la page de la gare GO de Streetsville pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392979",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000392584",
#                 "PostedDateTime": "2023-07-21 00:44:51",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "SR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There is no Lakeshore East train service this weekend due to construction. GO buses are running between Durham College Oshawa, Whitby, Ajax, and Pickering GO stations, then express to Union Station Bus Terminal. All other stations served by TTC. Learn more here.",
#                 "BodyFrench": "Il n\u2019y a pas de service de train sur la ligne Lakeshore Est ce week-end en raison des travaux de construction. Des autobus GO circulent entre les gares GO de Durham College Oshawa, Whitby, Ajax et Pickering, puis Express jusqu\u2019\u00e0 la station d\u2019autobus de la gare Union. Toutes les autres gares seront desservies par TTC. Pour en savoir plus, cliquez ici.",
#                 "Category": "Disruptions",
#                 "Code": "M0000393086",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-21 21:01:24",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Broadcast Message",
#                 "SubjectEnglish": "Temporary Service Changes",
#                 "SubjectFrench": "Modifications temporaires des services",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There is no Lakeshore East train service this weekend due to construction. GO buses are running between Durham College Oshawa, Whitby, Ajax, and Pickering GO stations, then express to Union Station Bus Terminal. All other stations served by TTC. Learn more here.",
#                 "BodyFrench": "Il n\u2019y a pas de service de train sur la ligne Lakeshore Est ce week-end en raison des travaux de construction. Des autobus GO circulent entre les gares GO de Durham College Oshawa, Whitby, Ajax et Pickering, puis Express jusqu\u2019\u00e0 la station d\u2019autobus de la gare Union. Toutes les autres gares seront desservies par TTC. Pour en savoir plus, cliquez ici.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393088",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-21 21:02:26",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Temporary Service Changes",
#                 "SubjectFrench": "Modifications temporaires des services",
#                 "Trips": []
#             }
#         ]
#     },
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:42:58"
#     }
# }

# %%
vechile_position='api/V1/UP/Gtfs/Feed/VehiclePosition'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{vechile_position}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230723-4038",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.7012749,
#                     "longitude": -79.6118,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1690166792,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:42:00",
#                     "trip_id": "20230723-4038"
#                 },
#                 "vehicle": {
#                     "id": "3002",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230723-4138",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6829224,
#                     "longitude": -79.61338,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1690166792,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:57:00",
#                     "trip_id": "20230723-4138"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230723-4237",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.696167,
#                     "longitude": -79.50501,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1690166792,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:30:00",
#                     "trip_id": "20230723-4237"
#                 },
#                 "vehicle": {
#                     "id": "1004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230723-4336",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6568565,
#                     "longitude": -79.450264,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "BL",
#                 "timestamp": 1690166792,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:27:00",
#                     "trip_id": "20230723-4336"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230723-4337",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6428757,
#                     "longitude": -79.3858643,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "BL",
#                 "timestamp": 1690166792,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230723",
#                     "start_time": "22:45:00",
#                     "trip_id": "20230723-4337"
#                 },
#                 "vehicle": {
#                     "id": "3005",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1690166794
#     }
# }

# %%
train_cancelled='api/V1/ServiceUpdate/Exceptions/Train'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{train_cancelled}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:51:18"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1157"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1158"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1111"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1164"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1165"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1166"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1119"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1162"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1324"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1123"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E8640Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3025"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1127"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3028"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1178"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3029"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1180"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3032"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1131"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3033"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1184"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1435"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1435Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
# ...
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1188"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3040Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1188Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1125"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1174"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "x1129"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1182"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E3432W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8125"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1190"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E1986W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1190Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E1037W"
#         }
#     ]
# }

# %%
bus_cancelled='api/V1/ServiceUpdate/Exceptions/Bus'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{bus_cancelled}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:52:26"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 07:35 - Union Station Bus Terminal 08:35",
#             "TripNumber": "90221"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 07:40 - Union Station Bus Terminal 08:40",
#             "TripNumber": "90223"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:05 - Union Station Bus Terminal 09:10",
#             "TripNumber": "90241"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:10 - Union Station Bus Terminal 09:15",
#             "TripNumber": "90243"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:35 - Union Station Bus Terminal 09:45",
#             "TripNumber": "90261"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:40 - Union Station Bus Terminal 09:50",
#             "TripNumber": "90263"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:05 - Union Station Bus Terminal 10:20",
#             "TripNumber": "90291"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:10 - Union Station Bus Terminal 10:25",
#             "TripNumber": "90293"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:35 - Union Station Bus Terminal 10:50",
#             "TripNumber": "90311"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:40 - Union Station Bus Terminal 10:55",
#             "TripNumber": "90313"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:05 - Union Station Bus Terminal 11:20",
#             "TripNumber": "90331"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:10 - Union Station Bus Terminal 11:25",
#             "TripNumber": "90333"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02652",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "West Harbour GO",
#                     "Order": 25,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Union Station Bus Terminal 07:10 - West Harbour GO 08:55",
#             "TripNumber": "18091"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:15 - Union Station Bus Terminal 11:30",
#             "TripNumber": "90335"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:35 - Union Station Bus Terminal 11:50",
#             "TripNumber": "90351"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:40 - Union Station Bus Terminal 11:55",
#             "TripNumber": "90353"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:45 - Union Station Bus Terminal 12:00",
#             "TripNumber": "90355"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:05 - Union Station Bus Terminal 12:20",
#             "TripNumber": "90371"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:10 - Union Station Bus Terminal 12:25",
#             "TripNumber": "90373"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:15 - Union Station Bus Terminal 12:30",
#             "TripNumber": "90375"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:35 - Union Station Bus Terminal 12:55",
#             "TripNumber": "90391"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:40 - Union Station Bus Terminal 13:00",
#             "TripNumber": "90393"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:45 - Union Station Bus Terminal 13:05",
#             "TripNumber": "90395"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:05 - Union Station Bus Terminal 13:30",
#             "TripNumber": "90411"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:10 - Union Station Bus Terminal 13:35",
#             "TripNumber": "90413"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:15 - Union Station Bus Terminal 13:40",
#             "TripNumber": "90415"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:35 - Union Station Bus Terminal 14:00",
#             "TripNumber": "90431"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:40 - Union Station Bus Terminal 14:05",
#             "TripNumber": "90433"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:45 - Union Station Bus Terminal 14:10",
#             "TripNumber": "90435"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 11:20 - Durham College Oshawa GO 12:40",
#             "TripNumber": "90332"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:58 - Trent University 14:48",
#             "TripNumber": "88480"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 11:45 - Durham College Oshawa GO 13:05",
#             "TripNumber": "90350"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:05 - Union Station Bus Terminal 14:30",
#             "TripNumber": "90451"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:10 - Union Station Bus Terminal 14:35",
#             "TripNumber": "90453"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:15 - Union Station Bus Terminal 14:40",
#             "TripNumber": "90455"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:35 - Union Station Bus Terminal 15:00",
#             "TripNumber": "90481"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:40 - Union Station Bus Terminal 15:05",
#             "TripNumber": "90483"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00159",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Durham College Oshawa GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02572",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St @ Thickson Ridge Power Cntr",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02698",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St. E. @ S Blair St.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00031",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Whitby GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 13:45 - Union Station Bus Terminal 15:10",
#             "TripNumber": "90485"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:05 - Union Station Bus Terminal 15:35",
#             "TripNumber": "90511"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:10 - Union Station Bus Terminal 15:40",
#             "TripNumber": "90513"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:15 - Union Station Bus Terminal 15:45",
#             "TripNumber": "90515"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:35 - Union Station Bus Terminal 16:05",
#             "TripNumber": "90541"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:40 - Union Station Bus Terminal 16:10",
#             "TripNumber": "90543"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:05 - Union Station Bus Terminal 16:35",
#             "TripNumber": "90571"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:10 - Union Station Bus Terminal 16:40",
#             "TripNumber": "90573"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:35 - Union Station Bus Terminal 17:05",
#             "TripNumber": "90601"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:40 - Union Station Bus Terminal 17:10",
#             "TripNumber": "90603"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00159",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Durham College Oshawa GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02572",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St @ Thickson Ridge Power Cntr",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02698",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St. E. @ S Blair St.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 16:35 - Union Station Bus Terminal 18:05",
#             "TripNumber": "90661"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 16:40 - Union Station Bus Terminal 18:10",
#             "TripNumber": "90663"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:05 - Union Station Bus Terminal 18:35",
#             "TripNumber": "90681"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:10 - Union Station Bus Terminal 18:40",
#             "TripNumber": "90683"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:35 - Union Station Bus Terminal 19:05",
#             "TripNumber": "90691"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:40 - Union Station Bus Terminal 19:10",
#             "TripNumber": "90693"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 18:05 - Union Station Bus Terminal 19:35",
#             "TripNumber": "90711"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 18:10 - Union Station Bus Terminal 19:40",
#             "TripNumber": "90713"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 18:35 - Union Station Bus Terminal 20:00",
#             "TripNumber": "90731"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 18:40 - Union Station Bus Terminal 20:05",
#             "TripNumber": "90733"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 19:05 - Union Station Bus Terminal 20:25",
#             "TripNumber": "90751"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 19:10 - Union Station Bus Terminal 20:30",
#             "TripNumber": "90753"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 19:35 - Union Station Bus Terminal 20:55",
#             "TripNumber": "90771"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 19:40 - Union Station Bus Terminal 21:00",
#             "TripNumber": "90773"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 20:05 - Union Station Bus Terminal 21:20",
#             "TripNumber": "90791"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 20:10 - Union Station Bus Terminal 21:25",
#             "TripNumber": "90793"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02674",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Hwy 407 Bus Terminal",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02728",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Hwy 407 Bus Terminal 19:10 - Hamilton GO Centre 21:10",
#             "TripNumber": "47711"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 20:35 - Union Station Bus Terminal 21:50",
#             "TripNumber": "90811"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 20:40 - Union Station Bus Terminal 21:55",
#             "TripNumber": "90813"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 21:05 - Union Station Bus Terminal 22:15",
#             "TripNumber": "90821"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 21:10 - Union Station Bus Terminal 22:20",
#             "TripNumber": "90823"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 21:35 - Union Station Bus Terminal 22:45",
#             "TripNumber": "90831"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 21:40 - Union Station Bus Terminal 22:50",
#             "TripNumber": "90833"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 22:05 - Union Station Bus Terminal 23:10",
#             "TripNumber": "90841"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 22:40 - Union Station Bus Terminal 23:40",
#             "TripNumber": "90851"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 23:10 - Union Station Bus Terminal 24:10",
#             "TripNumber": "90861"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 23:40 - Union Station Bus Terminal 24:40",
#             "TripNumber": "90871"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 13:00 - Union Station Bus Terminal 14:20",
#             "TripNumber": "16440"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 14:35 - Hamilton GO Centre 15:45",
#             "TripNumber": "16461"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 16:30 - Union Station Bus Terminal 17:50",
#             "TripNumber": "16640"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 18:05 - Hamilton GO Centre 19:15",
#             "TripNumber": "16661"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 17:00 - Union Station Bus Terminal 18:20",
#             "TripNumber": "16660"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 18:35 - Hamilton GO Centre 19:45",
#             "TripNumber": "16681"
#         }
#     ]
# }

# %%
all_cancelled='api/V1/ServiceUpdate/Exceptions/All'
params = {
    "key": key
}
base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'

# Run request
response = requests.get(f"{base_url}{all_cancelled}", params=params)
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the json (pretty printed)
    print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-07-23 22:53:42"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1157"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 07:35 - Union Station Bus Terminal 08:35",
#             "TripNumber": "90221"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 07:40 - Union Station Bus Terminal 08:40",
#             "TripNumber": "90223"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:05 - Union Station Bus Terminal 09:10",
#             "TripNumber": "90241"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:10 - Union Station Bus Terminal 09:15",
#             "TripNumber": "90243"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:35 - Union Station Bus Terminal 09:45",
#             "TripNumber": "90261"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 08:40 - Union Station Bus Terminal 09:50",
#             "TripNumber": "90263"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1158"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:05 - Union Station Bus Terminal 10:20",
#             "TripNumber": "90291"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:10 - Union Station Bus Terminal 10:25",
#             "TripNumber": "90293"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1111"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:35 - Union Station Bus Terminal 10:50",
#             "TripNumber": "90311"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 09:40 - Union Station Bus Terminal 10:55",
#             "TripNumber": "90313"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:05 - Union Station Bus Terminal 11:20",
#             "TripNumber": "90331"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:10 - Union Station Bus Terminal 11:25",
#             "TripNumber": "90333"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "02652",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "West Harbour GO",
#                     "Order": 25,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Union Station Bus Terminal 07:10 - West Harbour GO 08:55",
#             "TripNumber": "18091"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1164"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:15 - Union Station Bus Terminal 11:30",
#             "TripNumber": "90335"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:35 - Union Station Bus Terminal 11:50",
#             "TripNumber": "90351"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:40 - Union Station Bus Terminal 11:55",
#             "TripNumber": "90353"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 10:45 - Union Station Bus Terminal 12:00",
#             "TripNumber": "90355"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:05 - Union Station Bus Terminal 12:20",
#             "TripNumber": "90371"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:10 - Union Station Bus Terminal 12:25",
#             "TripNumber": "90373"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:15 - Union Station Bus Terminal 12:30",
#             "TripNumber": "90375"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1165"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:35 - Union Station Bus Terminal 12:55",
#             "TripNumber": "90391"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:40 - Union Station Bus Terminal 13:00",
#             "TripNumber": "90393"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 11:45 - Union Station Bus Terminal 13:05",
#             "TripNumber": "90395"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1166"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:05 - Union Station Bus Terminal 13:30",
#             "TripNumber": "90411"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:10 - Union Station Bus Terminal 13:35",
#             "TripNumber": "90413"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:15 - Union Station Bus Terminal 13:40",
#             "TripNumber": "90415"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:35 - Union Station Bus Terminal 14:00",
#             "TripNumber": "90431"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:40 - Union Station Bus Terminal 14:05",
#             "TripNumber": "90433"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:45 - Union Station Bus Terminal 14:10",
#             "TripNumber": "90435"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1119"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 11:20 - Durham College Oshawa GO 12:40",
#             "TripNumber": "90332"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 12:58 - Trent University 14:48",
#             "TripNumber": "88480"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 11:45 - Durham College Oshawa GO 13:05",
#             "TripNumber": "90350"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:05 - Union Station Bus Terminal 14:30",
#             "TripNumber": "90451"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:10 - Union Station Bus Terminal 14:35",
#             "TripNumber": "90453"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:15 - Union Station Bus Terminal 14:40",
#             "TripNumber": "90455"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:35 - Union Station Bus Terminal 15:00",
#             "TripNumber": "90481"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 13:40 - Union Station Bus Terminal 15:05",
#             "TripNumber": "90483"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00159",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Durham College Oshawa GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02572",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St @ Thickson Ridge Power Cntr",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02698",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St. E. @ S Blair St.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00031",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Whitby GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 13:45 - Union Station Bus Terminal 15:10",
#             "TripNumber": "90485"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:05 - Union Station Bus Terminal 15:35",
#             "TripNumber": "90511"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:10 - Union Station Bus Terminal 15:40",
#             "TripNumber": "90513"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1162"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E658Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:15 - Union Station Bus Terminal 15:45",
#             "TripNumber": "90515"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:35 - Union Station Bus Terminal 16:05",
#             "TripNumber": "90541"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 14:40 - Union Station Bus Terminal 16:10",
#             "TripNumber": "90543"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:05 - Union Station Bus Terminal 16:35",
#             "TripNumber": "90571"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:10 - Union Station Bus Terminal 16:40",
#             "TripNumber": "90573"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1324"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1123"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:35 - Union Station Bus Terminal 17:05",
#             "TripNumber": "90601"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 15:40 - Union Station Bus Terminal 17:10",
#             "TripNumber": "90603"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E8640Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3025"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00159",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Durham College Oshawa GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02572",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St @ Thickson Ridge Power Cntr",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02698",
#                     "ID": "",
#                     "IsCancelled": "1",
#                     "IsOverride": "0",
#                     "IsStopping": "0",
#                     "Name": "Victoria St. E. @ S Blair St.",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "Durham College Oshawa GO 16:35 - Union Station Bus Terminal 18:05",
#             "TripNumber": "90661"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 16:40 - Union Station Bus Terminal 18:10",
#             "TripNumber": "90663"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:05 - Union Station Bus Terminal 18:35",
#             "TripNumber": "90681"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:10 - Union Station Bus Terminal 18:40",
#             "TripNumber": "90683"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:35 - Union Station Bus Terminal 19:05",
#             "TripNumber": "90691"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 17:40 - Union Station Bus Terminal 19:10",
#             "TripNumber": "90693"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1127"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "BE",
#                     "ID": "26",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bramalea GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MA",
#                     "ID": "25",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Malton GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "WE",
#                     "ID": "23",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Weston GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "BL",
#                     "ID": "22",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Bloor GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X3028"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1178"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Durham College Oshawa GO 18:05 - Union Station Bus Terminal 19:35",
#             "TripNumber": "90711"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "0",
# ...
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E3040Q"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1188Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 13:00 - Union Station Bus Terminal 14:20",
#             "TripNumber": "16440"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 14:35 - Hamilton GO Centre 15:45",
#             "TripNumber": "16461"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 16:30 - Union Station Bus Terminal 17:50",
#             "TripNumber": "16640"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1125"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1174"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 18:05 - Hamilton GO Centre 19:15",
#             "TripNumber": "16661"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 17:00 - Union Station Bus Terminal 18:20",
#             "TripNumber": "16660"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 18:35 - Hamilton GO Centre 19:45",
#             "TripNumber": "16681"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "EX",
#                     "ID": "11",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Exhibition GO",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "MI",
#                     "ID": "10",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Mimico GO",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "LO",
#                     "ID": "9",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Long Branch GO",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "PO",
#                     "ID": "8",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Port Credit GO",
#                     "Order": 5,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "CL",
#                     "ID": "7",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Clarkson GO",
#                     "Order": 6,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 7,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "x1129"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1182"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E3432W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E8125"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "OA",
#                     "ID": "6",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Oakville GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "X1190"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E1986W"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "UN",
#                     "ID": "907",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "T"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "E1190Q"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "",
#             "TripNumber": "E1037W"
#         }
#     ]
# }
