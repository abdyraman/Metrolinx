# %%
# Dependencies
from pymongo import MongoClient
import requests
import json
from pprint import pprint

# %%
# Import the API key
from config import key

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the met database to a variable name
db = mongo['metrolinx']
# assign the collection to a variable
trains = db['trains']
buses=db['buses']
trip_updates=db['trip_updates']
service_messages=db['service_messages']
vechile_position=db['vechile_position']
train_cancelled=db['train_cancelled']
bus_cancelled=db['bus_cancelled']
all_cancelled=db['all_cancelled']

# %%
def get_data(trains_endpoint):
    base_url = 'http://api.openmetrolinx.com/OpenDataAPI/'
    params = {
    "key": key
}

    # Run request
    response = requests.get(f"{base_url}{trains_endpoint}", params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Return the JSON response
        return response.json()
    else:
        # Raise an exception with the status code if the request failed
        response.raise_for_status()

# %%
trains_endpoint = "api/V1/ServiceataGlance/Trains/All"

try:
    train_data = get_data(trains_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trains_collection = db['trains']
    trains_collection.insert_one(train_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-06 14:44:25"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 217.0,
#                 "DelaySeconds": 90,
#                 "Display": "LW - Aldershot GO",
#                 "EndTime": "15:22",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "AL",
#                 "Latitude": 43.554672,
#                 "LineCode": "LW",
#                 "Longitude": -79.588614,
#                 "ModifiedDate": "2023-08-06 14:43:50",
#                 "NextStopCode": "POCL",
#                 "PrevStopCode": "PO",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "14:14",
#                 "TripNumber": "1021",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 38.0,
#                 "DelaySeconds": 90,
#                 "Display": "LW - Union Station",
#                 "EndTime": "15:15",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.550924,
#                 "LineCode": "LW",
#                 "Longitude": -79.592614,
#                 "ModifiedDate": "2023-08-06 14:43:50",
#                 "NextStopCode": "PO",
#                 "PrevStopCode": "POCL",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "14:04",
#                 "TripNumber": "1022",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "WATE",
#                 "Cars": "12",
#                 "Course": 0.0,
#                 "DelaySeconds": -1215,
#                 "Display": "LW - Union Station",
#                 "EndTime": "16:15",
#                 "FirstStopCode": "AL",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.314095,
#                 "LineCode": "LW",
#                 "Longitude": -79.853153,
#                 "ModifiedDate": "2023-08-06 14:43:46",
#                 "NextStopCode": "WATE",
#                 "PrevStopCode": "AL",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "15:04",
#                 "TripNumber": "1024",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 229.0,
#                 "DelaySeconds": 62,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "15:05",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.343476,
#                 "LineCode": "LW",
#                 "Longitude": -79.805501,
#                 "ModifiedDate": "2023-08-06 14:43:50",
#                 "NextStopCode": "BU",
#                 "PrevStopCode": "BURE",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "13:44",
#                 "TripNumber": "1719",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "UN",
#                 "Cars": "12",
#                 "Course": 72.0,
#                 "DelaySeconds": -202,
#                 "Display": "LW - Union Station",
#                 "EndTime": "14:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.644792,
#                 "LineCode": "LW",
#                 "Longitude": -79.380253,
#                 "ModifiedDate": "2023-08-06 14:41:39",
#                 "NextStopCode": "UN",
#                 "PrevStopCode": "JOHN",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "13:23",
#                 "TripNumber": "1720",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "12",
#                 "Course": 200.0,
#                 "DelaySeconds": -13,
#                 "Display": "LW - West Harbour GO",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "WR",
#                 "Latitude": 43.645006,
#                 "LineCode": "LW",
#                 "Longitude": -79.377958,
#                 "ModifiedDate": "2023-08-06 14:43:48",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "14:44",
#                 "TripNumber": "1721",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 49.0,
#                 "DelaySeconds": 39,
#                 "Display": "LW - Union Station",
#                 "EndTime": "15:45",
#                 "FirstStopCode": "WR",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.349522,
#                 "LineCode": "LW",
#                 "Longitude": -79.795545,
#                 "ModifiedDate": "2023-08-06 14:43:49",
#                 "NextStopCode": "AP",
#                 "PrevStopCode": "BURE",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "14:23",
#                 "TripNumber": "1722",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 101.0,
#                 "DelaySeconds": -2,
#                 "Display": "LW - Niagara Falls GO (VIA Station)",
#                 "EndTime": "15:21",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "NI",
#                 "Latitude": 43.164367,
#                 "LineCode": "LW",
#                 "Longitude": -79.364857,
#                 "ModifiedDate": "2023-08-06 14:43:50",
#                 "NextStopCode": "JR",
#                 "PrevStopCode": "HBJO",
#                 "RouteNumber": "LW   ",
#                 "StartTime": "13:03",
#                 "TripNumber": "1969",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "BOVA",
#                 "Cars": "6",
#                 "Course": 253.0,
#                 "DelaySeconds": -312,
#                 "Display": "GT - Union Station",
#                 "EndTime": "15:36",
#                 "FirstStopCode": "MO",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.67531,
#                 "LineCode": "GT",
#                 "Longitude": -79.820746,
#                 "ModifiedDate": "2023-08-06 14:43:49",
#                 "NextStopCode": "BOVA",
#                 "PrevStopCode": "MO",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "14:49",
#                 "TripNumber": "3422",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "6",
#                 "Course": 0.0,
#                 "DelaySeconds": -441,
#                 "Display": "GT - Mount Pleasant GO",
#                 "EndTime": "15:39",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "MO",
#                 "Latitude": 43.645008,
#                 "LineCode": "GT",
#                 "Longitude": -79.377877,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "GT   ",
#                 "StartTime": "14:51",
#                 "TripNumber": "3521",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "JOHN",
#                 "Cars": "-",
#                 "Course": 19.0,
#                 "DelaySeconds": -550,
#                 "Display": "BR - Allandale Waterfront GO",
#                 "EndTime": "16:37",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "AD",
#                 "Latitude": 43.645259,
#                 "LineCode": "BR",
#                 "Longitude": -79.379008,
#                 "ModifiedDate": "2023-08-06 14:43:51",
#                 "NextStopCode": "JOHN",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "BR   ",
#                 "StartTime": "14:53",
#                 "TripNumber": "6921",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 96.0,
#                 "DelaySeconds": 29,
#                 "Display": "BR - Union Station",
#                 "EndTime": "15:48",
#                 "FirstStopCode": "AD",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 44.088068,
#                 "LineCode": "BR",
#                 "Longitude": -79.465425,
#                 "ModifiedDate": "2023-08-06 14:43:50",
#                 "NextStopCode": "EA",
#                 "PrevStopCode": "HOLL",
#                 "RouteNumber": "BR   ",
#                 "StartTime": "14:06",
#                 "TripNumber": "6922",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 43.0,
#                 "DelaySeconds": 29,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "15:20",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.747515,
#                 "LineCode": "LE",
#                 "Longitude": -79.221287,
#                 "ModifiedDate": "2023-08-06 14:43:49",
#                 "NextStopCode": "GU",
#                 "PrevStopCode": "EG",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "14:20",
#                 "TripNumber": "9020",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "SC",
#                 "Cars": "12",
#                 "Course": 228.0,
#                 "DelaySeconds": -13,
#                 "Display": "LE - Union Station",
#                 "EndTime": "15:09",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": false,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.740443,
#                 "LineCode": "LE",
#                 "Longitude": -79.230586,
#                 "ModifiedDate": "2023-08-06 14:43:49",
#                 "NextStopCode": "SC",
#                 "PrevStopCode": "EG",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "14:04",
#                 "TripNumber": "9023",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "VICT",
#                 "Cars": "12",
#                 "Course": 103.0,
#                 "DelaySeconds": 47,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "14:50",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": true,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.864501,
#                 "LineCode": "LE",
#                 "Longitude": -78.936473,
#                 "ModifiedDate": "2023-08-06 14:43:48",
#                 "NextStopCode": "VICT",
#                 "PrevStopCode": "WH",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "13:50",
#                 "TripNumber": "9218",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "SCOT",
#                 "Cars": "12",
#                 "Course": 89.0,
#                 "DelaySeconds": -372,
#                 "Display": "LE - Durham College Oshawa GO",
#                 "EndTime": "15:50",
#                 "FirstStopCode": "UN",
#                 "IsInMotion": false,
#                 "LastStopCode": "OS",
#                 "Latitude": 43.645111,
#                 "LineCode": "LE",
#                 "Longitude": -79.378401,
#                 "ModifiedDate": "2023-08-06 14:43:49",
#                 "NextStopCode": "SCOT",
#                 "PrevStopCode": "UN",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "14:50",
#                 "TripNumber": "9220",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "Cars": "12",
#                 "Course": 252.0,
#                 "DelaySeconds": 10,
#                 "Display": "LE - Union Station",
#                 "EndTime": "15:39",
#                 "FirstStopCode": "OS",
#                 "IsInMotion": true,
#                 "LastStopCode": "UN",
#                 "Latitude": 43.859783,
#                 "LineCode": "LE",
#                 "Longitude": -78.99021,
#                 "ModifiedDate": "2023-08-06 14:43:47",
#                 "NextStopCode": "HARW",
#                 "PrevStopCode": "HENRCP",
#                 "RouteNumber": "LE   ",
#                 "StartTime": "14:34",
#                 "TripNumber": "9223",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
buses_endpoint='api/V1/ServiceataGlance/Buses/All'
try:
    buses_data = get_data(buses_endpoint)
    # Print the JSON response (pretty printed)
    print(json.dumps(buses_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    buses_collection = db['buses']
    buses_collection.insert_one(buses_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-06 14:44:26"
#     },
#     "Trips": {
#         "Trip": [
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 69.0,
#                 "DelaySeconds": 2592,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "14:39",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.17895,
#                 "LineCode": "12",
#                 "Longitude": -79.2706,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02646",
#                 "PrevStopCode": "02621",
#                 "RouteNumber": "12   ",
#                 "StartTime": "12:39",
#                 "TripNumber": "12391",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02408",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 2371,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "14:14",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": false,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.097367,
#                 "LineCode": "12",
#                 "Longitude": -79.0853,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "00819",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "12:54",
#                 "TripNumber": "12393",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 108.0,
#                 "DelaySeconds": 1272,
#                 "Display": "12  - Niagara Falls",
#                 "EndTime": "15:39",
#                 "FirstStopCode": "00139",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.227267,
#                 "LineCode": "12",
#                 "Longitude": -79.679383,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02621",
#                 "PrevStopCode": "02730",
#                 "RouteNumber": "12   ",
#                 "StartTime": "13:39",
#                 "TripNumber": "12421",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 109.0,
#                 "DelaySeconds": 1798,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "15:14",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.225633,
#                 "LineCode": "12",
#                 "Longitude": -79.67255,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "00819",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "13:54",
#                 "TripNumber": "12423",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 15.0,
#                 "DelaySeconds": 243,
#                 "Display": "12  - Burlington Carpool",
#                 "EndTime": "15:15",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": true,
#                 "LastStopCode": "00139",
#                 "Latitude": 43.245167,
#                 "LineCode": "12",
#                 "Longitude": -79.757267,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": "02730",
#                 "RouteNumber": "12   ",
#                 "StartTime": "13:15",
#                 "TripNumber": "12480",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 288.0,
#                 "DelaySeconds": 831,
#                 "Display": "12B - Burlington GO",
#                 "EndTime": "15:02",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": true,
#                 "LastStopCode": "00177",
#                 "Latitude": 43.1977,
#                 "LineCode": "12",
#                 "Longitude": -79.556817,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00177",
#                 "PrevStopCode": "02405",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "13:57",
#                 "TripNumber": "12482",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02621",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -691,
#                 "Display": "12  - Burlington Carpool",
#                 "EndTime": "16:15",
#                 "FirstStopCode": "02408",
#                 "IsInMotion": false,
#                 "LastStopCode": "00139",
#                 "Latitude": 43.178567,
#                 "LineCode": "12",
#                 "Longitude": -79.245333,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "02621",
#                 "PrevStopCode": "02646",
#                 "RouteNumber": "12   ",
#                 "StartTime": "14:15",
#                 "TripNumber": "12530",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 193.0,
#                 "DelaySeconds": 930,
#                 "Display": "15 - Brantford Term",
#                 "EndTime": "15:01",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": true,
#                 "LastStopCode": "02617",
#                 "Latitude": 43.2352,
#                 "LineCode": "15",
#                 "Longitude": -79.948917,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02610",
#                 "PrevStopCode": "02619",
#                 "RouteNumber": "15   ",
#                 "StartTime": "14:01",
#                 "TripNumber": "15331",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 80.0,
#                 "DelaySeconds": 109,
#                 "Display": "15 - Aldershot GO",
#                 "EndTime": "15:20",
#                 "FirstStopCode": "02617",
#                 "IsInMotion": true,
#                 "LastStopCode": "00180",
#                 "Latitude": 43.193717,
#                 "LineCode": "15",
#                 "Longitude": -80.094133,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02185",
#                 "PrevStopCode": "02608",
#                 "RouteNumber": "15   ",
#                 "StartTime": "14:25",
#                 "TripNumber": "15610",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 172.0,
#                 "DelaySeconds": -1098,
#                 "Display": "16  - Union Station",
#                 "EndTime": "14:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.64325,
#                 "LineCode": "16",
#                 "Longitude": -79.376433,
#                 "ModifiedDate": "2023-08-06 14:31:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "13:30",
#                 "TripNumber": "16460",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 269.0,
#                 "DelaySeconds": 348,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "15:45",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.637533,
#                 "LineCode": "16",
#                 "Longitude": -79.408833,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": "00732",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "16   ",
#                 "StartTime": "14:35",
#                 "TripNumber": "16461",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 72.0,
#                 "DelaySeconds": -1465,
#                 "Display": "16  - Union Station",
#                 "EndTime": "15:20",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.624767,
#                 "LineCode": "16",
#                 "Longitude": -79.492667,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "14:00",
#                 "TripNumber": "16480",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01010",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -380,
#                 "Display": "16  - Hamilton GO",
#                 "EndTime": "16:15",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.644083,
#                 "LineCode": "16",
#                 "Longitude": -79.3777,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01010",
#                 "PrevStopCode": null,
#                 "RouteNumber": "16   ",
#                 "StartTime": "15:05",
#                 "TripNumber": "16481",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 294.0,
#                 "DelaySeconds": 387,
#                 "Display": "16  - Union Station",
#                 "EndTime": "15:50",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.262217,
#                 "LineCode": "16",
#                 "Longitude": -79.88775,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00178",
#                 "RouteNumber": "16   ",
#                 "StartTime": "14:30",
#                 "TripNumber": "16520",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 108.0,
#                 "DelaySeconds": 246,
#                 "Display": "18  - Hamilton GO",
#                 "EndTime": "14:47",
#                 "FirstStopCode": "00180",
#                 "IsInMotion": true,
#                 "LastStopCode": "00141",
#                 "Latitude": 43.25645,
#                 "LineCode": "18",
#                 "Longitude": -79.874433,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00141",
#                 "PrevStopCode": "01007",
#                 "RouteNumber": "18   ",
#                 "StartTime": "14:27",
#                 "TripNumber": "18331",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 172,
#                 "Display": "18  - Aldershot GO",
#                 "EndTime": "14:54",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00180",
#                 "Latitude": 43.259117,
#                 "LineCode": "18",
#                 "Longitude": -79.87785,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01004",
#                 "PrevStopCode": "01001",
#                 "RouteNumber": "18   ",
#                 "StartTime": "14:37",
#                 "TripNumber": "18590",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 215.0,
#                 "DelaySeconds": -203,
#                 "Display": "19 - Square One",
#                 "EndTime": "14:50",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.617433,
#                 "LineCode": "19",
#                 "Longitude": -79.6279,
#                 "ModifiedDate": "2023-08-06 14:42:20",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02658",
#                 "RouteNumber": "19   ",
#                 "StartTime": "13:50",
#                 "TripNumber": "19431",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 77.0,
#                 "DelaySeconds": -254,
#                 "Display": "19 - Finch Terminal",
#                 "EndTime": "15:20",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.718883,
#                 "LineCode": "19",
#                 "Longitude": -79.49695,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": "00019",
#                 "PrevStopCode": "02208",
#                 "RouteNumber": "19   ",
#                 "StartTime": "14:15",
#                 "TripNumber": "19450",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02709",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Square One",
#                 "EndTime": "15:50",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.782217,
#                 "LineCode": "19",
#                 "Longitude": -79.414917,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02709",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "14:50",
#                 "TripNumber": "19471",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02659",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "19 - Finch Terminal",
#                 "EndTime": "16:25",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.594867,
#                 "LineCode": "19",
#                 "Longitude": -79.6497,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02659",
#                 "PrevStopCode": null,
#                 "RouteNumber": "19   ",
#                 "StartTime": "15:15",
#                 "TripNumber": "19490",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 311.0,
#                 "DelaySeconds": -101,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "14:49",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": true,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.59635,
#                 "LineCode": "21",
#                 "Longitude": -79.782417,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "01482",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "13:54",
#                 "TripNumber": "21443",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 134.0,
#                 "DelaySeconds": -37,
#                 "Display": "21A - Oakville GO",
#                 "EndTime": "14:50",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": true,
#                 "LastStopCode": "00137",
#                 "Latitude": 43.467333,
#                 "LineCode": "21",
#                 "Longitude": -79.69145,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01729",
#                 "PrevStopCode": "00939",
#                 "RouteNumber": "21A  ",
#                 "StartTime": "14:10",
#                 "TripNumber": "21450",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 270,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "14:58",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": false,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.562167,
#                 "LineCode": "21",
#                 "Longitude": -79.7115,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02788",
#                 "PrevStopCode": "01447",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "14:08",
#                 "TripNumber": "21452",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 246,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "15:05",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": false,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.597533,
#                 "LineCode": "21",
#                 "Longitude": -79.64055,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02775",
#                 "PrevStopCode": "00132",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "14:27",
#                 "TripNumber": "21454",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -72,
#                 "Display": "21A - Milton GO",
#                 "EndTime": "15:14",
#                 "FirstStopCode": "00137",
#                 "IsInMotion": false,
#                 "LastStopCode": "00194",
#                 "Latitude": 43.487083,
#                 "LineCode": "21",
#                 "Longitude": -79.718383,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01435",
#                 "PrevStopCode": "01728",
#                 "RouteNumber": "21A  ",
#                 "StartTime": "14:31",
#                 "TripNumber": "21461",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01241",
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": 215,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "15:19",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": true,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.551733,
#                 "LineCode": "21",
#                 "Longitude": -79.700717,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01241",
#                 "PrevStopCode": "00181",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "14:24",
#                 "TripNumber": "21463",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 196.0,
#                 "DelaySeconds": -20,
#                 "Display": "21C - Erindale GO",
#                 "EndTime": "14:55",
#                 "FirstStopCode": "02775",
#                 "IsInMotion": true,
#                 "LastStopCode": "00189",
#                 "Latitude": 43.59395,
#                 "LineCode": "21",
#                 "Longitude": -79.6508,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01363",
#                 "PrevStopCode": "00133",
#                 "RouteNumber": "21C  ",
#                 "StartTime": "14:17",
#                 "TripNumber": "21465",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 239,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "15:28",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": false,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.597017,
#                 "LineCode": "21",
#                 "Longitude": -79.784383,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00191",
#                 "PrevStopCode": "00341",
#                 "RouteNumber": "21B  ",
#                 "StartTime": "14:38",
#                 "TripNumber": "21472",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02739",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "15:35",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": false,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.567917,
#                 "LineCode": "21",
#                 "Longitude": -79.668217,
#                 "ModifiedDate": "2023-08-06 14:42:39",
#                 "NextStopCode": "02739",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21C  ",
#                 "StartTime": "14:57",
#                 "TripNumber": "21474",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02215",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21B - Lisgar GO",
#                 "EndTime": "15:49",
#                 "FirstStopCode": "00181",
#                 "IsInMotion": false,
#                 "LastStopCode": "00341",
#                 "Latitude": 43.512917,
#                 "LineCode": "21",
#                 "Longitude": -79.63295,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02215",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21B  ",
#                 "StartTime": "14:54",
#                 "TripNumber": "21483",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00891",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21A - Oakville GO",
#                 "EndTime": "15:50",
#                 "FirstStopCode": "00194",
#                 "IsInMotion": false,
#                 "LastStopCode": "00137",
#                 "Latitude": 43.524033,
#                 "LineCode": "21",
#                 "Longitude": -79.8677,
#                 "ModifiedDate": "2023-08-06 14:41:19",
#                 "NextStopCode": "00891",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21A  ",
#                 "StartTime": "15:10",
#                 "TripNumber": "21490",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02739",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21C - Port Credit GO",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "00189",
#                 "IsInMotion": false,
#                 "LastStopCode": "02775",
#                 "Latitude": 43.56755,
#                 "LineCode": "21",
#                 "Longitude": -79.668033,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02739",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21C  ",
#                 "StartTime": "15:27",
#                 "TripNumber": "21494",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01483",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "21B - Clarkson GO",
#                 "EndTime": "16:28",
#                 "FirstStopCode": "00341",
#                 "IsInMotion": false,
#                 "LastStopCode": "00181",
#                 "Latitude": 43.591467,
#                 "LineCode": "21",
#                 "Longitude": -79.788133,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01483",
#                 "PrevStopCode": null,
#                 "RouteNumber": "21B  ",
#                 "StartTime": "15:38",
#                 "TripNumber": "21522",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 355.0,
#                 "DelaySeconds": 664,
#                 "Display": "25L - U of Waterloo",
#                 "EndTime": "15:15",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.409367,
#                 "LineCode": "25",
#                 "Longitude": -80.328267,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": "02148",
#                 "PrevStopCode": "02605",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "13:20",
#                 "TripNumber": "25411",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 267.0,
#                 "DelaySeconds": 270,
#                 "Display": "25C - U of Waterloo",
#                 "EndTime": "15:10",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.415,
#                 "LineCode": "25",
#                 "Longitude": -80.305917,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02800",
#                 "PrevStopCode": "00133",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "13:55",
#                 "TripNumber": "25433",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -93,
#                 "Display": "25L - U of Waterloo",
#                 "EndTime": "16:15",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.57295,
#                 "LineCode": "25",
#                 "Longitude": -79.831383,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02151",
#                 "PrevStopCode": "02635",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "14:20",
#                 "TripNumber": "25451",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "02148",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25C - U of Waterloo",
#                 "EndTime": "16:10",
#                 "FirstStopCode": "00133",
#                 "IsInMotion": false,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.5953,
#                 "LineCode": "25",
#                 "Longitude": -79.648617,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "02148",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25C  ",
#                 "StartTime": "14:55",
#                 "TripNumber": "25473",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 65.0,
#                 "DelaySeconds": -22,
#                 "Display": "25L - Square One",
#                 "EndTime": "15:30",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.523817,
#                 "LineCode": "25",
#                 "Longitude": -79.929933,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02812",
#                 "PrevStopCode": "00337",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "13:35",
#                 "TripNumber": "25510",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 76.0,
#                 "DelaySeconds": -238,
#                 "Display": "25C - Square One",
#                 "EndTime": "15:35",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.44805,
#                 "LineCode": "25",
#                 "Longitude": -80.17515,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "25C  ",
#                 "StartTime": "14:15",
#                 "TripNumber": "25542",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 78.0,
#                 "DelaySeconds": -3,
#                 "Display": "25L - Square One",
#                 "EndTime": "16:30",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.473333,
#                 "LineCode": "25",
#                 "Longitude": -80.486767,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": "02150",
#                 "PrevStopCode": "02153",
#                 "RouteNumber": "25L  ",
#                 "StartTime": "14:35",
#                 "TripNumber": "25570",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02153",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "25L - Square One",
#                 "EndTime": "17:30",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": false,
#                 "LastStopCode": "00132",
#                 "Latitude": 43.474467,
#                 "LineCode": "25",
#                 "Longitude": -80.540433,
#                 "ModifiedDate": "2023-08-06 14:40:59",
#                 "NextStopCode": "02153",
#                 "PrevStopCode": null,
#                 "RouteNumber": "25L  ",
#                 "StartTime": "15:35",
#                 "TripNumber": "25630",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "01648",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -682,
#                 "Display": "27F - Finch Terminal",
#                 "EndTime": "15:15",
#                 "FirstStopCode": "00129",
#                 "IsInMotion": false,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.724967,
#                 "LineCode": "27",
#                 "Longitude": -79.448983,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01648",
#                 "PrevStopCode": "00022",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "14:00",
#                 "TripNumber": "27440",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 211.0,
#                 "DelaySeconds": 103,
#                 "Display": "27F - Meadowvale GO",
#                 "EndTime": "15:40",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": true,
#                 "LastStopCode": "00129",
#                 "Latitude": 43.748333,
#                 "LineCode": "27",
#                 "Longitude": -79.41625,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00020",
#                 "PrevStopCode": "01647",
#                 "RouteNumber": "27F  ",
#                 "StartTime": "14:30",
#                 "TripNumber": "27461",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 65.0,
#                 "DelaySeconds": -204,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "14:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": true,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.544867,
#                 "LineCode": "29",
#                 "Longitude": -80.246617,
#                 "ModifiedDate": "2023-08-06 14:41:19",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00201",
#                 "RouteNumber": "29   ",
#                 "StartTime": "13:00",
#                 "TripNumber": "29411",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 299.0,
#                 "DelaySeconds": 306,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "15:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": true,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.531417,
#                 "LineCode": "29",
#                 "Longitude": -79.731083,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "00337",
#                 "PrevStopCode": "02635",
#                 "RouteNumber": "29   ",
#                 "StartTime": "14:00",
#                 "TripNumber": "29451",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 40.0,
#                 "DelaySeconds": -55,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "15:25",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": true,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.550767,
#                 "LineCode": "29",
#                 "Longitude": -79.701883,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "00132",
#                 "PrevStopCode": "02636",
#                 "RouteNumber": "29   ",
#                 "StartTime": "13:30",
#                 "TripNumber": "29480",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02660",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "29 - Guelph Central GO",
#                 "EndTime": "16:45",
#                 "FirstStopCode": "02778",
#                 "IsInMotion": false,
#                 "LastStopCode": "02519",
#                 "Latitude": 43.635533,
#                 "LineCode": "29",
#                 "Longitude": -79.537667,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02660",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "15:00",
#                 "TripNumber": "29501",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01708",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -101,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "16:25",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": false,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.529567,
#                 "LineCode": "29",
#                 "Longitude": -80.225467,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "01708",
#                 "PrevStopCode": "02519",
#                 "RouteNumber": "29   ",
#                 "StartTime": "14:30",
#                 "TripNumber": "29540",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "00201",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -81,
#                 "Display": "29 - Kipling Bus Terminal",
#                 "EndTime": "17:25",
#                 "FirstStopCode": "02519",
#                 "IsInMotion": false,
#                 "LastStopCode": "02778",
#                 "Latitude": 43.54485,
#                 "LineCode": "29",
#                 "Longitude": -80.246533,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00201",
#                 "PrevStopCode": null,
#                 "RouteNumber": "29   ",
#                 "StartTime": "15:30",
#                 "TripNumber": "29600",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 43.0,
#                 "DelaySeconds": 434,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "14:47",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.652517,
#                 "LineCode": "30",
#                 "Longitude": -79.717617,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00200",
#                 "RouteNumber": "30   ",
#                 "StartTime": "13:12",
#                 "TripNumber": "30400",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 295.0,
#                 "DelaySeconds": 655,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "15:05",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.4341,
#                 "LineCode": "30",
#                 "Longitude": -80.449833,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02531",
#                 "PrevStopCode": "02587",
#                 "RouteNumber": "30   ",
#                 "StartTime": "13:35",
#                 "TripNumber": "30411",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 58.0,
#                 "DelaySeconds": 240,
#                 "Display": "30 - Bramalea GO",
#                 "EndTime": "15:47",
#                 "FirstStopCode": "02799",
#                 "IsInMotion": true,
#                 "LastStopCode": "08041",
#                 "Latitude": 43.4039,
#                 "LineCode": "30",
#                 "Longitude": -80.373267,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00200",
#                 "PrevStopCode": "02204",
#                 "RouteNumber": "30   ",
#                 "StartTime": "14:12",
#                 "TripNumber": "30440",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 224.0,
#                 "DelaySeconds": -39,
#                 "Display": "30 - U of Waterloo",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "02728",
#                 "IsInMotion": true,
#                 "LastStopCode": "02800",
#                 "Latitude": 43.6418,
#                 "LineCode": "30",
#                 "Longitude": -79.7363,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02587",
#                 "PrevStopCode": "02728",
#                 "RouteNumber": "30   ",
#                 "StartTime": "14:35",
#                 "TripNumber": "30451",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 282,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "14:55",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": false,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.673717,
#                 "LineCode": "33",
#                 "Longitude": -79.7438,
#                 "ModifiedDate": "2023-08-06 14:00:40",
#                 "NextStopCode": "00223",
#                 "PrevStopCode": "01317",
#                 "RouteNumber": "33   ",
#                 "StartTime": "12:10",
#                 "TripNumber": "33360",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 133.0,
#                 "DelaySeconds": 570,
#                 "Display": "33 - York Mills Term",
#                 "EndTime": "16:55",
#                 "FirstStopCode": "00201",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.613033,
#                 "LineCode": "33",
#                 "Longitude": -80.13595,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02808",
#                 "PrevStopCode": "00860",
#                 "RouteNumber": "33   ",
#                 "StartTime": "14:10",
#                 "TripNumber": "33440",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 316.0,
#                 "DelaySeconds": 63,
#                 "Display": "33 - U of Guelph",
#                 "EndTime": "16:20",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "00201",
#                 "Latitude": 43.700483,
#                 "LineCode": "33",
#                 "Longitude": -79.779467,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02712",
#                 "PrevStopCode": "01454",
#                 "RouteNumber": "33   ",
#                 "StartTime": "13:35",
#                 "TripNumber": "33451",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 74.0,
#                 "DelaySeconds": -347,
#                 "Display": "36B - York Mills Term",
#                 "EndTime": "15:05",
#                 "FirstStopCode": "02827",
#                 "IsInMotion": true,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.725983,
#                 "LineCode": "36",
#                 "Longitude": -79.465517,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00011",
#                 "PrevStopCode": "00022",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "14:10",
#                 "TripNumber": "36420",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 248.0,
#                 "DelaySeconds": 146,
#                 "Display": "36B - Bramalea Term",
#                 "EndTime": "15:10",
#                 "FirstStopCode": "00011",
#                 "IsInMotion": true,
#                 "LastStopCode": "02827",
#                 "Latitude": 43.7108,
#                 "LineCode": "36",
#                 "Longitude": -79.5494,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "01165",
#                 "PrevStopCode": "00020",
#                 "RouteNumber": "36B  ",
#                 "StartTime": "14:20",
#                 "TripNumber": "36451",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "01185",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "36B - York Mills Term",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "02827",
#                 "IsInMotion": false,
#                 "LastStopCode": "00011",
#                 "Latitude": 43.721167,
#                 "LineCode": "36",
#                 "Longitude": -79.719083,
#                 "ModifiedDate": "2023-08-06 14:43:20",
#                 "NextStopCode": "01185",
#                 "PrevStopCode": null,
#                 "RouteNumber": "36B  ",
#                 "StartTime": "15:10",
#                 "TripNumber": "36460",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 358.0,
#                 "DelaySeconds": 662,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "14:55",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": true,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.749383,
#                 "LineCode": "40",
#                 "Longitude": -79.629767,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02771",
#                 "PrevStopCode": "00311",
#                 "RouteNumber": "40   ",
#                 "StartTime": "13:10",
#                 "TripNumber": "40410",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 88,
#                 "Display": "40 - Richmond Hill Ctr",
#                 "EndTime": "15:25",
#                 "FirstStopCode": "00141",
#                 "IsInMotion": false,
#                 "LastStopCode": "00350",
#                 "Latitude": 43.663767,
#                 "LineCode": "40",
#                 "Longitude": -79.590267,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00311",
#                 "PrevStopCode": "02661",
#                 "RouteNumber": "40   ",
#                 "StartTime": "13:40",
#                 "TripNumber": "40420",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 217.0,
#                 "DelaySeconds": 182,
#                 "Display": "40 - Hamilton GO",
#                 "EndTime": "15:35",
#                 "FirstStopCode": "00350",
#                 "IsInMotion": true,
# ...
#                 "LineCode": "71",
#                 "Longitude": -79.3763,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02141",
#                 "RouteNumber": "71E  ",
#                 "StartTime": "13:45",
#                 "TripNumber": "71450",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 72.0,
#                 "DelaySeconds": -457,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "15:18",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.847883,
#                 "LineCode": "71",
#                 "Longitude": -79.317,
#                 "ModifiedDate": "2023-08-06 14:42:59",
#                 "NextStopCode": "00128",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "71E  ",
#                 "StartTime": "14:13",
#                 "TripNumber": "71451",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 344.0,
#                 "DelaySeconds": -443,
#                 "Display": "71C - Old Elm GO",
#                 "EndTime": "15:48",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": true,
#                 "LastStopCode": "00352",
#                 "Latitude": 43.826067,
#                 "LineCode": "71",
#                 "Longitude": -79.362833,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00128",
#                 "PrevStopCode": "02300",
#                 "RouteNumber": "71C  ",
#                 "StartTime": "14:18",
#                 "TripNumber": "71461",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": "02144",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 36,
#                 "Display": "71E - Mount Joy GO",
#                 "EndTime": "15:48",
#                 "FirstStopCode": "02300",
#                 "IsInMotion": false,
#                 "LastStopCode": "00121",
#                 "Latitude": 43.64445,
#                 "LineCode": "71",
#                 "Longitude": -79.37775,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02144",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71E  ",
#                 "StartTime": "14:43",
#                 "TripNumber": "71471",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 70.0,
#                 "DelaySeconds": 155,
#                 "Display": "71  - Union Station",
#                 "EndTime": "15:20",
#                 "FirstStopCode": "00302",
#                 "IsInMotion": true,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.853317,
#                 "LineCode": "71",
#                 "Longitude": -79.309017,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02141",
#                 "RouteNumber": "71   ",
#                 "StartTime": "13:30",
#                 "TripNumber": "71480",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": "00974",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "71C - Union Station",
#                 "EndTime": "16:20",
#                 "FirstStopCode": "00352",
#                 "IsInMotion": false,
#                 "LastStopCode": "02300",
#                 "Latitude": 43.996817,
#                 "LineCode": "71",
#                 "Longitude": -79.231133,
#                 "ModifiedDate": "2023-08-06 14:13:00",
#                 "NextStopCode": "00974",
#                 "PrevStopCode": null,
#                 "RouteNumber": "71C  ",
#                 "StartTime": "14:50",
#                 "TripNumber": "71550",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 49.0,
#                 "DelaySeconds": -196,
#                 "Display": "88  - DC Oshawa GO",
#                 "EndTime": "14:49",
#                 "FirstStopCode": "02501",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.875267,
#                 "LineCode": "88",
#                 "Longitude": -78.874483,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "00156",
#                 "RouteNumber": "88   ",
#                 "StartTime": "12:59",
#                 "TripNumber": "88411",
#                 "VariantDir": "S"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 3.0,
#                 "DelaySeconds": 14,
#                 "Display": "88  - Trent U",
#                 "EndTime": "14:48",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02501",
#                 "Latitude": 44.343933,
#                 "LineCode": "88",
#                 "Longitude": -78.305567,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02502",
#                 "RouteNumber": "88   ",
#                 "StartTime": "12:58",
#                 "TripNumber": "88480",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 342.0,
#                 "DelaySeconds": 104,
#                 "Display": "88  - Trent U",
#                 "EndTime": "15:43",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "02501",
#                 "Latitude": 44.04485,
#                 "LineCode": "88",
#                 "Longitude": -78.61785,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02504",
#                 "PrevStopCode": "02162",
#                 "RouteNumber": "88   ",
#                 "StartTime": "13:58",
#                 "TripNumber": "88560",
#                 "VariantDir": "N"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 92.0,
#                 "DelaySeconds": 2547,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "14:45",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.188617,
#                 "LineCode": "12",
#                 "Longitude": -79.465217,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "00819",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "13:25",
#                 "TripNumber": "900147",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00429",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 530,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "15:00",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.8846,
#                 "LineCode": "92",
#                 "Longitude": -78.921467,
#                 "ModifiedDate": "2023-08-06 13:35:00",
#                 "NextStopCode": "00429",
#                 "PrevStopCode": "02749",
#                 "RouteNumber": "92   ",
#                 "StartTime": "13:15",
#                 "TripNumber": "92410",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 73.0,
#                 "DelaySeconds": 10,
#                 "Display": "92 - DC Oshawa GO",
#                 "EndTime": "15:25",
#                 "FirstStopCode": "00019",
#                 "IsInMotion": true,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.855217,
#                 "LineCode": "92",
#                 "Longitude": -79.052233,
#                 "ModifiedDate": "2023-08-06 14:42:59",
#                 "NextStopCode": "00323",
#                 "PrevStopCode": "00343",
#                 "RouteNumber": "92   ",
#                 "StartTime": "13:50",
#                 "TripNumber": "92431",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02675",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 219,
#                 "Display": "92 - Yorkdale Term",
#                 "EndTime": "16:00",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": false,
#                 "LastStopCode": "00019",
#                 "Latitude": 43.875083,
#                 "LineCode": "92",
#                 "Longitude": -78.96385,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": "02675",
#                 "PrevStopCode": "00174",
#                 "RouteNumber": "92   ",
#                 "StartTime": "14:15",
#                 "TripNumber": "92450",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 157.0,
#                 "DelaySeconds": -113,
#                 "Display": "94  - Square One",
#                 "EndTime": "15:05",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": true,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.669633,
#                 "LineCode": "94",
#                 "Longitude": -79.59195,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02658",
#                 "PrevStopCode": "02209",
#                 "RouteNumber": "94   ",
#                 "StartTime": "13:25",
#                 "TripNumber": "94410",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 93.0,
#                 "DelaySeconds": -367,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "15:00",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": true,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.795317,
#                 "LineCode": "94",
#                 "Longitude": -79.152567,
#                 "ModifiedDate": "2023-08-06 14:43:39",
#                 "NextStopCode": null,
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "94   ",
#                 "StartTime": "13:20",
#                 "TripNumber": "94411",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": "02816",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": -25,
#                 "Display": "94  - Square One",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "00147",
#                 "IsInMotion": false,
#                 "LastStopCode": "00133",
#                 "Latitude": 43.775633,
#                 "LineCode": "94",
#                 "Longitude": -79.25285,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02816",
#                 "PrevStopCode": "00147",
#                 "RouteNumber": "94   ",
#                 "StartTime": "14:25",
#                 "TripNumber": "94450",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": "00022",
#                 "BusType": "Coach",
#                 "Course": 0.0,
#                 "DelaySeconds": 0,
#                 "Display": "94  - Pickering GO",
#                 "EndTime": "16:05",
#                 "FirstStopCode": "00132",
#                 "IsInMotion": false,
#                 "LastStopCode": "00147",
#                 "Latitude": 43.682433,
#                 "LineCode": "94",
#                 "Longitude": -79.613683,
#                 "ModifiedDate": "2023-08-06 14:40:19",
#                 "NextStopCode": "00022",
#                 "PrevStopCode": "02208",
#                 "RouteNumber": "94   ",
#                 "StartTime": "14:20",
#                 "TripNumber": "94451",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 265.0,
#                 "DelaySeconds": 292,
#                 "Display": "96Z - Finch Terminal",
#                 "EndTime": "14:55",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.767783,
#                 "LineCode": "96",
#                 "Longitude": -79.342067,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02772",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "96Z  ",
#                 "StartTime": "13:30",
#                 "TripNumber": "96420",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 121.0,
#                 "DelaySeconds": 166,
#                 "Display": "96Z - DC Oshawa GO",
#                 "EndTime": "15:25",
#                 "FirstStopCode": "00013",
#                 "IsInMotion": false,
#                 "LastStopCode": "00159",
#                 "Latitude": 43.778667,
#                 "LineCode": "96",
#                 "Longitude": -79.255733,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "00161",
#                 "PrevStopCode": "02816",
#                 "RouteNumber": "96Z  ",
#                 "StartTime": "14:10",
#                 "TripNumber": "96441",
#                 "VariantDir": "E"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 259.0,
#                 "DelaySeconds": 163,
#                 "Display": "96Z - Finch Terminal",
#                 "EndTime": "15:55",
#                 "FirstStopCode": "00159",
#                 "IsInMotion": true,
#                 "LastStopCode": "00736",
#                 "Latitude": 43.867017,
#                 "LineCode": "96",
#                 "Longitude": -78.959767,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02776",
#                 "PrevStopCode": "00031",
#                 "RouteNumber": "96Z  ",
#                 "StartTime": "14:30",
#                 "TripNumber": "96460",
#                 "VariantDir": "W"
#             },
#             {
#                 "AtStationCode": null,
#                 "BusType": "Coach",
#                 "Course": 69.0,
#                 "DelaySeconds": 3983,
#                 "Display": "12B - Niagara Falls",
#                 "EndTime": "14:05",
#                 "FirstStopCode": "00177",
#                 "IsInMotion": true,
#                 "LastStopCode": "02408",
#                 "Latitude": 43.1788,
#                 "LineCode": "12",
#                 "Longitude": -79.271167,
#                 "ModifiedDate": "2023-08-06 14:43:40",
#                 "NextStopCode": "02408",
#                 "PrevStopCode": "00819",
#                 "RouteNumber": "12B  ",
#                 "StartTime": "12:50",
#                 "TripNumber": "989956",
#                 "VariantDir": "W"
#             }
#         ]
#     }
# }
# Data successfully inserted into MongoDB.

# %%
trip_updates='api/V1/UP/Gtfs/Feed/TripUpdates'
try:
    trip_data = get_data(trip_updates)
    # Print the JSON response (pretty printed)
    print(json.dumps(trip_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    trip_updates_collection = db['buses']
    trip_updates_collection.insert_one(trip_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230806-4022",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 108,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 53,
#                             "time": 1691348033,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 53,
#                             "time": 1691348393,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 53,
#                             "time": 1691348873,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1691347461,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:42:00",
#                     "trip_id": "20230806-4022"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230806-4122",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691348220,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691348880,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691349240,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691349720,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1691347461,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:57:00",
#                     "trip_id": "20230806-4122"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230806-4221",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 19,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 49,
#                             "time": 1691347444,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 49,
#                             "time": 1691348149,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1691347461,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:30:00",
#                     "trip_id": "20230806-4221"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230806-4320",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 78,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 77,
#                             "time": 1691347517,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 77,
#                             "time": 1691347997,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     }
#                 ],
#                 "timestamp": 1691347461,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:27:00",
#                     "trip_id": "20230806-4320"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         },
#         {
#             "alert": null,
#             "id": "20230806-4321",
#             "is_deleted": false,
#             "trip_update": {
#                 "delay": 0,
#                 "stop_time_update": [
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691347500,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "UN"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691347980,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "BL"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691348340,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "WE"
#                     },
#                     {
#                         "arrival": null,
#                         "departure": {
#                             "delay": 0,
#                             "time": 1691349000,
#                             "uncertainty": 0
#                         },
#                         "schedule_relationship": "SCHEDULED",
#                         "stop_id": "PA"
#                     }
#                 ],
#                 "timestamp": 1691347461,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:45:00",
#                     "trip_id": "20230806-4321"
#                 },
#                 "vehicle": {
#                     "id": "1004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             },
#             "vehicle": null
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1691347462
#     }
# }
# Data successfully inserted into MongoDB.

# %%
service_messages='api/V1/ServiceUpdate/ServiceAlert/All'
try:
    service_messages_data = get_data(service_messages)
    # Print the JSON response (pretty printed)
    print(json.dumps(service_messages_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    service_messages_collection = db['service_messages']
    service_messages_collection.insert_one(service_messages_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Messages": {
#         "Message": [
#             {
#                 "BodyEnglish": "The elevator connecting the main lobby to platforms 1 and 2 is out of service. The station remains accessible through the ramp in the bus terminal.",
#                 "BodyFrench": "L'ascenseur reliant le hall principal aux quais 1 et 2 est hors service. La gare reste accessible par la rampe de la station d'autobus.",
#                 "Category": "Amenity",
#                 "Code": "M0000383679",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-06-20 09:04:42",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "HA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting June 20, City of Brampton is expected to start construction at Bramalea Terminal by the Bramalea City Centre. As a result, a temporary new bus stop on Central Park Dr. @ Knightsbridge Rd. will be used until the terminal re-opens. Here\u2019s what you need to know: \u00b7 Construction is expected to last for six months. \u00b7 During the time of construction, the bus terminal building will remain open, and you will have access to washrooms. \u00b7 Please follow directional signs. \u00b7 The construction schedule may adjust due to weather conditions or unforeseen circumstances. We will keep you updated. Thank you for your patience and understanding. Please visit the City of Brampton for more information.",
#                 "BodyFrench": "\u00c0 compter 20 juin, la ville de Brampton devrait commencer des travaux de construction \u00e0 la station de Bramalea, \u00e0 c\u00f4t\u00e9 du Bramalea City Centre. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire situ\u00e9 \u00e0 l\u2019intersection de la promenade Central Park et du chemin Knightsbridge sera utilis\u00e9 jusqu\u2019\u00e0 ce que la station rouvre. Voici ce que vous devez savoir :\u00b7 Les travaux de construction devraient durer six mois. \u00b7 Durant ces travaux, l\u2019\u00e9difice de la station d\u2019autobus rester ouvert, et vous aurez acc\u00e8s aux toilettes. \u00b7 Veuillez suivre les panneaux de signalisation. \u00b7 Le calendrier de construction pourrait \u00eatre rajust\u00e9 en fonction des conditions m\u00e9t\u00e9orologiques ou de circonstances impr\u00e9vues. Nous vous tiendrons inform\u00e9s.Nous vous remercions de votre patience et de votre compr\u00e9hension. Veuillez visiter la ville de Brampton pour obtenir de plus amples renseignements.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000388353",
#                 "Lines": [
#                     {
#                         "Code": "32"
#                     },
#                     {
#                         "Code": "36"
#                     }
#                 ],
#                 "ParentCode": "M0000387619",
#                 "PostedDateTime": "2023-06-20 00:01:20",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Bramalea Bus Terminal temporary closure",
#                 "SubjectFrench": "Fermeture temporaire du terminal d\u2019autobus de Bramalea",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Construction continues in your bus loop. Here\u2019s what you need to know:\u2022 As of July 2, the Bronte GO bus loop will be closing, and all buses will operate out of the east parking lot.\u2022 The temporary bus stop in the east parking lot will be in use until approximately Mid-August.\u2022 Please be cautious near and around construction areas.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000390213",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": "M0000389990",
#                 "PostedDateTime": "2023-07-01 10:03:28",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "BO",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "New temporary bus stops in the east lot",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Due to a construction project the southbound stop at Main Street and Baker Hill Boulevard will be missed and will also be moved back approximately 100 meters. Customers may board the bus at Main Street at Sandale Road. Please also note that the stop at Highway 48 and Hover Park will also be moved forward approximately 50 meters to provide better service during this time.",
#                 "BodyFrench": "En raison d'un projet de construction, l'arr\u00eat vers le sud de Main Street et Baker Hill Boulevard sera rat\u00e9 et sera \u00e9galement d\u00e9plac\u00e9 environ 100 m\u00e8tres. Les clients peuvent monter \u00e0 bord de l\u2019autobus sur la rue Main \u00e0 Sandale Road. Veuillez \u00e9galement noter que l\u2019arr\u00eat \u00e0 l\u2019autoroute 48 et \u00e0 Hover Park sera \u00e9galement avanc\u00e9 d\u2019environ 50 m\u00e8tres afin d\u2019offrir un meilleur service pendant cette p\u00e9riode.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000391018",
#                 "Lines": [
#                     {
#                         "Code": "70"
#                     },
#                     {
#                         "Code": "71"
#                     }
#                 ],
#                 "ParentCode": "M0000390922",
#                 "PostedDateTime": "2023-07-19 14:43:42",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified \u2013 Route 70 and 71",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the station building/bus loop/kiss & ride to the tunnel is out of service. Platforms are still accessible by using the pedestrian bridge. Visit the Pickering GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le b\u00e2timent de la gare, la ceinture de trafic pour autobus et le d\u00e9barcad\u00e8re au tunnel est hors service. Les quais sont toujours accessibles en empruntant la passerelle pour pi\u00e9tons. Visitez la page de la gare GO de Pickering pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000392957",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-20 23:09:11",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "PIN",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Lane closures are scheduled on the Burlington Skyway Bridge in the evening on Friday August 11, and August 18, 2023. All westbound lanes heading toward Niagara will be closed by 10:00 p.m.Buses on your route will detour during this time and delays of up to 20 minutes can be expected. Lanes are scheduled to reopen the following Saturday morning by 10:00 a.m.",
#                 "BodyFrench": "Des fermetures de voies sont pr\u00e9vues sur le pont Skyway de Burlington dans la soir\u00e9e les vendredi 11 ao\u00fbt et 18 ao\u00fbt 2023. Toutes les voies vers l'ouest en direction de Niagara seront ferm\u00e9es d'ici 22 h.Les autobus de votre trajet feront un d\u00e9tour pendant cette p\u00e9riode et des retards allant jusqu'\u00e0 20 minutes peuvent \u00eatre pr\u00e9vus. Les voies doivent rouvrir le samedi matin suivant avant 10 h.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393308",
#                 "Lines": [
#                     {
#                         "Code": "12"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-28 14:59:06",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Bus Delay",
#                 "SubjectEnglish": "Burlington Skyway Bridge Project \u2013 Delays Expected",
#                 "SubjectFrench": "Projet du pont Skyway de Burlington - Retards pr\u00e9vus",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "There are some rules in place to keep everyone safe and comfortable on the train. Learn everything you need to know about bringing a bike on the GO.",
#                 "BodyFrench": "Certaines r\u00e8gles sont en place pour que tout le monde reste en s\u00e9curit\u00e9 et confortable dans le train. Apprenez tout ce que vous avez besoin de savoir sur l'introduction d'un v\u00e9lo sur le GO.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000393659",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": "M0000391811",
#                 "PostedDateTime": "2023-07-26 11:41:17",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Travelling with a bicycle?",
#                 "SubjectFrench": "Vous voyagez avec un v\u00e9lo ? \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the Finch Bus Terminal to the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator at the Kiss & Ride entrance on the northwest corner of Yonge St. at Hendon Ave. Visit the Finch GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie la station d\u2019autobus de la gare de Finch au tunnel de la TTC est hors service. Les passagers qui ont besoin de cet ascenseur pour acc\u00e9der au syst\u00e8me de la TTC sont invit\u00e9s \u00e0 utiliser l'ascenseur de la TTC situ\u00e9 \u00e0 l'entr\u00e9e de la zone de d\u00e9barcad\u00e8re, \u00e0 l'angle nord-ouest de Yonge St. et de Hendon Ave. Visitez la page de la gare GO de Finch pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000393666",
#                 "Lines": [
#                     {
#                         "Code": "19"
#                     },
#                     {
#                         "Code": "27"
#                     },
#                     {
#                         "Code": "96"
#                     }
#                 ],
#                 "ParentCode": "M0000393657",
#                 "PostedDateTime": "2023-07-26 13:24:25",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "00013",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevators connecting the station to the tunnel (north side of platforms) as well as the tunnel to platform 2 and 3 are out of service. Customers who need these elevators should board the train at Scarborough GO or Union Station. An update will be provided as more information becomes available. Visit the Danforth GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "Les ascenseurs reliant la gare au tunnel (c\u00f4t\u00e9 nord des quais) ainsi que le tunnel aux quais 2 et 3 sont hors service. Les clients qui ont besoin de ces ascenseurs doivent monter \u00e0 bord du train \u00e0 la GO ou \u00e0 la Gare Union de Scarborough. La gare reste accessible depuis le tunnel ouest dans les stationnements sud et nord. Visitez la page de la gare Danforth GO pour trouver des informations utiles sur les d\u00e9parts, un plan de la gare et une liste de tous les services que nous proposons. Consultez notre page sur l'accessibilit\u00e9 pour d\u00e9couvrir comment nous nous engageons \u00e0 rendre nos services faciles \u00e0 utiliser pour tous.",
#                 "Category": "Amenity",
#                 "Code": "M0000394107",
#                 "Lines": [
#                     {
#                         "Code": "LE"
#                     }
#                 ],
#                 "ParentCode": "M0000393930",
#                 "PostedDateTime": "2023-07-30 13:19:35",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "DA",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Starting July 31st, the City of Brampton begins construction by Brampton Shopper's World. As a result, a new temporary bus stop will be located on Main Street and Charolais Boulevard for westbound trips. An update will be provided when this stop is back in service.",
#                 "BodyFrench": "\u00c0 partir du 31 juillet, la ville de Brampton commence la construction par Brampton Shopper's World. Par cons\u00e9quent, un nouvel arr\u00eat de bus temporaire sera situ\u00e9 sur la rue Main et le boulevard Charolais pour les trajets en direction ouest. Une mise \u00e0 jour sera fournie lorsque cet arr\u00eat sera de nouveau en service.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000394202",
#                 "Lines": [
#                     {
#                         "Code": "31"
#                     },
#                     {
#                         "Code": "33"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-07-31 14:35:27",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Modified Trip - Bus Detour",
#                 "SubjectEnglish": "Bus route modified - Route 31 and 33",
#                 "SubjectFrench": "Trajet d'autobus modifi\u00e9 - Trajets 31 et 33 \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Work is underway on the Bloor Street Rail Bridge, resulting in traffic impacts on Bloor Street West. Please follow all directional signs and use caution when walking near construction areas. There is no impact to train service. Until August 11, the Bloor St. entrance to the GO station is closed. Please access the station via Ernest Ave. or the Dundas St. Pick-up/drop-off area. Visit the Bloor GO Station Improvement webpage to learn more.",
#                 "BodyFrench": "Des travaux sont en cours sur le pont ferroviaire de la rue Bloor, ce qui a des incidences sur la circulation sur la rue Bloor Ouest. Veuillez suivre tous les panneaux de signalisation et faire preuve de prudence en marchant pr\u00e8s des zones de construction. Le service de train ne sera pas touch\u00e9 durant ces travaux. L\u2019entr\u00e9e de la gare GO \u00e0 la rue Bloor sera ferm\u00e9e jusqu\u2019au 11 ao\u00fbt. Veuillez acc\u00e9der \u00e0 la gare par l\u2019avenue Ernest ou la zone de d\u00e9barcad\u00e8re de la rue Dundas. Allez \u00e0 la page Web Am\u00e9lioration de la gare GO de Bloor pour en savoir plus.",
#                 "Category": "UP Express Station Messages",
#                 "Code": "M0000394356",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-05 00:01:22",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BL",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "UP Station Disruption WEB",
#                 "SubjectEnglish": "Bloor Street West Rail Bridge Shift",
#                 "SubjectFrench": "D\u00e9placement du pont ferroviaire de la rue Bloor Ouest",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platforms 2 and 3 is out of service. Customers who need this elevator should board the train at Appleby or Aldershot. Visit the Burlington GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel aux quais 2 et 3 est hors service. Les passagers qui ont besoin de cet ascenseur doivent prendre le train \u00e0 Appleby ou \u00e0 Aldershot. Visitez la page de la gare GO de Burlington pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000394533",
#                 "Lines": [
#                     {
#                         "Code": "LW"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-02 11:27:31",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BU",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the GO platform and the TTC tunnel is out of service. Customers who need this elevator to access the TTC system are advised to use the TTC station elevator on Transway Crescent, adjacent to the south parking lot. Visit the Kennedy GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000394601",
#                 "Lines": [
#                     {
#                         "Code": "ST"
#                     }
#                 ],
#                 "ParentCode": "M0000390000",
#                 "PostedDateTime": "2023-08-02 23:04:06",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "KE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platforms 1 and 2 is out of service. Customers who need this elevator should board the train at Erindale GO or Meadowvale GO. Visit the Streetsville GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": null,
#                 "Category": "Amenity",
#                 "Code": "M0000394624",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000392979",
#                 "PostedDateTime": "2023-08-03 01:28:58",
#                 "Status": "UPD",
#                 "Stops": [
#                     {
#                         "Code": "SR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Reminder: Elevator out of service",
#                 "SubjectFrench": "Rappel : Ascenseur hors service \r\n",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L'ascenseur qui relie le tunnel Est aux quais 1 et 2 est hors service. La gare reste accessible par l\u2019ascenseur du tunnel ouest. Visitez la page de la gare GO de Weston pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000394640",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-03 05:35:06",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "WE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": " Elevator out of service ",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "The elevator connecting the east tunnel to platforms 1 and 2 is out of service. The station remains accessible via the elevator to/from the west tunnel. Visit the Weston Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "Category": "Amenity",
#                 "Code": "M0000394641",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-03 05:41:12",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "WE",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service",
#                 "SubjectFrench": "Ascenseur hors service",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "A temporary schedule change is in effect due to track work that requires trains to travel slower in some areas. Check updated schedules here. If you are connecting with local transit from Milton GO station, check connection times using triplinx.ca. Thank you for your patience during this important work.",
#                 "BodyFrench": "Un changement temporaire \u00e0 l\u2019horaire est en vigueur en raison de travaux sur la voie qui n\u00e9cessitent une r\u00e9duction de la vitesse des trains dans certains secteurs. Consultez les horaires mis \u00e0 jour ici. Si vous avez une correspondance avec le transport en commun local \u00e0 partir de la gare GO de Milton, consultez les heures de correspondance sur triplinx.ca. Nous vous remercions de votre patience pendant que nous effectuons ces travaux importants.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000394811",
#                 "Lines": [
#                     {
#                         "Code": "MI"
#                     }
#                 ],
#                 "ParentCode": "M0000393486",
#                 "PostedDateTime": "2023-08-04 12:43:15",
#                 "Status": "UPD",
#                 "Stops": [],
#                 "SubCategory": "Train Delay",
#                 "SubjectEnglish": "Temporary schedule change on Milton Line",
#                 "SubjectFrench": "Changement temporaire \u00e0 l\u2019horaire de la ligne Milton",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "Work is underway on the Bloor Street Rail Bridge, resulting in traffic impacts on Bloor Street West. Please follow all directional signs and use caution when walking near construction areas. There is no impact to train service. From August 12-18, the Bloor St. entrance to the GO station will be closed. Please access the station via Ernest Ave. or the Dundas St. Pick-up/drop-off area. Visit the Bloor GO Station Improvement webpage to learn more.",
#                 "BodyFrench": "Des travaux sont en cours sur le pont ferroviaire de la rue Bloor, ce qui a des incidences sur la circulation sur la rue Bloor Ouest. Veuillez suivre tous les panneaux de signalisation et faire preuve de prudence en marchant pr\u00e8s des zones de construction. Le service de train ne sera pas touch\u00e9 durant ces travaux. Du 12 au 18 ao\u00fbt, l\u2019entr\u00e9e de la gare GO sur la rue Bloor sera ferm\u00e9e. Veuillez acc\u00e9der \u00e0 la gare par l\u2019avenue Ernest ou la zone de d\u00e9barcad\u00e8re de la rue Dundas. Allez \u00e0 la page Web Am\u00e9lioration de la gare GO de Bloor pour en savoir plus.",
#                 "Category": "UP Express Station Messages",
#                 "Code": "M0000394827",
#                 "Lines": [
#                     {
#                         "Code": "UP"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-04 14:31:33",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BL",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "UP Station Disruption WEB",
#                 "SubjectEnglish": " UP - Bloor Street West Rail Bridge Shift",
#                 "SubjectFrench": "D\u00e9placement du pont ferroviaire de la rue Bloor Ouest",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The elevator connecting the tunnel to platform 1 is out of service. The station remains accessible. Visit the Brampton GO Station page to find helpful information on departures, a station map and a listing of all the services we have available. Visit our Accessibility page to see how we are committed to making our services easy for everyone to use.",
#                 "BodyFrench": "L\u2019ascenseur qui relie le tunnel \u00e0 la quai 1 est hors service. La gare reste accessible. Visitez la page de la gare GO de Brampton pour trouver des informations utiles, notamment sur les d\u00e9parts, un plan de la gare et tous les services que nous proposons. Visitez notre page Accessibilit\u00e9 pour voir comment nous nous engageons \u00e0 rendre nos services aussi faciles \u00e0 utiliser que possible pour tout le monde.",
#                 "Category": "Amenity",
#                 "Code": "M0000395041",
#                 "Lines": [
#                     {
#                         "Code": "GT"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-06 08:58:07",
#                 "Status": "INIT",
#                 "Stops": [
#                     {
#                         "Code": "BR",
#                         "Name": null
#                     }
#                 ],
#                 "SubCategory": "Elevator-Escalator Disruption",
#                 "SubjectEnglish": "Elevator out of service ",
#                 "SubjectFrench": "",
#                 "Trips": []
#             },
#             {
#                 "BodyEnglish": "The Union Station Bus Terminal 14:05 - Hamilton GO Centre 15:15 bus is cancelled due to an operational adjustment. The next bus is scheduled to depart Union Station Bus Terminal at 14:35.",
#                 "BodyFrench": "L'autobus de la gare Union 14:05 - Hamilton GO Centre 15:15 est annul\u00e9 en raison d'un ajustement op\u00e9rationnel. Le prochain bus est pr\u00e9vu de quitter la gare Union Bus Terminal \u00e0 14:35.",
#                 "Category": "Service Disruption",
#                 "Code": "M0000395055",
#                 "Lines": [
#                     {
#                         "Code": "16"
#                     }
#                 ],
#                 "ParentCode": null,
#                 "PostedDateTime": "2023-08-06 12:39:47",
#                 "Status": "INIT",
#                 "Stops": [],
#                 "SubCategory": "Bus Cancellation",
#                 "SubjectEnglish": "Bus cancelled - Union Station Bus Terminal 14:05 - Hamilton GO Centre 15:15",
#                 "SubjectFrench": "Bus annul\u00e9 - Station d'autobus de la gare Union 14:05 - Centre GO de Hamilton 15:15 \r\n",
#                 "Trips": [
#                     {
#                         "TripNumber": "16441"
#                     }
#                 ]
#             }
#         ]
#     },
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-06 14:44:27"
#     }
# }
# Data successfully inserted into MongoDB.

# %%
vechile_position='api/V1/UP/Gtfs/Feed/VehiclePosition'
try:
    vechile_position_data = get_data(vechile_position)
    # Print the JSON response (pretty printed)
    print(json.dumps(vechile_position_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    vechile_position_collection = db['service_messages']
    vechile_position_collection.insert_one(vechile_position_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "entity": [
#         {
#             "alert": null,
#             "id": "20230806-4022",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6860161,
#                     "longitude": -79.61544,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1691347466,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:42:00",
#                     "trip_id": "20230806-4022"
#                 },
#                 "vehicle": {
#                     "id": "3001",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230806-4122",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "IN_TRANSIT_TO",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6829224,
#                     "longitude": -79.61338,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "PA",
#                 "timestamp": 1691347466,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:57:00",
#                     "trip_id": "20230806-4122"
#                 },
#                 "vehicle": {
#                     "id": "3006",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230806-4221",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.7001839,
#                     "longitude": -79.51331,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "WE",
#                 "timestamp": 1691347466,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:30:00",
#                     "trip_id": "20230806-4221"
#                 },
#                 "vehicle": {
#                     "id": "3003",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230806-4320",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.6578331,
#                     "longitude": -79.45105,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "BL",
#                 "timestamp": 1691347466,
#                 "trip": {
#                     "direction_id": 0,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:27:00",
#                     "trip_id": "20230806-4320"
#                 },
#                 "vehicle": {
#                     "id": "3004",
#                     "label": "UP - Union Station",
#                     "license_plate": ""
#                 }
#             }
#         },
#         {
#             "alert": null,
#             "id": "20230806-4321",
#             "is_deleted": false,
#             "trip_update": null,
#             "vehicle": {
#                 "congestion_level": "UNKNOWN_CONGESTION_LEVEL",
#                 "current_status": "INCOMING_AT",
#                 "occupancy_status": "EMPTY",
#                 "position": {
#                     "bearing": 0.0,
#                     "latitude": 43.64437,
#                     "longitude": -79.3829346,
#                     "odometer": 0.0,
#                     "speed": 0.0
#                 },
#                 "stop_id": "UN",
#                 "timestamp": 1691347466,
#                 "trip": {
#                     "direction_id": 1,
#                     "route_id": "UP",
#                     "schedule_relationship": "SCHEDULED",
#                     "start_date": "20230806",
#                     "start_time": "14:45:00",
#                     "trip_id": "20230806-4321"
#                 },
#                 "vehicle": {
#                     "id": "1004",
#                     "label": "UP - Pearson Airport",
#                     "license_plate": ""
#                 }
#             }
#         }
#     ],
#     "header": {
#         "gtfs_realtime_version": "1.0",
#         "incrementality": "FULL_DATASET",
#         "timestamp": 1691347467
#     }
# }
# Data successfully inserted into MongoDB.

# %%
train_cancelled='api/V1/ServiceUpdate/Exceptions/Train'
try:
    train_cancelled_data = get_data(train_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(train_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    train_cancelled_collection = db['train_cancelled']
    train_cancelled_collection.insert_one(train_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "204",
#         "ErrorMessage": "No Content",
#         "TimeStamp": "2023-08-06 14:44:28"
#     },
#     "Trip": []
# }
# Data successfully inserted into MongoDB.

# %%
bus_cancelled='api/V1/ServiceUpdate/Exceptions/Bus'
try:
    bus_cancelled_data = get_data(bus_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(bus_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    bus_cancelled_collection = db['bus_cancelled']
    bus_cancelled_collection.insert_one(bus_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-06 14:44:29"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "947720"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00128",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Unionville GO",
#                     "Order": 27,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02141",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Ymca Blvd. @ Kennedy Rd.",
#                     "Order": 28,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02300",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station Bus Terminal",
#                     "Order": 29,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "962556"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "952452"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "915209"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "947280"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "964483"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "989956"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "900147"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 12:30 - Union Station Bus Terminal 13:50",
#             "TripNumber": "16420"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 14:05 - Hamilton GO Centre 15:15",
#             "TripNumber": "16441"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.

# %%
all_cancelled='api/V1/ServiceUpdate/Exceptions/All'
try:
    all_cancelled_data = get_data(all_cancelled)
    # Print the JSON response (pretty printed)
    print(json.dumps(all_cancelled_data, indent=4, sort_keys=True))

    # Connect to MongoDB
    client = MongoClient('localhost', 27017)  # Replace with your MongoDB connection details
    db = client['metrolinx']  # Use the appropriate database name

    # Insert the train_data as a single document into the 'trains' collection
    all_cancelled_collection = db['all_cancelled']
    all_cancelled_collection.insert_one(all_cancelled_data)

    print("Data successfully inserted into MongoDB.")
except requests.exceptions.HTTPError as e:
    print("Request failed with status code:", e.response.status_code)
# Out:
# {
#     "Metadata": {
#         "ErrorCode": "200",
#         "ErrorMessage": "OK",
#         "TimeStamp": "2023-08-06 14:44:29"
#     },
#     "Trip": [
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "947720"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00128",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Unionville GO",
#                     "Order": 27,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02141",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Ymca Blvd. @ Kennedy Rd.",
#                     "Order": 28,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02300",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Union Station Bus Terminal",
#                     "Order": 29,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "962556"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "952452"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "915209"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "947280"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "964483"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "989956"
#         },
#         {
#             "IsCancelled": "0",
#             "IsOverride": "1",
#             "Stop": [
#                 {
#                     "ActualTime": null,
#                     "Code": "00177",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Burlington GO",
#                     "Order": 1,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "00819",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Fairview St @ Maple Ave",
#                     "Order": 2,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02404",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Stanley Ave. @ Hwy. 420 Park & Ride",
#                     "Order": 3,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 },
#                 {
#                     "ActualTime": null,
#                     "Code": "02408",
#                     "ID": "",
#                     "IsCancelled": "0",
#                     "IsOverride": "1",
#                     "IsStopping": "0",
#                     "Name": "Niagara Falls Bus Terminal",
#                     "Order": 4,
#                     "SchArrival": null,
#                     "SchDeparture": null,
#                     "ServiceType": "B"
#                 }
#             ],
#             "TripName": "",
#             "TripNumber": "900147"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Hamilton GO Centre 12:30 - Union Station Bus Terminal 13:50",
#             "TripNumber": "16420"
#         },
#         {
#             "IsCancelled": "1",
#             "IsOverride": "0",
#             "Stop": [],
#             "TripName": "Union Station Bus Terminal 14:05 - Hamilton GO Centre 15:15",
#             "TripNumber": "16441"
#         }
#     ]
# }
# Data successfully inserted into MongoDB.
